# %% [markdown]
# <h1><center> MODELLING INVESTMENT STRATEGIES </center></h1>
# <h2><center> IDEAS FROM GOOGLE'S COLLABORATIVE RESEARCH COMMUNITY </center></h2>

# %% [markdown]
# ## 1. SOURCES

# %% [markdown]
# https://github.com/firmai/financial-machine-learning

# %% [markdown]
# https://colab.research.google.com/drive/1FzLCI0AO3c7A4bp9Fi01UwXeoc7BN8sW

# %% [markdown]
# ## 2. CREATING THE DATA FILE

# %%
## Further  recommendation, test multiple frameworks, see what works better on average. 
## Open source RL: https://docs.google.com/spreadsheets/d/1EeFPd-XIQ3mq_9snTlAZSsFY7Hbnmd7P5bbT8LPuMn0/edit#gid=0

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
sns.set()
# Out:
# D:\Program Files\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from pandas_datareader import data as pdr
import fix_yahoo_finance as yf
df_full = pdr.get_data_yahoo("JPM", start="2018-01-01").reset_index()
df_full.to_csv('JPM.csv',index=False)
df_full.head()
# Out:
# D:\Program Files\Anaconda\lib\site-packages\fix_yahoo_finance\__init__.py:0: DeprecationWarning:
#
# *** `fix_yahoo_finance` was renamed to `yfinance`. ***
# Please install and use `yfinance` directly using `pip install yfinance -U`
#
# More information: https://github.com/ranaroussi/yfinance

# %%
df_full = pd.read_csv('JPM.csv')

# %% [markdown]
# ## 3. MODELING THE INVESTMENT  AGENTS

# %% [markdown]
# ###  3.1. TURTLE TRADING

# %% [markdown]
# Turtle trading is a well known trend following strategy that was originally taught by Richard Dennis. The basic strategy is to buy futures on a 20-day high (breakout) and sell on a 20-day low, although the full set of rules is more intricate. I've modeled the meat of the strategy in Quantopian and used it to trade exchange-traded funds (ETFs), in this case just some silver and copper securities.
#
# I used rules from here. From what I have seen, the rules of turtle trading slightly vary from source to source, however what's outlined in that PDF seems well-guided and reliable. If you want to adjust the rules you can clone this and it should be fairly straightforward from there. I've also added an option in the code if you only want to long and not short. To trigger buys and sells, the code calculates the goal amount of shares then works from there to determine how many to buy or sell. This method for determining order amount works well for things like risk-adjusted portfolio sizes.
#
# This is a pretty fundamental strategy and it seems to work well. There are a few different parameters to play with, so clone this and see if you can get some good results or even add to the code in any way.

# %%
df= df_full.copy()
name = 'Turtle Trading Agent'
count = int(np.ceil(len(df) * 0.1))
signals = pd.DataFrame(index=df.index)
signals['signal'] = 0.0
signals['trend'] = df['Close']
signals['RollingMax'] = (signals.trend.shift(1).rolling(count).max())
signals['RollingMin'] = (signals.trend.shift(1).rolling(count).min())
signals.loc[signals['RollingMax'] < signals.trend, 'signal'] = -1
signals.loc[signals['RollingMin'] > signals.trend, 'signal'] = 1
signals
# Out:
#      signal       trend  RollingMax  RollingMin
# 0       0.0  107.949997         NaN         NaN
# 1       0.0  108.059998         NaN         NaN
# 2       0.0  109.040001         NaN         NaN
# 3       0.0  108.339996         NaN         NaN
# 4       0.0  108.500000         NaN         NaN
# ..      ...         ...         ...         ...
# 523     0.0  132.360001  141.089996  128.479996
# 524     0.0  133.369995  141.089996  128.600006
# 525     0.0  135.289993  141.089996  129.529999
# 526     0.0  137.589996  141.089996  129.630005
# 527     0.0  137.654205  141.089996  129.630005
#
# [528 rows x 4 columns]

# %%
def buy_stock(
    real_movement,
    signal,
    initial_money = 10000,
    max_buy = 1,
    max_sell = 1,
):
    """
    real_movement = actual movement in the real world
    delay = how much interval you want to delay to change our decision from buy to sell, vice versa
    initial_state = 1 is buy, 0 is sell
    initial_money = 1000, ignore what kind of currency
    max_buy = max quantity for share to buy
    max_sell = max quantity for share to sell
    """
    starting_money = initial_money
    states_sell = []
    states_buy = []
    current_inventory = 0

    def buy(i, initial_money, current_inventory):
        shares = initial_money // real_movement[i]
        if shares < 1:
            print(
                'day %d: total balances %f, not enough money to buy a unit price %f'
                % (i, initial_money, real_movement[i])
            )
        else:
            if shares > max_buy:
                buy_units = max_buy
            else:
                buy_units = shares
            initial_money -= buy_units * real_movement[i]
            current_inventory += buy_units
            print(
                'day %d: buy %d units at price %f, total balance %f'
                % (i, buy_units, buy_units * real_movement[i], initial_money)
            )
            states_buy.append(0)
        return initial_money, current_inventory

    for i in range(real_movement.shape[0] - int(0.025 * len(df))):
        state = signal[i]
        if state == 1:
            initial_money, current_inventory = buy(
                i, initial_money, current_inventory
            )
            states_buy.append(i)
        elif state == -1:
            if current_inventory == 0:
                    print('day %d: cannot sell anything, inventory 0' % (i))
            else:
                if current_inventory > max_sell:
                    sell_units = max_sell
                else:
                    sell_units = current_inventory
                current_inventory -= sell_units
                total_sell = sell_units * real_movement[i]
                initial_money += total_sell
                try:
                    invest = (
                        (real_movement[i] - real_movement[states_buy[-1]])
                        / real_movement[states_buy[-1]]
                    ) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell %d units at price %f, investment %f %%, total balance %f,'
                    % (i, sell_units, total_sell, invest, initial_money)
                )
            states_sell.append(i)
            
    invest = ((initial_money - starting_money) / starting_money) * 100
    total_gains = initial_money - starting_money
    return states_buy, states_sell, total_gains, invest

# %%
states_buy, states_sell, total_gains, invest = buy_stock(df.Close, signals['signal'])
# Out:
# day 56: buy 1 units at price 107.010002, total balance 9892.989998
# day 101: buy 1 units at price 105.930000, total balance 9787.059998
# day 119: buy 1 units at price 105.750000, total balance 9681.309998
# day 120: buy 1 units at price 104.790001, total balance 9576.519997
# day 122: buy 1 units at price 103.239998, total balance 9473.279999
# day 141, sell 1 units at price 115.180000, investment 11.565287 %, total balance 9588.459999,
# day 143, sell 1 units at price 116.029999, investment 12.388610 %, total balance 9704.489998,
# day 144, sell 1 units at price 116.730003, investment 13.066646 %, total balance 9821.220001,
# day 148, sell 1 units at price 117.089996, investment 13.415342 %, total balance 9938.309998,
# day 149, sell 1 units at price 117.120003, investment 13.444406 %, total balance 10055.430000,
# day 150: cannot sell anything, inventory 0
# day 151: cannot sell anything, inventory 0
# day 181: cannot sell anything, inventory 0
# day 195: buy 1 units at price 111.470001, total balance 9943.959999
# day 196: buy 1 units at price 108.129997, total balance 9835.830002
# day 197: buy 1 units at price 106.949997, total balance 9728.880005
# day 198: buy 1 units at price 106.339996, total balance 9622.540009
# day 204: buy 1 units at price 105.250000, total balance 9517.290009
# day 205: buy 1 units at price 103.290001, total balance 9414.000008
# day 236: buy 1 units at price 101.360001, total balance 9312.640007
# day 237: buy 1 units at price 100.370003, total balance 9212.270004
# day 240: buy 1 units at price 100.290001, total balance 9111.980003
# day 241: buy 1 units at price 99.010002, total balance 9012.970001
# day 242: buy 1 units at price 98.540001, total balance 8914.430000
# day 243: buy 1 units at price 97.290001, total balance 8817.139999
# day 244: buy 1 units at price 96.449997, total balance 8720.690002
# day 245: buy 1 units at price 94.169998, total balance 8626.520004
# day 246: buy 1 units at price 92.139999, total balance 8534.380005
# day 287, sell 1 units at price 106.099998, investment 15.150856 %, total balance 8640.480003,
# day 301, sell 1 units at price 106.550003, investment 15.639249 %, total balance 8747.030006,
# day 302, sell 1 units at price 107.190002, investment 16.333843 %, total balance 8854.220009,
# day 306: buy 1 units at price 99.760002, total balance 8754.460007
# day 307: buy 1 units at price 98.930000, total balance 8655.530006
# day 321, sell 1 units at price 111.209999, investment 12.412816 %, total balance 8766.740005,
# day 324, sell 1 units at price 114.300003, investment 15.536240 %, total balance 8881.040009,
# day 330, sell 1 units at price 114.470001, investment 15.708077 %, total balance 8995.510010,
# day 331, sell 1 units at price 116.120003, investment 17.375925 %, total balance 9111.630013,
# day 390, sell 1 units at price 116.360001, investment 17.618518 %, total balance 9227.990013,
# day 391, sell 1 units at price 116.830002, investment 18.093603 %, total balance 9344.820015,
# day 406: buy 1 units at price 104.800003, total balance 9240.020012
# day 424, sell 1 units at price 116.870003, investment 11.517175 %, total balance 9356.890015,
# day 425, sell 1 units at price 117.190002, investment 11.822518 %, total balance 9474.080017,
# day 426, sell 1 units at price 117.910004, investment 12.509542 %, total balance 9591.990021,
# day 427, sell 1 units at price 120.230003, investment 14.723282 %, total balance 9712.220024,
# day 451, sell 1 units at price 120.349998, investment 14.837781 %, total balance 9832.570023,
# day 452, sell 1 units at price 120.559998, investment 15.038162 %, total balance 9953.130020,
# day 453, sell 1 units at price 123.550003, investment 17.891221 %, total balance 10076.680023,
# day 454, sell 1 units at price 124.790001, investment 19.074425 %, total balance 10201.470024,
# day 455, sell 1 units at price 125.120003, investment 19.389312 %, total balance 10326.590027,
# day 457: cannot sell anything, inventory 0
# day 458: cannot sell anything, inventory 0
# day 462: cannot sell anything, inventory 0
# day 463: cannot sell anything, inventory 0
# day 464: cannot sell anything, inventory 0
# day 465: cannot sell anything, inventory 0
# day 466: cannot sell anything, inventory 0
# day 467: cannot sell anything, inventory 0
# day 473: cannot sell anything, inventory 0
# day 477: cannot sell anything, inventory 0
# day 478: cannot sell anything, inventory 0
# day 479: cannot sell anything, inventory 0
# day 480: cannot sell anything, inventory 0
# day 484: cannot sell anything, inventory 0
# day 485: cannot sell anything, inventory 0
# day 486: cannot sell anything, inventory 0
# day 490: cannot sell anything, inventory 0
# day 493: cannot sell anything, inventory 0
# day 499: cannot sell anything, inventory 0
# day 500: cannot sell anything, inventory 0
# day 502: cannot sell anything, inventory 0
# day 503: cannot sell anything, inventory 0

# %%
close = df['Close']
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig('output/'+name+'.png')
plt.show()

# %% [markdown]
# ### 3.2.MOVING AVERAGE

# %% [markdown]
# In the statistics of time series, and in particular the analysis of financial time series for stock trading purposes, a moving-average crossover occurs when, on plotting two moving averages each based on different degrees of smoothing, the traces of these moving averages cross. It does not predict future direction but shows trends. This indicator uses two (or more) moving averages, a slower moving average and a faster moving average. The faster moving average is a short term moving average. For end-of-day stock markets, for example, it may be 5-, 10- or 25-day period while the slower moving average is medium or long term moving average (e.g. 50-, 100- or 200-day period). A short term moving average is faster because it only considers prices over short period of time and is thus more reactive to daily price changes. On the other hand, a long term moving average is deemed slower as it encapsulates prices over a longer period and is more lethargic. However, it tends to smooth out price noises which are often reflected in short term moving averages.
#
# A moving average, as a line by itself, is often overlaid in price charts to indicate price trends. A crossover occurs when a faster moving average (i.e., a shorter period moving average) crosses a slower moving average (i.e. a longer period moving average). In other words, this is when the shorter period moving average line crosses a longer period moving average line. In stock investing, this meeting point is used either to enter (buy or sell) or exit (sell or buy) the market.
#
# The particular case where simple equally weighted moving-averages are used is sometimes called a simple moving-average (SMA) crossover. Such a crossover can be used to signal a change in trend and can be used to trigger a trade in a Black Box trading system.

# %%
df= df_full.copy()
name = 'Moving Average agent'

short_window = int(0.025 * len(df))
long_window = int(0.05 * len(df))

signals = pd.DataFrame(index=df.index)
signals['signal'] = 0.0

signals['short_ma'] = df['Close'].rolling(window=short_window, min_periods=1, center=False).mean()
signals['long_ma'] = df['Close'].rolling(window=long_window, min_periods=1, center=False).mean()

signals['signal'][short_window:] = np.where(signals['short_ma'][short_window:] 
                                            > signals['long_ma'][short_window:], 1.0, 0.0)   
signals['positions'] = signals['signal'].diff()

signals
# Out:
#      signal    short_ma     long_ma  positions
# 0       0.0  107.949997  107.949997        NaN
# 1       0.0  108.004997  108.004997        0.0
# 2       0.0  108.349998  108.349998        0.0
# 3       0.0  108.347498  108.347498        0.0
# 4       0.0  108.377998  108.377998        0.0
# ..      ...         ...         ...        ...
# 523     0.0  135.624613  136.849998        0.0
# 524     0.0  135.206920  136.688075        0.0
# 525     0.0  135.096919  136.543844        0.0
# 526     0.0  135.123073  136.484229        0.0
# 527     0.0  135.081089  136.446698        0.0
#
# [528 rows x 4 columns]

# %%
def buy_stock(
    real_movement,
    signal,
    initial_money = 10000,
    max_buy = 1,
    max_sell = 1,
):
    """
    real_movement = actual movement in the real world
    delay = how much interval you want to delay to change our decision from buy to sell, vice versa
    initial_state = 1 is buy, 0 is sell
    initial_money = 1000, ignore what kind of currency
    max_buy = max quantity for share to buy
    max_sell = max quantity for share to sell
    """
    starting_money = initial_money
    states_sell = []
    states_buy = []
    current_inventory = 0

    def buy(i, initial_money, current_inventory):
        shares = initial_money // real_movement[i]
        if shares < 1:
            print(
                'day %d: total balances %f, not enough money to buy a unit price %f'
                % (i, initial_money, real_movement[i])
            )
        else:
            if shares > max_buy:
                buy_units = max_buy
            else:
                buy_units = shares
            initial_money -= buy_units * real_movement[i]
            current_inventory += buy_units
            print(
                'day %d: buy %d units at price %f, total balance %f'
                % (i, buy_units, buy_units * real_movement[i], initial_money)
            )
            states_buy.append(0)
        return initial_money, current_inventory

    for i in range(real_movement.shape[0] - int(0.025 * len(df))):
        state = signal[i]
        if state == 1:
            initial_money, current_inventory = buy(
                i, initial_money, current_inventory
            )
            states_buy.append(i)
        elif state == -1:
            if current_inventory == 0:
                    print('day %d: cannot sell anything, inventory 0' % (i))
            else:
                if current_inventory > max_sell:
                    sell_units = max_sell
                else:
                    sell_units = current_inventory
                current_inventory -= sell_units
                total_sell = sell_units * real_movement[i]
                initial_money += total_sell
                try:
                    invest = (
                        (real_movement[i] - real_movement[states_buy[-1]])
                        / real_movement[states_buy[-1]]
                    ) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell %d units at price %f, investment %f %%, total balance %f,'
                    % (i, sell_units, total_sell, invest, initial_money)
                )
            states_sell.append(i)
    invest = ((initial_money - starting_money) / starting_money) * 100
    total_gains = initial_money - starting_money
    return states_buy, states_sell, total_gains, invest

# %%
states_buy, states_sell, total_gains, invest = buy_stock(df.Close, signals['positions'])
# Out:
# day 13: buy 1 units at price 114.330002, total balance 9885.669998
# day 30, sell 1 units at price 115.029999, investment 0.612260 %, total balance 10000.699997,
# day 39: buy 1 units at price 115.500000, total balance 9885.199997
# day 55, sell 1 units at price 109.949997, investment -4.805197 %, total balance 9995.149994,
# day 76: buy 1 units at price 110.930000, total balance 9884.219994
# day 82, sell 1 units at price 108.779999, investment -1.938161 %, total balance 9992.999992,
# day 93: buy 1 units at price 113.339996, total balance 9879.659996
# day 105, sell 1 units at price 108.449997, investment -4.314452 %, total balance 9988.109993,
# day 137: buy 1 units at price 109.889999, total balance 9878.219994
# day 163, sell 1 units at price 114.680000, investment 4.358905 %, total balance 9992.899994,
# day 184: buy 1 units at price 116.389999, total balance 9876.509995
# day 195, sell 1 units at price 111.470001, investment -4.227166 %, total balance 9987.979996,
# day 219: buy 1 units at price 109.589996, total balance 9878.389999
# day 234, sell 1 units at price 105.190002, investment -4.014959 %, total balance 9983.580002,
# day 260: buy 1 units at price 101.680000, total balance 9881.900002
# day 305, sell 1 units at price 102.870003, investment 1.170341 %, total balance 9984.770004,
# day 321: buy 1 units at price 111.209999, total balance 9873.560005
# day 345, sell 1 units at price 110.769997, investment -0.395650 %, total balance 9984.330002,
# day 367: buy 1 units at price 109.910004, total balance 9874.419998
# day 402, sell 1 units at price 109.860001, investment -0.045495 %, total balance 9984.279999,
# day 423: buy 1 units at price 115.400002, total balance 9868.879997
# day 444, sell 1 units at price 111.820000, investment -3.102255 %, total balance 9980.699997,
# day 454: buy 1 units at price 124.790001, total balance 9855.909996

# %%
close = df['Close']
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig('output/'+name+'.png')
plt.show()

# %% [markdown]
# ### 3.3. SIGNAL ROLLING AGENT

# %%
df= df_full.copy()
name = 'Signal Rolling agent'

# %%
def buy_stock(
    real_movement,
    delay = 5,
    initial_state = 1,
    initial_money = 10000,
    max_buy = 1,
    max_sell = 1,
):
    """
    real_movement = actual movement in the real world
    delay = how much interval you want to delay to change our decision from buy to sell, vice versa
    initial_state = 1 is buy, 0 is sell
    initial_money = 1000, ignore what kind of currency
    max_buy = max quantity for share to buy
    max_sell = max quantity for share to sell
    """
    starting_money = initial_money
    delay_change_decision = delay
    current_decision = 0
    state = initial_state
    current_val = real_movement[0]
    states_sell = []
    states_buy = []
    current_inventory = 0

    def buy(i, initial_money, current_inventory):
        shares = initial_money // real_movement[i]
        if shares < 1:
            print(
                'day %d: total balances %f, not enough money to buy a unit price %f'
                % (i, initial_money, real_movement[i])
            )
        else:
            if shares > max_buy:
                buy_units = max_buy
            else:
                buy_units = shares
            initial_money -= buy_units * real_movement[i]
            current_inventory += buy_units
            print(
                'day %d: buy %d units at price %f, total balance %f'
                % (i, buy_units, buy_units * real_movement[i], initial_money)
            )
            states_buy.append(0)
        return initial_money, current_inventory

    if state == 1:
        initial_money, current_inventory = buy(
            0, initial_money, current_inventory
        )

    for i in range(1, real_movement.shape[0], 1):
        if real_movement[i] < current_val and state == 0:
            if current_decision < delay_change_decision:
                current_decision += 1
            else:
                state = 1
                initial_money, current_inventory = buy(
                    i, initial_money, current_inventory
                )
                current_decision = 0
                states_buy.append(i)
        if real_movement[i] > current_val and state == 1:
            if current_decision < delay_change_decision:
                current_decision += 1
            else:
                state = 0

                if current_inventory == 0:
                    print('day %d: cannot sell anything, inventory 0' % (i))
                else:
                    if current_inventory > max_sell:
                        sell_units = max_sell
                    else:
                        sell_units = current_inventory
                    current_inventory -= sell_units
                    total_sell = sell_units * real_movement[i]
                    initial_money += total_sell
                    try:
                        invest = (
                            (real_movement[i] - real_movement[states_buy[-1]])
                            / real_movement[states_buy[-1]]
                        ) * 100
                    except:
                        invest = 0
                    print(
                        'day %d, sell %d units at price %f, investment %f %%, total balance %f,'
                        % (i, sell_units, total_sell, invest, initial_money)
                    )

                current_decision = 0
                states_sell.append(i)
        current_val = real_movement[i]
    invest = ((initial_money - starting_money) / starting_money) * 100
    total_gains = initial_money - starting_money
    return states_buy, states_sell, total_gains, invest

# %%
states_buy, states_sell, total_gains, invest = buy_stock(df.Close, initial_state = 1, 
                                                         delay = 4, initial_money = 10000)
# Out:
# day 0: buy 1 units at price 107.949997, total balance 9892.050003
# day 6, sell 1 units at price 110.250000, investment 2.130619 %, total balance 10002.300003,
# day 19: buy 1 units at price 115.110001, total balance 9887.190002
# day 27, sell 1 units at price 110.040001, investment -4.404482 %, total balance 9997.230003,
# day 40: buy 1 units at price 113.430000, total balance 9883.800003
# day 50, sell 1 units at price 115.239998, investment 1.595696 %, total balance 9999.040001,
# day 59: buy 1 units at price 108.000000, total balance 9891.040001
# day 66, sell 1 units at price 110.400002, investment 2.222224 %, total balance 10001.440002,
# day 75: buy 1 units at price 111.470001, total balance 9889.970001
# day 88, sell 1 units at price 113.410004, investment 1.740381 %, total balance 10003.380005,
# day 98: buy 1 units at price 112.489998, total balance 9890.890007
# day 108, sell 1 units at price 110.800003, investment -1.502351 %, total balance 10001.690010,
# day 114: buy 1 units at price 107.900002, total balance 9893.790009
# day 127, sell 1 units at price 103.720001, investment -3.873958 %, total balance 9997.510010,
# day 137: buy 1 units at price 109.889999, total balance 9887.620010
# day 143, sell 1 units at price 116.029999, investment 5.587405 %, total balance 10003.650009,
# day 156: buy 1 units at price 113.699997, total balance 9889.950012
# day 172, sell 1 units at price 114.320000, investment 0.545297 %, total balance 10004.270012,
# day 183: buy 1 units at price 116.720001, total balance 9887.550011
# day 193, sell 1 units at price 115.320000, investment -1.199453 %, total balance 10002.870010,
# day 198: buy 1 units at price 106.339996, total balance 9896.530014
# day 209, sell 1 units at price 106.699997, investment 0.338537 %, total balance 10003.230011,
# day 220: buy 1 units at price 107.330002, total balance 9895.900009
# day 229, sell 1 units at price 110.940002, investment 3.363459 %, total balance 10006.840012,
# day 236: buy 1 units at price 101.360001, total balance 9905.480011
# day 250, sell 1 units at price 97.620003, investment -3.689816 %, total balance 10003.100014,
# day 258: buy 1 units at price 99.910004, total balance 9903.190010
# day 263, sell 1 units at price 104.589996, investment 4.684208 %, total balance 10007.780006,
# day 275: buy 1 units at price 103.739998, total balance 9904.040009
# day 287, sell 1 units at price 106.099998, investment 2.274919 %, total balance 10010.140007,
# day 293: buy 1 units at price 104.110001, total balance 9906.030006
# day 301, sell 1 units at price 106.550003, investment 2.343677 %, total balance 10012.580009,
# day 307: buy 1 units at price 98.930000, total balance 9913.650009
# day 313, sell 1 units at price 105.139999, investment 6.277165 %, total balance 10018.790009,
# day 328: buy 1 units at price 113.550003, total balance 9905.240005
# day 335, sell 1 units at price 116.120003, investment 2.263320 %, total balance 10021.360008,
# day 340: buy 1 units at price 112.510002, total balance 9908.850006
# day 350, sell 1 units at price 109.709999, investment -2.488670 %, total balance 10018.560005,
# day 359: buy 1 units at price 109.160004, total balance 9909.400002
# day 366, sell 1 units at price 110.709999, investment 1.419930 %, total balance 10020.110001,
# day 377: buy 1 units at price 112.820000, total balance 9907.290001
# day 385, sell 1 units at price 115.120003, investment 2.038648 %, total balance 10022.410004,
# day 395: buy 1 units at price 115.589996, total balance 9906.820007
# day 407, sell 1 units at price 105.199997, investment -8.988667 %, total balance 10012.020004,
# day 428: buy 1 units at price 119.160004, total balance 9892.860001
# day 445, sell 1 units at price 112.629997, investment -5.480032 %, total balance 10005.489998,
# day 461: buy 1 units at price 124.919998, total balance 9880.570000
# day 466, sell 1 units at price 130.000000, investment 4.066604 %, total balance 10010.570000,
# day 475: buy 1 units at price 129.630005, total balance 9880.939995
# day 480, sell 1 units at price 132.059998, investment 1.874560 %, total balance 10012.999992,
# day 489: buy 1 units at price 134.179993, total balance 9878.820000
# day 499, sell 1 units at price 139.039993, investment 3.622001 %, total balance 10017.859993,
# day 509: buy 1 units at price 136.070007, total balance 9881.789986
# day 520, sell 1 units at price 134.429993, investment -1.205273 %, total balance 10016.219978,

# %%
close = df['Close']
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig('output/'+name+'.png')
plt.show()

# %% [markdown]
# ### 3.4. POLICY GRADIENT AGENT

# %% [markdown]
# Reinforcement learning (RL) is an area of machine learning concerned with how software agents ought to take actions in an environment in order to maximize some notion of cumulative reward. Reinforcement learning is one of three basic machine learning paradigms, alongside supervised learning and unsupervised learning.
#
# Reinforcement learning differs from supervised learning in not needing labelled input/output pairs be presented, and in not needing sub-optimal actions to be explicitly corrected. Instead the focus is on finding a balance between exploration (of uncharted territory) and exploitation (of current knowledge).[1]
#
# The environment is typically stated in the form of a Markov decision process (MDP), because many reinforcement learning algorithms for this context utilize dynamic programming techniques.[2] The main difference between the classical dynamic programming methods and reinforcement learning algorithms is that the latter do not assume knowledge of an exact mathematical model of the MDP and they target large MDPs where exact methods become infeasible.
#
# Reinforcement learning, due to its generality, is studied in many other disciplines, such as game theory, control theory, operations research, information theory, simulation-based optimization, multi-agent systems, swarm intelligence, statistics and genetic algorithms. In the operations research and control literature, reinforcement learning is called approximate dynamic programming, or neuro-dynamic programming. The problems of interest in reinforcement learning have also been studied in the theory of optimal control, which is concerned mostly with the existence and characterization of optimal solutions, and algorithms for their exact computation, and less with learning or approximation, particularly in the absence of a mathematical model of the environment. In economics and game theory, reinforcement learning may be used to explain how equilibrium may arise under bounded rationality.
#
# A reinforcement learning agent interacts with its environment in discrete time steps. At each time t, the agent receives an observation {\displaystyle o_{t}}o_{t}, which typically includes the reward {\displaystyle r_{t}}r_{t}. It then chooses an action {\displaystyle a_{t}}a_{t} from the set of available actions, which is subsequently sent to the environment. The environment moves to a new state {\displaystyle s_{t+1}}s_{t+1} and the reward {\displaystyle r_{t+1}}r_{t+1} associated with the transition {\displaystyle (s_{t},a_{t},s_{t+1})}(s_{t},a_{t},s_{t+1}) is determined. The goal of a reinforcement learning agent is to collect as much reward as possible. The agent can (possibly randomly) choose any action as a function of the history.
#
# When the agent's performance is compared to that of an agent that acts optimally, the difference in performance gives rise to the notion of regret. In order to act near optimally, the agent must reason about the long term consequences of its actions (i.e., maximize future income), although the immediate reward associated with this might be negative.
#
# Thus, reinforcement learning is particularly well-suited to problems that include a long-term versus short-term reward trade-off. It has been applied successfully to various problems, including robot control, elevator scheduling, telecommunications, backgammon, checkers[3] and Go (AlphaGo).
#
# Two elements make reinforcement learning powerful: the use of samples to optimize performance and the use of function approximation to deal with large environments. Thanks to these two key components, reinforcement learning can be used in large environments in the following situations:
#
# A model of the environment is known, but an analytic solution is not available;
# Only a simulation model of the environment is given (the subject of simulation-based optimization);[4]
# The only way to collect information about the environment is to interact with it.
# The first two of these problems could be considered planning problems (since some form of model is available), while the last one could be considered to be a genuine learning problem. However, reinforcement learning converts both planning problems to machine learning problems.

# %%
import tensorflow as tf
df = df_full.copy()
name = 'Policy Gradient agent'
class Agent:

    LEARNING_RATE = 1e-4
    LAYER_SIZE = 256
    GAMMA = 0.9
    OUTPUT_SIZE = 3

    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.X = tf.placeholder(tf.float32, (None, self.state_size))
        self.REWARDS = tf.placeholder(tf.float32, (None))
        self.ACTIONS = tf.placeholder(tf.int32, (None))
        feed_forward = tf.layers.dense(self.X, self.LAYER_SIZE, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed_forward, self.OUTPUT_SIZE, activation = tf.nn.softmax)
        input_y = tf.one_hot(self.ACTIONS, self.OUTPUT_SIZE)
        loglike = tf.log((input_y * (input_y - self.logits) + (1 - input_y) * (input_y + self.logits)) + 1)
        rewards = tf.tile(tf.reshape(self.REWARDS, (-1,1)), [1, self.OUTPUT_SIZE])
        self.cost = -tf.reduce_mean(loglike * (rewards + 1)) 
        self.optimizer = tf.train.AdamOptimizer(learning_rate = self.LEARNING_RATE).minimize(self.cost)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def predict(self, inputs):
        return self.sess.run(self.logits, feed_dict={self.X:inputs})
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])
    
    def discount_rewards(self, r):
        discounted_r = np.zeros_like(r)
        running_add = 0
        for t in reversed(range(0, r.size)):
            running_add = running_add * self.GAMMA + r[t]
            discounted_r[t] = running_add
        return discounted_r
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.get_predicted_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            ep_history = []
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.get_predicted_action(state)
                next_state = self.get_state(t + 1)
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= close[t]
                
                elif action == 2 and len(inventory):
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                ep_history.append([state,action,starting_money,next_state])
                state = next_state
            ep_history = np.array(ep_history)
            ep_history[:,2] = self.discount_rewards(ep_history[:,2])
            cost, _ = self.sess.run([self.cost, self.optimizer], feed_dict={self.X:np.vstack(ep_history[:,0]),
                                                    self.REWARDS:ep_history[:,2],
                                                    self.ACTIONS:ep_history[:,1]})
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
agent = Agent(state_size = window_size,
             window_size = window_size,
             trend = close,
             skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-15-39377897c888>:20: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From D:\Program Files\Anaconda\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From D:\Program Files\Anaconda\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# epoch: 10, total rewards: 50.720024.3, cost: -29135.101562, total money: 10050.720024
# epoch: 20, total rewards: 113.790047.3, cost: -29581.496094, total money: 9424.340050
# epoch: 30, total rewards: 172.520050.3, cost: -29731.382812, total money: 8796.190063
# epoch: 40, total rewards: 158.660088.3, cost: -30183.273438, total money: 9195.290092
# epoch: 50, total rewards: 118.720078.3, cost: -30651.716797, total money: 9018.410080
# epoch: 60, total rewards: 99.800079.3, cost: -31165.875000, total money: 9000.620071
# epoch: 70, total rewards: 155.490112.3, cost: -31243.205078, total money: 8781.670105
# epoch: 80, total rewards: 195.580101.3, cost: -31308.941406, total money: 9094.840096
# epoch: 90, total rewards: 119.280067.3, cost: -31095.314453, total money: 8881.340065
# epoch: 100, total rewards: 141.910065.3, cost: -31736.324219, total money: 8905.290054
# epoch: 110, total rewards: 245.180069.3, cost: -30625.269531, total money: 8057.320084
# epoch: 120, total rewards: 128.140030.3, cost: -31153.304688, total money: 9304.290024
# epoch: 130, total rewards: 348.679985.3, cost: -30467.257812, total money: 8705.489998
# epoch: 140, total rewards: 198.260017.3, cost: -31043.013672, total money: 9098.580009
# epoch: 150, total rewards: 459.200020.3, cost: -29341.984375, total money: 7771.320045
# epoch: 160, total rewards: 398.699966.3, cost: -31490.945312, total money: 8358.089981
# epoch: 170, total rewards: 465.560005.3, cost: -27688.316406, total money: 5616.830002
# epoch: 180, total rewards: 103.900017.3, cost: -32998.632812, total money: 9142.850014
# epoch: 190, total rewards: 204.430031.3, cost: -33193.453125, total money: 9101.490028
# epoch: 200, total rewards: 422.550011.3, cost: -31376.169922, total money: 7089.630035

# %%
close = df['Close']
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig('output/'+name+'.png')
plt.show()

# %% [markdown]
# ### 3.5. Q-LEARNING AGENT

# %% [markdown]
# Q-learning is a model-free reinforcement learning algorithm. The goal of Q-learning is to learn a policy, which tells an agent what action to take under what circumstances. It does not require a model (hence the connotation "model-free") of the environment, and it can handle problems with stochastic transitions and rewards, without requiring adaptations.
#
# For any finite Markov decision process (FMDP), Q-learning finds a policy that is optimal in the sense that it maximizes the expected value of the total reward over any and all successive steps, starting from the current state.[1] Q-learning can identify an optimal action-selection policy for any given FMDP, given infinite exploration time and a partly-random policy.[1] "Q" names the function that returns the reward used to provide the reinforcement and can be said to stand for the "quality" of an action taken in a given state.[2]

# %%
## Q-learning agent

from collections import deque
import random

df= df_full.copy()
name = 'Q-learning agent'

class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []

        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999

        tf.reset_default_graph()
        self.sess = tf.InteractiveSession()
        self.X = tf.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.placeholder(tf.float32, [None, self.action_size])
        feed = tf.layers.dense(self.X, 256, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed, self.action_size)
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.global_variables_initializer())

    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0]
        )
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest, 
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip, 
              batch_size = batch_size)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)

states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# D:\Program Files\Anaconda\lib\site-packages\tensorflow\python\client\session.py:1702: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch: 10, total rewards: 75.739990.3, cost: 0.237624, total money: 6743.019989
# epoch: 20, total rewards: 185.269966.3, cost: 0.169282, total money: 7397.259979
# epoch: 30, total rewards: 147.589928.3, cost: 0.140812, total money: 7217.159935
# epoch: 40, total rewards: 192.569939.3, cost: 0.106395, total money: 7714.919952
# epoch: 50, total rewards: 209.229950.3, cost: 0.094566, total money: 7505.389961
# epoch: 60, total rewards: 232.409950.3, cost: 0.098230, total money: 7528.569962
# epoch: 70, total rewards: 207.709953.3, cost: 0.072610, total money: 7712.799965
# epoch: 80, total rewards: 198.529938.3, cost: 0.054993, total money: 9106.829956
# epoch: 90, total rewards: 224.409958.3, cost: 0.054428, total money: 8873.629974
# epoch: 100, total rewards: 197.459961.3, cost: 0.051338, total money: 8976.599976
# epoch: 110, total rewards: 159.779968.3, cost: 0.048106, total money: 9200.139984
# epoch: 120, total rewards: 145.129982.3, cost: 0.045219, total money: 9595.889977
# epoch: 130, total rewards: 11.629982.3, cost: 0.047144, total money: 9599.969978
# epoch: 140, total rewards: 81.610001.3, cost: 0.041777, total money: 9945.729996
# epoch: 150, total rewards: 110.799973.3, cost: 0.041516, total money: 9836.579971
# epoch: 160, total rewards: 26.139977.3, cost: 0.042667, total money: 10026.139977
# epoch: 170, total rewards: 37.989975.3, cost: 0.041620, total money: 10037.989975
# epoch: 180, total rewards: 12.209976.3, cost: 0.040899, total money: 10012.209976
# epoch: 190, total rewards: 9.949989.3, cost: 0.039966, total money: 10009.949989
# epoch: 200, total rewards: 23.879982.3, cost: 0.039075, total money: 10023.879982
# day 3: buy 1 unit at price 108.339996, total balance 9891.660004
# day 4: buy 1 unit at price 108.500000, total balance 9783.160004
# day 5: buy 1 unit at price 109.050003, total balance 9674.110001
# day 9: buy 1 unit at price 112.269997, total balance 9561.840004
# day 11: buy 1 unit at price 113.260002, total balance 9448.580002
# day 14, sell 1 unit at price 114.209999, investment 5.418131 %, total balance 9562.790001,
# day 15: buy 1 unit at price 115.669998, total balance 9447.120003
# day 18: buy 1 unit at price 116.199997, total balance 9330.920006
# day 21: buy 1 unit at price 116.870003, total balance 9214.050003
# day 23: buy 1 unit at price 108.800003, total balance 9105.250000
# day 25, sell 1 unit at price 112.870003, investment 4.027652 %, total balance 9218.120003,
# day 26: buy 1 unit at price 107.879997, total balance 9110.240005
# day 27: buy 1 unit at price 110.040001, total balance 9000.200005
# day 33, sell 1 unit at price 114.709999, investment 5.190276 %, total balance 9114.910004,
# day 34, sell 1 unit at price 115.190002, investment 2.600878 %, total balance 9230.100006,
# day 36, sell 1 unit at price 117.309998, investment 3.575839 %, total balance 9347.410004,
# day 37, sell 1 unit at price 118.769997, investment 2.680037 %, total balance 9466.180000,
# day 38, sell 1 unit at price 117.360001, investment 0.998282 %, total balance 9583.540001,
# day 40, sell 1 unit at price 113.430000, investment -2.943443 %, total balance 9696.970001,
# day 42, sell 1 unit at price 115.059998, investment 5.753671 %, total balance 9812.029999,
# day 43, sell 1 unit at price 115.160004, investment 6.748245 %, total balance 9927.190002,
# day 44, sell 1 unit at price 114.730003, investment 4.262089 %, total balance 10041.920006,
# day 47: buy 1 unit at price 117.660004, total balance 9924.260002
# day 48: buy 1 unit at price 116.250000, total balance 9808.010002
# day 49: buy 1 unit at price 114.949997, total balance 9693.060005
# day 50, sell 1 unit at price 115.239998, investment -2.056779 %, total balance 9808.300003,
# day 51: buy 1 unit at price 115.440002, total balance 9692.860001
# day 52, sell 1 unit at price 114.529999, investment -1.479571 %, total balance 9807.389999,
# day 53, sell 1 unit at price 114.639999, investment -0.269680 %, total balance 9922.029999,
# day 54, sell 1 unit at price 114.739998, investment -0.606380 %, total balance 10036.769997,
# day 55: buy 1 unit at price 109.949997, total balance 9926.820000
# day 56: buy 1 unit at price 107.010002, total balance 9819.809998
# day 58: buy 1 unit at price 108.169998, total balance 9711.639999
# day 59, sell 1 unit at price 108.000000, investment -1.773531 %, total balance 9819.639999,
# day 62: buy 1 unit at price 109.330002, total balance 9710.309998
# day 63: buy 1 unit at price 110.989998, total balance 9599.320000
# day 65, sell 1 unit at price 109.089996, investment 1.943738 %, total balance 9708.409996,
# day 66, sell 1 unit at price 110.400002, investment 2.061573 %, total balance 9818.809998,
# day 67, sell 1 unit at price 112.510002, investment 2.908625 %, total balance 9931.320000,
# day 68, sell 1 unit at price 110.620003, investment -0.333359 %, total balance 10041.940002,
# day 73: buy 1 unit at price 109.320000, total balance 9932.620003
# day 74, sell 1 unit at price 111.720001, investment 2.195391 %, total balance 10044.340004,
# day 80: buy 1 unit at price 109.400002, total balance 9934.940002
# day 81, sell 1 unit at price 108.779999, investment -0.566730 %, total balance 10043.720001,
# day 90: buy 1 unit at price 113.860001, total balance 9929.860001
# day 91: buy 1 unit at price 113.900002, total balance 9815.959999
# day 92, sell 1 unit at price 113.029999, investment -0.728967 %, total balance 9928.989998,
# day 93: buy 1 unit at price 113.339996, total balance 9815.650002
# day 94, sell 1 unit at price 112.959999, investment -0.825287 %, total balance 9928.610001,
# day 95: buy 1 unit at price 111.129997, total balance 9817.480003
# day 96: buy 1 unit at price 112.150002, total balance 9705.330002
# day 97, sell 1 unit at price 113.010002, investment -0.291154 %, total balance 9818.340004,
# day 104, sell 1 unit at price 108.400002, investment -2.456579 %, total balance 9926.740005,
# day 105: buy 1 unit at price 108.449997, total balance 9818.290009
# day 106, sell 1 unit at price 107.839996, investment -3.843072 %, total balance 9926.130005,
# day 107: buy 1 unit at price 110.360001, total balance 9815.770004
# day 108: buy 1 unit at price 110.800003, total balance 9704.970001
# day 109, sell 1 unit at price 111.110001, investment 2.452747 %, total balance 9816.080002,
# day 110: buy 1 unit at price 110.830002, total balance 9705.250000
# day 112, sell 1 unit at price 109.970001, investment -0.353388 %, total balance 9815.220001,
# day 113, sell 1 unit at price 108.029999, investment -2.500004 %, total balance 9923.250000,
# day 115, sell 1 unit at price 108.180000, investment -2.391051 %, total balance 10031.430000,
# day 119: buy 1 unit at price 105.750000, total balance 9925.680000
# day 121, sell 1 unit at price 104.860001, investment -0.841607 %, total balance 10030.540001,
# day 123: buy 1 unit at price 104.930000, total balance 9925.610001
# day 124: buy 1 unit at price 104.199997, total balance 9821.410004
# day 125, sell 1 unit at price 105.080002, investment 0.142954 %, total balance 9926.490005,
# day 126: buy 1 unit at price 103.610001, total balance 9822.880005
# day 127, sell 1 unit at price 103.720001, investment -0.460649 %, total balance 9926.600006,
# day 128, sell 1 unit at price 104.059998, investment 0.434318 %, total balance 10030.660004,
# day 131: buy 1 unit at price 106.389999, total balance 9924.270004
# day 132, sell 1 unit at price 106.849998, investment 0.432371 %, total balance 10031.120003,
# day 134: buy 1 unit at price 110.580002, total balance 9920.540001
# day 135, sell 1 unit at price 110.500000, investment -0.072347 %, total balance 10031.040001,
# day 137: buy 1 unit at price 109.889999, total balance 9921.150002
# day 141: buy 1 unit at price 115.180000, total balance 9805.970001
# day 142, sell 1 unit at price 114.849998, investment 4.513604 %, total balance 9920.820000,
# day 144, sell 1 unit at price 116.730003, investment 1.345722 %, total balance 10037.550003,
# day 147: buy 1 unit at price 116.150002, total balance 9921.400002
# day 148, sell 1 unit at price 117.089996, investment 0.809294 %, total balance 10038.489998,
# day 150: buy 1 unit at price 117.550003, total balance 9920.939995
# day 151: buy 1 unit at price 117.790001, total balance 9803.149994
# day 156, sell 1 unit at price 113.699997, investment -3.275207 %, total balance 9916.849991,
# day 157, sell 1 unit at price 114.769997, investment -2.563888 %, total balance 10031.619987,
# day 163: buy 1 unit at price 114.680000, total balance 9916.939987
# day 164, sell 1 unit at price 116.709999, investment 1.770142 %, total balance 10033.649986,
# day 166: buy 1 unit at price 115.760002, total balance 9917.889984
# day 169, sell 1 unit at price 115.150002, investment -0.526953 %, total balance 10033.039986,
# day 170: buy 1 unit at price 114.589996, total balance 9918.449989
# day 171, sell 1 unit at price 114.099998, investment -0.427610 %, total balance 10032.549988,
# day 177: buy 1 unit at price 113.500000, total balance 9919.049988
# day 179: buy 1 unit at price 114.300003, total balance 9804.749985
# day 180, sell 1 unit at price 117.620003, investment 3.629958 %, total balance 9922.369987,
# day 181, sell 1 unit at price 118.629997, investment 3.788271 %, total balance 10040.999985,
# day 182: buy 1 unit at price 117.849998, total balance 9923.149986
# day 183: buy 1 unit at price 116.720001, total balance 9806.429985
# day 184: buy 1 unit at price 116.389999, total balance 9690.039986
# day 185, sell 1 unit at price 115.019997, investment -2.401359 %, total balance 9805.059982,
# day 186, sell 1 unit at price 114.519997, investment -1.884857 %, total balance 9919.579979,
# day 187: buy 1 unit at price 112.839996, total balance 9806.739983
# day 188, sell 1 unit at price 113.500000, investment -2.483031 %, total balance 9920.239983,
# day 190, sell 1 unit at price 115.040001, investment 1.949667 %, total balance 10035.279984,
# day 195: buy 1 unit at price 111.470001, total balance 9923.809982
# day 196: buy 1 unit at price 108.129997, total balance 9815.679985
# day 197, sell 1 unit at price 106.949997, investment -4.054906 %, total balance 9922.629982,
# day 198, sell 1 unit at price 106.339996, investment -1.655416 %, total balance 10028.969978,
# day 202: buy 1 unit at price 107.910004, total balance 9921.059975
# day 203, sell 1 unit at price 106.360001, investment -1.436385 %, total balance 10027.419975,
# day 211: buy 1 unit at price 108.980003, total balance 9918.439972
# day 212, sell 1 unit at price 108.379997, investment -0.550565 %, total balance 10026.819969,
# day 213: buy 1 unit at price 109.089996, total balance 9917.729973
# day 214, sell 1 unit at price 109.599998, investment 0.467506 %, total balance 10027.329971,
# day 217: buy 1 unit at price 111.290001, total balance 9916.039970
# day 218: buy 1 unit at price 108.949997, total balance 9807.089973
# day 219: buy 1 unit at price 109.589996, total balance 9697.499977
# day 220: buy 1 unit at price 107.330002, total balance 9590.169975
# day 221, sell 1 unit at price 110.070000, investment -1.096236 %, total balance 9700.239975,
# day 222, sell 1 unit at price 109.989998, investment 0.954567 %, total balance 9810.229973,
# day 223, sell 1 unit at price 110.830002, investment 1.131495 %, total balance 9921.059975,
# day 224: buy 1 unit at price 108.449997, total balance 9812.609978
# day 225, sell 1 unit at price 107.639999, investment 0.288827 %, total balance 9920.249977,
# day 226: buy 1 unit at price 106.650002, total balance 9813.599976
# day 227, sell 1 unit at price 109.260002, investment 0.746893 %, total balance 9922.859978,
# day 228: buy 1 unit at price 109.720001, total balance 9813.139977
# day 229, sell 1 unit at price 110.940002, investment 4.022504 %, total balance 9924.079979,
# day 230: buy 1 unit at price 110.059998, total balance 9814.019981
# day 231: buy 1 unit at price 111.190002, total balance 9702.829979
# day 232, sell 1 unit at price 112.239998, investment 2.296752 %, total balance 9815.069977,
# day 233: buy 1 unit at price 107.230003, total balance 9707.839973
# day 234, sell 1 unit at price 105.190002, investment -4.424855 %, total balance 9813.029976,
# day 235: buy 1 unit at price 103.290001, total balance 9709.739975
# day 237, sell 1 unit at price 100.370003, investment -9.731090 %, total balance 9810.109978,
# day 240, sell 1 unit at price 100.290001, investment -6.472071 %, total balance 9910.399979,
# day 243: buy 1 unit at price 97.290001, total balance 9813.109978
# day 244, sell 1 unit at price 96.449997, investment -6.622136 %, total balance 9909.559975,
# day 245: buy 1 unit at price 94.169998, total balance 9815.389977
# day 246, sell 1 unit at price 92.139999, investment -5.293454 %, total balance 9907.529976,
# day 247, sell 1 unit at price 95.959999, investment 1.900819 %, total balance 10003.489975,
# day 248: buy 1 unit at price 97.040001, total balance 9906.449974
# day 249, sell 1 unit at price 96.830002, investment -0.216405 %, total balance 10003.279976,
# day 250: buy 1 unit at price 97.620003, total balance 9905.659973
# day 251, sell 1 unit at price 99.309998, investment 1.731197 %, total balance 10004.969971,
# day 258: buy 1 unit at price 99.910004, total balance 9905.059967
# day 259: buy 1 unit at price 100.940002, total balance 9804.119965
# day 260, sell 1 unit at price 101.680000, investment 1.771591 %, total balance 9905.799965,
# day 261, sell 1 unit at price 102.500000, investment 1.545470 %, total balance 10008.299965,
# day 266: buy 1 unit at price 102.739998, total balance 9905.559967
# day 269: buy 1 unit at price 104.169998, total balance 9801.389969
# day 270, sell 1 unit at price 104.410004, investment 1.625468 %, total balance 9905.799973,
# day 272, sell 1 unit at price 103.879997, investment -0.278392 %, total balance 10009.679970,
# day 288: buy 1 unit at price 105.290001, total balance 9904.389969
# day 289: buy 1 unit at price 105.160004, total balance 9799.229965
# day 291, sell 1 unit at price 104.430000, investment -0.816792 %, total balance 9903.659966,
# day 292, sell 1 unit at price 104.190002, investment -0.922405 %, total balance 10007.849968,
# day 298: buy 1 unit at price 104.040001, total balance 9903.809967
# day 299, sell 1 unit at price 104.389999, investment 0.336408 %, total balance 10008.199966,
# day 304: buy 1 unit at price 104.519997, total balance 9903.679970
# day 305, sell 1 unit at price 102.870003, investment -1.578639 %, total balance 10006.549973,
# day 313: buy 1 unit at price 105.139999, total balance 9901.409973
# day 315, sell 1 unit at price 105.559998, investment 0.399466 %, total balance 10006.969971,
# day 316: buy 1 unit at price 105.309998, total balance 9901.659973
# day 317, sell 1 unit at price 105.650002, investment 0.322860 %, total balance 10007.309975,
# day 318: buy 1 unit at price 104.870003, total balance 9902.439972
# day 319, sell 1 unit at price 105.339996, investment 0.448168 %, total balance 10007.779968,
# day 328: buy 1 unit at price 113.550003, total balance 9894.229965
# day 330: buy 1 unit at price 114.470001, total balance 9779.759964
# day 331, sell 1 unit at price 116.120003, investment 2.263320 %, total balance 9895.879967,
# day 333, sell 1 unit at price 115.160004, investment 0.602780 %, total balance 10011.039970,
# day 337: buy 1 unit at price 113.209999, total balance 9897.829971
# day 341: buy 1 unit at price 109.449997, total balance 9788.379974
# day 343: buy 1 unit at price 109.900002, total balance 9678.479973
# day 347: buy 1 unit at price 111.730003, total balance 9566.749969
# day 351: buy 1 unit at price 108.519997, total balance 9458.229973
# day 352, sell 1 unit at price 108.220001, investment -4.407736 %, total balance 9566.449974,
# day 353: buy 1 unit at price 107.059998, total balance 9459.389977
# day 354, sell 1 unit at price 105.959999, investment -3.188669 %, total balance 9565.349976,
# day 355: buy 1 unit at price 106.459999, total balance 9458.889977
# day 356, sell 1 unit at price 109.739998, investment -0.145590 %, total balance 9568.629974,
# day 359: buy 1 unit at price 109.160004, total balance 9459.469971
# day 361, sell 1 unit at price 110.680000, investment -0.939768 %, total balance 9570.149971,
# day 362: buy 1 unit at price 109.269997, total balance 9460.879974
# day 363, sell 1 unit at price 109.540001, investment 0.939923 %, total balance 9570.419975,
# day 364, sell 1 unit at price 109.820000, investment 2.577996 %, total balance 9680.239975,
# day 365, sell 1 unit at price 109.220001, investment 2.592525 %, total balance 9789.459976,
# day 366: buy 1 unit at price 110.709999, total balance 9678.749977
# day 369, sell 1 unit at price 109.440002, investment 0.256503 %, total balance 9788.189980,
# day 372, sell 1 unit at price 108.480003, investment -0.722974 %, total balance 9896.669983,
# day 373: buy 1 unit at price 108.839996, total balance 9787.829987
# day 375, sell 1 unit at price 113.680000, investment 2.682686 %, total balance 9901.509987,
# day 376, sell 1 unit at price 113.800003, investment 4.557154 %, total balance 10015.309990,
# day 377: buy 1 unit at price 112.820000, total balance 9902.489990
# day 378, sell 1 unit at price 113.489998, investment 0.593865 %, total balance 10015.979988,
# day 383: buy 1 unit at price 115.300003, total balance 9900.679985
# day 385, sell 1 unit at price 115.120003, investment -0.156115 %, total balance 10015.799988,
# day 386: buy 1 unit at price 113.989998, total balance 9901.809990
# day 390: buy 1 unit at price 116.360001, total balance 9785.449989
# day 391: buy 1 unit at price 116.830002, total balance 9668.619987
# day 392: buy 1 unit at price 115.709999, total balance 9552.909988
# day 394: buy 1 unit at price 115.849998, total balance 9437.059990
# day 395, sell 1 unit at price 115.589996, investment 1.403631 %, total balance 9552.649986,
# day 397: buy 1 unit at price 112.940002, total balance 9439.709984
# day 398: buy 1 unit at price 112.930000, total balance 9326.779984
# day 400, sell 1 unit at price 110.430000, investment -5.096253 %, total balance 9437.209984,
# day 401: buy 1 unit at price 108.029999, total balance 9329.179985
# day 402, sell 1 unit at price 109.860001, investment -5.965934 %, total balance 9439.039986,
# day 405: buy 1 unit at price 109.339996, total balance 9329.699989
# day 406, sell 1 unit at price 104.800003, investment -9.428741 %, total balance 9434.499992,
# day 408, sell 1 unit at price 107.720001, investment -7.017693 %, total balance 9542.219994,
# day 409: buy 1 unit at price 108.690002, total balance 9433.529991
# day 410, sell 1 unit at price 107.309998, investment -4.984952 %, total balance 9540.839989,
# day 411, sell 1 unit at price 107.610001, investment -4.710883 %, total balance 9648.449989,
# day 412, sell 1 unit at price 108.720001, investment 0.638714 %, total balance 9757.169991,
# day 413: buy 1 unit at price 106.019997, total balance 9651.149994
# day 414: buy 1 unit at price 106.870003, total balance 9544.279991
# day 415, sell 1 unit at price 105.739998, investment -3.292481 %, total balance 9650.019989,
# day 417, sell 1 unit at price 109.220001, investment 0.487624 %, total balance 9759.239990,
# day 418, sell 1 unit at price 109.860001, investment 3.621962 %, total balance 9869.099991,
# day 419, sell 1 unit at price 108.559998, investment 1.581356 %, total balance 9977.659988,
# day 421: buy 1 unit at price 112.370003, total balance 9865.289986
# day 422: buy 1 unit at price 112.610001, total balance 9752.679985
# day 423, sell 1 unit at price 115.400002, investment 2.696448 %, total balance 9868.079987,
# day 424, sell 1 unit at price 116.870003, investment 3.782970 %, total balance 9984.949989,
# day 425: buy 1 unit at price 117.190002, total balance 9867.759987
# day 426, sell 1 unit at price 117.910004, investment 0.614388 %, total balance 9985.669991,
# day 429: buy 1 unit at price 118.570000, total balance 9867.099991
# day 430, sell 1 unit at price 119.760002, investment 1.003629 %, total balance 9986.859993,
# day 431: buy 1 unit at price 119.379997, total balance 9867.479996
# day 433, sell 1 unit at price 118.879997, investment -0.418831 %, total balance 9986.359993,
# day 438: buy 1 unit at price 117.690002, total balance 9868.669991
# day 439, sell 1 unit at price 115.550003, investment -1.818336 %, total balance 9984.219994,
# day 444: buy 1 unit at price 111.820000, total balance 9872.399994
# day 446, sell 1 unit at price 114.209999, investment 2.137363 %, total balance 9986.609993,
# day 450: buy 1 unit at price 119.680000, total balance 9866.929993
# day 451, sell 1 unit at price 120.349998, investment 0.559825 %, total balance 9987.279991,
# day 452: buy 1 unit at price 120.559998, total balance 9866.719994
# day 453: buy 1 unit at price 123.550003, total balance 9743.169991
# day 454, sell 1 unit at price 124.790001, investment 3.508629 %, total balance 9867.959991,
# day 455, sell 1 unit at price 125.120003, investment 1.270740 %, total balance 9993.079994,
# day 456: buy 1 unit at price 125.029999, total balance 9868.049995
# day 457: buy 1 unit at price 126.029999, total balance 9742.019997
# day 458: buy 1 unit at price 126.510002, total balance 9615.509995
# day 459: buy 1 unit at price 126.430000, total balance 9489.079994
# day 461, sell 1 unit at price 124.919998, investment -0.087979 %, total balance 9613.999992,
# day 465: buy 1 unit at price 129.300003, total balance 9484.699989
# day 468: buy 1 unit at price 129.919998, total balance 9354.779991
# day 469: buy 1 unit at price 129.160004, total balance 9225.619987
# day 472, sell 1 unit at price 129.529999, investment 2.777117 %, total balance 9355.149986,
# day 480: buy 1 unit at price 132.059998, total balance 9223.089989
# day 483, sell 1 unit at price 129.779999, investment 2.584773 %, total balance 9352.869987,
# day 484, sell 1 unit at price 132.339996, investment 4.674520 %, total balance 9485.209984,
# day 485, sell 1 unit at price 133.059998, investment 2.907962 %, total balance 9618.269981,
# day 486, sell 1 unit at price 135.039993, investment 3.940883 %, total balance 9753.309975,
# day 489: buy 1 unit at price 134.179993, total balance 9619.129982
# day 492, sell 1 unit at price 137.339996, investment 6.333224 %, total balance 9756.469978,
# day 493: buy 1 unit at price 138.179993, total balance 9618.289986
# day 494: buy 1 unit at price 138.039993, total balance 9480.249992
# day 498: buy 1 unit at price 137.580002, total balance 9342.669991
# day 500, sell 1 unit at price 139.139999, investment 5.361201 %, total balance 9481.809990,
# day 504: buy 1 unit at price 138.339996, total balance 9343.469994
# day 506: buy 1 unit at price 135.880005, total balance 9207.589989
# day 507, sell 1 unit at price 136.940002, investment 2.056946 %, total balance 9344.529991,
# day 509, sell 1 unit at price 136.070007, investment -1.526983 %, total balance 9480.599998,
# day 510, sell 1 unit at price 137.199997, investment -0.608517 %, total balance 9617.799995,
# day 515, sell 1 unit at price 136.839996, investment -0.537873 %, total balance 9754.639992,
# day 520, sell 1 unit at price 134.429993, investment -2.826373 %, total balance 9889.069984,
# day 521, sell 1 unit at price 134.229996, investment -1.214313 %, total balance 10023.299980,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig('output/'+name+'.png')
plt.show()

# %% [markdown]
# ### 3.6 DOUBLE Q-LEARNING

# %% [markdown]
# Because the future maximum approximated action value in Q-learning is evaluated using the same Q function as in current action selection policy, in noisy environments Q-learning can sometimes overestimate the action values, slowing the learning. A variant called Double Q-learning was proposed to correct this. Double Q-learning[18] is an off-policy reinforcement learning algorithm, where a different policy is used for value evaluation than what is used to select the next action.
#
# In practice, two separate value functions are trained in a mutually symmetric fashion using separate experiences, {\displaystyle Q^{A}}{\displaystyle Q^{A}} and {\displaystyle Q^{B}}{\displaystyle Q^{B}}. The double Q-learning update step is then as follows:
#
# Now the estimated value of the discounted future is evaluated using a different policy, which solves the overestimation issue.
#
# This algorithm was later modified[clarification needed] in 2015 and combined with deep learning, as in the DQN algorithm, resulting in Double DQN, which outperforms the original DQN algorithm.[19]

# %%
## Double Q-learning agent

from collections import deque
import random

df= df_full.copy()
name = 'Double Q-learning agent'

class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate):
        self.X = tf.placeholder(tf.float32, (None, input_size))
        self.Y = tf.placeholder(tf.float32, (None, output_size))
        feed_forward = tf.layers.dense(self.X, layer_size, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed_forward, output_size)
        self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        self.trainable = tf.trainable_variables()
    
    def _assign(self):
        for i in range(len(self.trainable)//2):
            assign_op = self.trainable[i+len(self.trainable)//2].assign(self.trainable[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.predict(states)
        Q_new = self.predict(new_states)
        Q_new_negative = self.sess.run(self.model_negative.logits, feed_dict={self.model_negative.X:new_states})
        replay_size = len(replay)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, done_r = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not done_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
        return X, Y

    def predict(self, inputs):
        return self.sess.run(self.model.logits, feed_dict={self.model.X:inputs})
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign()
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                state = next_state
                X, Y = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.model.cost, self.model.optimizer], 
                                        feed_dict={self.model.X: X, self.model.Y:Y})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)

states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# D:\Program Files\Anaconda\lib\site-packages\tensorflow\python\client\session.py:1702: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch: 10, total rewards: 4.599983.3, cost: 0.005204, total money: 9736.949989
# epoch: 20, total rewards: -56.069916.3, cost: 0.014505, total money: 9402.850098
# epoch: 30, total rewards: 235.609970.3, cost: 0.010728, total money: 10235.609970
# epoch: 40, total rewards: 8.649979.3, cost: 0.016125, total money: 9737.689987
# epoch: 50, total rewards: 22.300034.3, cost: 0.017268, total money: 9618.400040
# epoch: 60, total rewards: 119.530006.3, cost: 0.007319, total money: 9981.940010
# epoch: 70, total rewards: -9.849960.3, cost: 0.006085, total money: 9720.630051
# epoch: 80, total rewards: 39.980011.3, cost: 0.002432, total money: 10039.980011
# epoch: 90, total rewards: 2.020042.3, cost: 0.002051, total money: 9869.660042
# epoch: 100, total rewards: 73.299965.3, cost: 0.002800, total money: 10073.299965
# epoch: 110, total rewards: 29.409958.3, cost: 0.001626, total money: 10029.409958
# epoch: 120, total rewards: -17.370003.3, cost: 0.003486, total money: 9847.340004
# epoch: 130, total rewards: -3.329994.3, cost: 0.001297, total money: 9996.670006
# epoch: 140, total rewards: 56.489990.3, cost: 0.010525, total money: 10056.489990
# epoch: 150, total rewards: -2.639977.3, cost: 0.003192, total money: 9997.360023
# epoch: 160, total rewards: 10.829964.3, cost: 0.000813, total money: 9873.239967
# epoch: 170, total rewards: 12.779968.3, cost: 0.000382, total money: 10012.779968
# epoch: 180, total rewards: 11.880005.3, cost: 0.000632, total money: 9876.590012
# epoch: 190, total rewards: -23.429993.3, cost: 0.000783, total money: 9976.570007
# epoch: 200, total rewards: 19.860046.3, cost: 0.000936, total money: 10019.860046
# day 0: buy 1 unit at price 107.949997, total balance 9892.050003
# day 3: buy 1 unit at price 108.339996, total balance 9783.710007
# day 4, sell 1 unit at price 108.500000, investment 0.509498 %, total balance 9892.210007,
# day 5, sell 1 unit at price 109.050003, investment 0.655351 %, total balance 10001.260010,
# day 13: buy 1 unit at price 114.330002, total balance 9886.930008
# day 14, sell 1 unit at price 114.209999, investment -0.104962 %, total balance 10001.140007,
# day 19: buy 1 unit at price 115.110001, total balance 9886.030006
# day 20, sell 1 unit at price 115.669998, investment 0.486489 %, total balance 10001.700005,
# day 24: buy 1 unit at price 112.110001, total balance 9889.590004
# day 25: buy 1 unit at price 112.870003, total balance 9776.720001
# day 26, sell 1 unit at price 107.879997, investment -3.773083 %, total balance 9884.599998,
# day 27, sell 1 unit at price 110.040001, investment -2.507311 %, total balance 9994.639999,
# day 28: buy 1 unit at price 111.739998, total balance 9882.900002
# day 29, sell 1 unit at price 112.430000, investment 0.617507 %, total balance 9995.330002,
# day 44: buy 1 unit at price 114.730003, total balance 9880.599998
# day 45: buy 1 unit at price 114.739998, total balance 9765.860001
# day 46: buy 1 unit at price 118.040001, total balance 9647.820000
# day 47, sell 1 unit at price 117.660004, investment 2.553822 %, total balance 9765.480003,
# day 49, sell 1 unit at price 114.949997, investment 0.183022 %, total balance 9880.430000,
# day 50, sell 1 unit at price 115.239998, investment -2.372080 %, total balance 9995.669998,
# day 54: buy 1 unit at price 114.739998, total balance 9880.930000
# day 55, sell 1 unit at price 109.949997, investment -4.174657 %, total balance 9990.879997,
# day 75: buy 1 unit at price 111.470001, total balance 9879.409996
# day 77, sell 1 unit at price 110.410004, investment -0.950926 %, total balance 9989.820000,
# day 82: buy 1 unit at price 108.779999, total balance 9881.040001
# day 83, sell 1 unit at price 107.919998, investment -0.790587 %, total balance 9988.959999,
# day 91: buy 1 unit at price 113.900002, total balance 9875.059998
# day 92, sell 1 unit at price 113.029999, investment -0.763830 %, total balance 9988.089996,
# day 99: buy 1 unit at price 111.230003, total balance 9876.859993
# day 100, sell 1 unit at price 110.660004, investment -0.512451 %, total balance 9987.519997,
# day 106: buy 1 unit at price 107.839996, total balance 9879.680000
# day 107: buy 1 unit at price 110.360001, total balance 9769.320000
# day 109, sell 1 unit at price 111.110001, investment 3.032274 %, total balance 9880.430000,
# day 110, sell 1 unit at price 110.830002, investment 0.425880 %, total balance 9991.260002,
# day 122: buy 1 unit at price 103.239998, total balance 9888.020004
# day 123, sell 1 unit at price 104.930000, investment 1.636965 %, total balance 9992.950005,
# day 146: buy 1 unit at price 115.660004, total balance 9877.290001
# day 147, sell 1 unit at price 116.150002, investment 0.423654 %, total balance 9993.440002,
# day 172: buy 1 unit at price 114.320000, total balance 9879.120003
# day 174, sell 1 unit at price 114.430000, investment 0.096222 %, total balance 9993.550003,
# day 184: buy 1 unit at price 116.389999, total balance 9877.160004
# day 185, sell 1 unit at price 115.019997, investment -1.177079 %, total balance 9992.180000,
# day 187: buy 1 unit at price 112.839996, total balance 9879.340004
# day 188: buy 1 unit at price 113.500000, total balance 9765.840004
# day 189, sell 1 unit at price 113.970001, investment 1.001422 %, total balance 9879.810005,
# day 190, sell 1 unit at price 115.040001, investment 1.356829 %, total balance 9994.850006,
# day 198: buy 1 unit at price 106.339996, total balance 9888.510010
# day 199, sell 1 unit at price 108.620003, investment 2.144072 %, total balance 9997.130013,
# day 200: buy 1 unit at price 109.830002, total balance 9887.300011
# day 201, sell 1 unit at price 108.089996, investment -1.584272 %, total balance 9995.390007,
# day 212: buy 1 unit at price 108.379997, total balance 9887.010010
# day 214, sell 1 unit at price 109.599998, investment 1.125670 %, total balance 9996.610008,
# day 231: buy 1 unit at price 111.190002, total balance 9885.420006
# day 232, sell 1 unit at price 112.239998, investment 0.944325 %, total balance 9997.660004,
# day 240: buy 1 unit at price 100.290001, total balance 9897.370003
# day 241, sell 1 unit at price 99.010002, investment -1.276298 %, total balance 9996.380005,
# day 247: buy 1 unit at price 95.959999, total balance 9900.420006
# day 248, sell 1 unit at price 97.040001, investment 1.125471 %, total balance 9997.460007,
# day 252: buy 1 unit at price 97.110001, total balance 9900.350006
# day 254, sell 1 unit at price 100.760002, investment 3.758626 %, total balance 10001.110008,
# day 256: buy 1 unit at price 100.400002, total balance 9900.710007
# day 257, sell 1 unit at price 100.389999, investment -0.009962 %, total balance 10001.100006,
# day 260: buy 1 unit at price 101.680000, total balance 9899.420006
# day 261, sell 1 unit at price 102.500000, investment 0.806451 %, total balance 10001.920006,
# day 279: buy 1 unit at price 102.599998, total balance 9899.320007
# day 280, sell 1 unit at price 103.089996, investment 0.477581 %, total balance 10002.410004,
# day 287: buy 1 unit at price 106.099998, total balance 9896.310005
# day 289, sell 1 unit at price 105.160004, investment -0.885952 %, total balance 10001.470009,
# day 292: buy 1 unit at price 104.190002, total balance 9897.280006
# day 293: buy 1 unit at price 104.110001, total balance 9793.170006
# day 294, sell 1 unit at price 103.720001, investment -0.451100 %, total balance 9896.890007,
# day 295, sell 1 unit at price 102.970001, investment -1.094995 %, total balance 9999.860008,
# day 298: buy 1 unit at price 104.040001, total balance 9895.820007
# day 299, sell 1 unit at price 104.389999, investment 0.336408 %, total balance 10000.210007,
# day 312: buy 1 unit at price 104.639999, total balance 9895.570007
# day 313: buy 1 unit at price 105.139999, total balance 9790.430008
# day 314, sell 1 unit at price 105.349998, investment 0.678516 %, total balance 9895.780006,
# day 315: buy 1 unit at price 105.559998, total balance 9790.220009
# day 316, sell 1 unit at price 105.309998, investment 0.161687 %, total balance 9895.530006,
# day 318, sell 1 unit at price 104.870003, investment -0.653652 %, total balance 10000.400009,
# day 321: buy 1 unit at price 111.209999, total balance 9889.190010
# day 322, sell 1 unit at price 109.940002, investment -1.141981 %, total balance 9999.130013,
# day 325: buy 1 unit at price 113.459999, total balance 9885.670013
# day 326, sell 1 unit at price 113.599998, investment 0.123391 %, total balance 9999.270012,
# day 332: buy 1 unit at price 116.050003, total balance 9883.220009
# day 333, sell 1 unit at price 115.160004, investment -0.766910 %, total balance 9998.380013,
# day 337: buy 1 unit at price 113.209999, total balance 9885.170013
# day 338, sell 1 unit at price 112.610001, investment -0.529987 %, total balance 9997.780014,
# day 339: buy 1 unit at price 112.519997, total balance 9885.260017
# day 340, sell 1 unit at price 112.510002, investment -0.008882 %, total balance 9997.770020,
# day 346: buy 1 unit at price 111.349998, total balance 9886.420021
# day 347, sell 1 unit at price 111.730003, investment 0.341271 %, total balance 9998.150024,
# day 355: buy 1 unit at price 106.459999, total balance 9891.690025
# day 356: buy 1 unit at price 109.739998, total balance 9781.950027
# day 357, sell 1 unit at price 110.129997, investment 3.447302 %, total balance 9892.080025,
# day 358, sell 1 unit at price 110.370003, investment 0.574089 %, total balance 10002.450027,
# day 359: buy 1 unit at price 109.160004, total balance 9893.290024
# day 360: buy 1 unit at price 110.339996, total balance 9782.950027
# day 361, sell 1 unit at price 110.680000, investment 1.392448 %, total balance 9893.630028,
# day 363, sell 1 unit at price 109.540001, investment -0.725028 %, total balance 10003.170029,
# day 374: buy 1 unit at price 111.800003, total balance 9891.370026
# day 375, sell 1 unit at price 113.680000, investment 1.681572 %, total balance 10005.050026,
# day 376: buy 1 unit at price 113.800003, total balance 9891.250023
# day 378: buy 1 unit at price 113.489998, total balance 9777.760025
# day 379, sell 1 unit at price 112.870003, investment -0.817223 %, total balance 9890.630028,
# day 380, sell 1 unit at price 113.349998, investment -0.123358 %, total balance 10003.980026,
# day 388: buy 1 unit at price 113.540001, total balance 9890.440025
# day 389, sell 1 unit at price 114.269997, investment 0.642941 %, total balance 10004.710022,
# day 398: buy 1 unit at price 112.930000, total balance 9891.780022
# day 399, sell 1 unit at price 109.570000, investment -2.975295 %, total balance 10001.350021,
# day 417: buy 1 unit at price 109.220001, total balance 9892.130020
# day 418, sell 1 unit at price 109.860001, investment 0.585973 %, total balance 10001.990021,
# day 424: buy 1 unit at price 116.870003, total balance 9885.120018
# day 425, sell 1 unit at price 117.190002, investment 0.273808 %, total balance 10002.310020,
# day 439: buy 1 unit at price 115.550003, total balance 9886.760017
# day 440, sell 1 unit at price 113.250000, investment -1.990483 %, total balance 10000.010017,
# day 441: buy 1 unit at price 112.190002, total balance 9887.820015
# day 443, sell 1 unit at price 114.370003, investment 1.943132 %, total balance 10002.190018,
# day 446: buy 1 unit at price 114.209999, total balance 9887.980019
# day 447, sell 1 unit at price 116.139999, investment 1.689870 %, total balance 10004.120018,
# day 458: buy 1 unit at price 126.510002, total balance 9877.610016
# day 459, sell 1 unit at price 126.430000, investment -0.063238 %, total balance 10004.040016,
# day 461: buy 1 unit at price 124.919998, total balance 9879.120018
# day 462: buy 1 unit at price 127.800003, total balance 9751.320015
# day 463, sell 1 unit at price 128.820007, investment 3.122005 %, total balance 9880.140022,
# day 465: buy 1 unit at price 129.300003, total balance 9750.840019
# day 468, sell 1 unit at price 129.919998, investment 1.658838 %, total balance 9880.760017,
# day 469, sell 1 unit at price 129.160004, investment -0.108275 %, total balance 10009.920021,
# day 473: buy 1 unit at price 130.619995, total balance 9879.300026
# day 474, sell 1 unit at price 130.580002, investment -0.030618 %, total balance 10009.880028,
# day 480: buy 1 unit at price 132.059998, total balance 9877.820030
# day 482, sell 1 unit at price 131.470001, investment -0.446764 %, total balance 10009.290031,
# day 495: buy 1 unit at price 137.350006, total balance 9871.940025
# day 496, sell 1 unit at price 137.240005, investment -0.080088 %, total balance 10009.180031,
# day 518: buy 1 unit at price 133.149994, total balance 9876.030037
# day 519: buy 1 unit at price 132.029999, total balance 9744.000038
# day 520, sell 1 unit at price 134.429993, investment 0.961321 %, total balance 9878.430031,
# day 521, sell 1 unit at price 134.229996, investment 1.666286 %, total balance 10012.660027,
# day 525: buy 1 unit at price 135.289993, total balance 9877.370033
# day 526, sell 1 unit at price 137.589996, investment 1.700054 %, total balance 10014.960030,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig('output/'+name+'.png')
plt.show()

# %% [markdown]
# ### 3.7. RECURRENT Q LEARNING AGENT

# %% [markdown]
# In end-to-end reinforcement learning, the end-to-end process, in other words, the entire process from sensors to motors in a robot or agent involves a single, layered or recurrent neural network without modularization, and is trained by reinforcement learning (RL).[1] The approach has been proposed for a long time,[2] but was reenergized by the successful results in learning to play Atari video games (2013–15)[3][4][5][6] and AlphaGo (2016)[7] by Google DeepMind.
#
# RL traditionally required explicit design of state space and action space, while the mapping from state space to action space is learned.[8] Therefore, RL has been limited to learning only for action, and human designers have to design how to construct state space from sensor signals and to give how the motion commands are generated for each action before learning. Neural networks have been often used in RL, to provide non-linear function approximation to avoid the curse of dimensionality.[8] Recurrent neural networks have been also employed, mainly to avoid perceptual aliasing or partially observable Markov decision process (POMDP).[9][10][11][12][13]
#
# End-to-end RL extends RL from learning only for actions to learning the entire process from sensors to motors including higher-level functions that are difficult to develop independently from other functions. Higher-level functions do not connect directly with either sensors or motors, and so even giving their inputs and outputs is difficult.
#
# The approach originated in TD-Gammon (1992).[14] In backgammon, the evaluation of the game situation during self-play was learned through TD({\displaystyle \lambda }\lambda ) using a layered neural network. Four inputs were used for the number of pieces of a given color at a given location on the board, totaling 198 input signals. With zero knowledge built in, the network learned to play the game at an intermediate level.
#
# Shibata began working with this framework in 1997.[15][2] They employed Q-learning and actor-critic for continuous motion tasks,[16] and used a recurrent neural network for memory-required tasks.[17] They applied this framework to some real robot tasks.[16][18] They demonstrated learning of various functions.
#
# Beginning around 2013, Google DeepMind showed impressive learning results in video games[3][4] and game of Go (AlphaGo).[7] They used a deep convolutional neural network that showed superior results in image recognition. They used 4 frames of almost raw RGB pixels (84x84) as inputs. The network was trained based on RL with the reward representing the sign of the change in the game score. All 49 games were learned using the same network architecture and Q-learning with minimal prior knowledge, and outperformed competing methods on almost all the games and performed at a level that is comparable or superior to a professional human game tester.[4] It is sometimes called Deep-Q network (DQN). In AlphaGo, deep neural networks are trained not only by reinforcement learning, but also by supervised learning and Monte Carlo tree search.[7]

# %%
## Recurrent Q-learning agent

from collections import deque
import random

df= df_full.copy()
name = 'Recurrent Q-learning agent'
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.INITIAL_FEATURES = np.zeros((4, self.state_size))
        self.X = tf.placeholder(tf.float32, (None, None, self.state_size))
        self.Y = tf.placeholder(tf.float32, (None, self.OUTPUT_SIZE))
        cell = tf.nn.rnn_cell.LSTMCell(self.LAYER_SIZE, state_is_tuple = False)
        self.hidden_layer = tf.placeholder(tf.float32, (None, 2 * self.LAYER_SIZE))
        self.rnn,self.last_state = tf.nn.dynamic_rnn(inputs=self.X,cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
        self.logits = tf.layers.dense(self.rnn[:,-1], self.OUTPUT_SIZE)
        self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate = self.LEARNING_RATE).minimize(self.cost)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def _memorize(self, state, action, reward, new_state, dead, rnn_state):
        self.MEMORIES.append((state, action, reward, new_state, dead, rnn_state))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        init_values = np.array([a[-1] for a in replay])
        Q = self.sess.run(self.logits, feed_dict={self.X:states, self.hidden_layer:init_values})
        Q_new = self.sess.run(self.logits, feed_dict={self.X:new_states, self.hidden_layer:init_values})
        replay_size = len(replay)
        X = np.empty((replay_size, 4, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        INIT_VAL = np.empty((replay_size, 2 * self.LAYER_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, dead_r, rnn_memory = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not dead_r:
                target[action_r] += self.GAMMA * np.amax(Q_new[i])
            X[i] = state_r
            Y[i] = target
            INIT_VAL[i] = rnn_memory
        return X, Y, INIT_VAL
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        init_value = np.zeros((1, 2 * self.LAYER_SIZE))
        for k in range(self.INITIAL_FEATURES.shape[0]):
            self.INITIAL_FEATURES[k,:] = state
        for t in range(0, len(self.trend) - 1, self.skip):
            action, last_state = self.sess.run([self.logits,self.last_state],
                                                feed_dict={self.X:[self.INITIAL_FEATURES],
                                                            self.hidden_layer:init_value})
            action, init_value = np.argmax(action[0]), last_state
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
            self.INITIAL_FEATURES = new_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            init_value = np.zeros((1, 2 * self.LAYER_SIZE))
            for k in range(self.INITIAL_FEATURES.shape[0]):
                self.INITIAL_FEATURES[k,:] = state
            for t in range(0, len(self.trend) - 1, self.skip):
                
                if np.random.rand() < self.EPSILON:
                    action = np.random.randint(self.OUTPUT_SIZE)
                else:
                    action, last_state = self.sess.run([self.logits,
                                                  self.last_state],
                                                  feed_dict={self.X:[self.INITIAL_FEATURES],
                                                             self.hidden_layer:init_value})
                    action, init_value = np.argmax(action[0]), last_state
                    
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
                self._memorize(self.INITIAL_FEATURES, action, invest, new_state, 
                               starting_money < initial_money, init_value[0])
                self.INITIAL_FEATURES = new_state
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                X, Y, INIT_VAL = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.cost, self.optimizer], 
                                        feed_dict={self.X: X, self.Y:Y,
                                                  self.hidden_layer: INIT_VAL})
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
                
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 10, checkpoint = 10, initial_money = initial_money)

states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x000002748816CFD0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# D:\Program Files\Anaconda\lib\site-packages\tensorflow\python\client\session.py:1702: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch: 10, total rewards: 319.510002.3, cost: 0.015337, total money: 9107.040031
# day 27: buy 1 unit at price 110.040001, total balance 9889.959999
# day 30, sell 1 unit at price 115.029999, investment 4.534713 %, total balance 10004.989998,
# day 69: buy 1 unit at price 113.370003, total balance 9891.619995
# day 70, sell 1 unit at price 110.300003, investment -2.707947 %, total balance 10001.919998,
# day 107: buy 1 unit at price 110.360001, total balance 9891.559998
# day 109: buy 1 unit at price 111.110001, total balance 9780.449997
# day 111, sell 1 unit at price 110.190002, investment -0.154040 %, total balance 9890.639999,
# day 113, sell 1 unit at price 108.029999, investment -2.772029 %, total balance 9998.669998,
# day 155: buy 1 unit at price 114.650002, total balance 9884.019997
# day 157: buy 1 unit at price 114.769997, total balance 9769.250000
# day 159: buy 1 unit at price 114.620003, total balance 9654.629997
# day 166, sell 1 unit at price 115.760002, investment 0.968164 %, total balance 9770.389999,
# day 167, sell 1 unit at price 115.190002, investment 0.365954 %, total balance 9885.580002,
# day 168, sell 1 unit at price 114.580002, investment -0.034899 %, total balance 10000.160004,
# day 340: buy 1 unit at price 112.510002, total balance 9887.650002
# day 341, sell 1 unit at price 109.449997, investment -2.719763 %, total balance 9997.099998,
# day 409: buy 1 unit at price 108.690002, total balance 9888.409996
# day 410, sell 1 unit at price 107.309998, investment -1.269670 %, total balance 9995.719994,
# day 426: buy 1 unit at price 117.910004, total balance 9877.809990
# day 428, sell 1 unit at price 119.160004, investment 1.060131 %, total balance 9996.969994,
# day 437: buy 1 unit at price 117.720001, total balance 9879.249992
# day 438, sell 1 unit at price 117.690002, investment -0.025483 %, total balance 9996.939995,
# day 474: buy 1 unit at price 130.580002, total balance 9866.359993
# day 485, sell 1 unit at price 133.059998, investment 1.899216 %, total balance 9999.419991,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig('output/'+name+'.png')
plt.show()

# %% [markdown]
# ### 3.8.  DOUBLE RECURRENT Q-LEARNING AGENT

# %%
## Double Recurrent Q-learning agent

from collections import deque
import random


df= df_full.copy()
name = 'Double Recurrent Q-learning agent'


class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate, name):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, None, input_size))
            self.Y = tf.placeholder(tf.float32, (None, output_size))
            cell = tf.nn.rnn_cell.LSTMCell(layer_size, state_is_tuple = False)
            self.hidden_layer = tf.placeholder(tf.float32, (None, 2 * layer_size))
            self.rnn,self.last_state = tf.nn.dynamic_rnn(inputs=self.X,cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
            self.logits = tf.layers.dense(self.rnn[:,-1], output_size)
            self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
            self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.INITIAL_FEATURES = np.zeros((4, self.state_size))
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE,
                           'real_model')
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE,
                                   'negative_model')
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        self.trainable = tf.trainable_variables()
    
    def _assign(self, from_name, to_name):
        from_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=from_name)
        to_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=to_name)
        for i in range(len(from_w)):
            assign_op = to_w[i].assign(from_w[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, dead, rnn_state):
        self.MEMORIES.append((state, action, reward, new_state, dead, rnn_state))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        init_values = np.array([a[-1] for a in replay])
        Q = self.sess.run(self.model.logits, feed_dict={self.model.X:states, 
                                                   self.model.hidden_layer:init_values})
        Q_new = self.sess.run(self.model.logits, feed_dict={self.model.X:new_states, 
                                                       self.model.hidden_layer:init_values})
        Q_new_negative = self.sess.run(self.model_negative.logits, 
                                  feed_dict={self.model_negative.X:new_states, 
                                             self.model_negative.hidden_layer:init_values})
        replay_size = len(replay)
        X = np.empty((replay_size, 4, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        INIT_VAL = np.empty((replay_size, 2 * self.LAYER_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, dead_r, rnn_memory = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not dead_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
            INIT_VAL[i] = rnn_memory
        return X, Y, INIT_VAL
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        init_value = np.zeros((1, 2 * self.LAYER_SIZE))
        for k in range(self.INITIAL_FEATURES.shape[0]):
            self.INITIAL_FEATURES[k,:] = state
        for t in range(0, len(self.trend) - 1, self.skip):
            action, last_state = self.sess.run([self.model.logits,self.model.last_state],
                                                feed_dict={self.model.X:[self.INITIAL_FEATURES],
                                                            self.model.hidden_layer:init_value})
            action, init_value = np.argmax(action[0]), last_state
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
            self.INITIAL_FEATURES = new_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            init_value = np.zeros((1, 2 * self.LAYER_SIZE))
            for k in range(self.INITIAL_FEATURES.shape[0]):
                self.INITIAL_FEATURES[k,:] = state
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign('real_model', 'negative_model')
                
                if np.random.rand() < self.EPSILON:
                    action = np.random.randint(self.OUTPUT_SIZE)
                else:
                    action, last_state = self.sess.run([self.model.logits,
                                                  self.model.last_state],
                                                  feed_dict={self.model.X:[self.INITIAL_FEATURES],
                                                             self.model.hidden_layer:init_value})
                    action, init_value = np.argmax(action[0]), last_state
                    
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
                
                self._memorize(self.INITIAL_FEATURES, action, invest, new_state, 
                               starting_money < initial_money, init_value[0])
                self.INITIAL_FEATURES = new_state
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                X, Y, INIT_VAL = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.model.cost, self.model.optimizer], 
                                        feed_dict={self.model.X: X, self.model.Y:Y,
                                                  self.model.hidden_layer: INIT_VAL})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 10, checkpoint = 10, initial_money = initial_money)

states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x00000274893EBA20>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x00000274893EB748>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# D:\Program Files\Anaconda\lib\site-packages\tensorflow\python\client\session.py:1702: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch: 10, total rewards: 43.479996.3, cost: 0.003124, total money: 9367.110016
# day 18: buy 1 unit at price 116.199997, total balance 9883.800003
# day 19: buy 1 unit at price 115.110001, total balance 9768.690002
# day 20: buy 1 unit at price 115.669998, total balance 9653.020004
# day 21: buy 1 unit at price 116.870003, total balance 9536.150002
# day 22, sell 1 unit at price 114.279999, investment -1.652322 %, total balance 9650.430000,
# day 23, sell 1 unit at price 108.800003, investment -5.481711 %, total balance 9759.230003,
# day 24, sell 1 unit at price 112.110001, investment -3.077719 %, total balance 9871.340004,
# day 25: buy 1 unit at price 112.870003, total balance 9758.470001
# day 26: buy 1 unit at price 107.879997, total balance 9650.590004
# day 27: buy 1 unit at price 110.040001, total balance 9540.550003
# day 28, sell 1 unit at price 111.739998, investment -4.389497 %, total balance 9652.290001,
# day 29, sell 1 unit at price 112.430000, investment -0.389831 %, total balance 9764.720001,
# day 30: buy 1 unit at price 115.029999, total balance 9649.690002
# day 31, sell 1 unit at price 115.510002, investment 7.072678 %, total balance 9765.200005,
# day 32: buy 1 unit at price 114.680000, total balance 9650.520004
# day 33: buy 1 unit at price 114.709999, total balance 9535.810005
# day 34, sell 1 unit at price 115.190002, investment 4.680118 %, total balance 9651.000008,
# day 36: buy 1 unit at price 117.309998, total balance 9533.690010
# day 37: buy 1 unit at price 118.769997, total balance 9414.920013
# day 38: buy 1 unit at price 117.360001, total balance 9297.560013
# day 40: buy 1 unit at price 113.430000, total balance 9184.130013
# day 41: buy 1 unit at price 113.320000, total balance 9070.810013
# day 42: buy 1 unit at price 115.059998, total balance 8955.750015
# day 43: buy 1 unit at price 115.160004, total balance 8840.590012
# day 44, sell 1 unit at price 114.730003, investment -0.260798 %, total balance 8955.320015,
# day 45, sell 1 unit at price 114.739998, investment 0.052317 %, total balance 9070.060013,
# day 46, sell 1 unit at price 118.040001, investment 2.902974 %, total balance 9188.100014,
# day 47: buy 1 unit at price 117.660004, total balance 9070.440010
# day 48, sell 1 unit at price 116.250000, investment -0.903587 %, total balance 9186.690010,
# day 49: buy 1 unit at price 114.949997, total balance 9071.740013
# day 50, sell 1 unit at price 115.239998, investment -2.972130 %, total balance 9186.980011,
# day 51, sell 1 unit at price 115.440002, investment -1.635990 %, total balance 9302.420013,
# day 53: buy 1 unit at price 114.639999, total balance 9187.780014
# day 54: buy 1 unit at price 114.739998, total balance 9073.040016
# day 55: buy 1 unit at price 109.949997, total balance 8963.090019
# day 56: buy 1 unit at price 107.010002, total balance 8856.080017
# day 57: buy 1 unit at price 110.309998, total balance 8745.770020
# day 58: buy 1 unit at price 108.169998, total balance 8637.600021
# day 59: buy 1 unit at price 108.000000, total balance 8529.600021
# day 60, sell 1 unit at price 109.970001, investment -3.050339 %, total balance 8639.570023,
# day 61, sell 1 unit at price 107.849998, investment -4.827040 %, total balance 8747.420021,
# day 62, sell 1 unit at price 109.330002, investment -4.980007 %, total balance 8856.750023,
# day 63, sell 1 unit at price 110.989998, investment -3.621054 %, total balance 8967.740021,
# day 64, sell 1 unit at price 111.879997, investment -4.912465 %, total balance 9079.620018,
# day 65, sell 1 unit at price 109.089996, investment -5.097869 %, total balance 9188.710014,
# day 66: buy 1 unit at price 110.400002, total balance 9078.310013
# day 67, sell 1 unit at price 112.510002, investment -1.857988 %, total balance 9190.820015,
# day 69: buy 1 unit at price 113.370003, total balance 9077.450012
# day 70: buy 1 unit at price 110.300003, total balance 8967.150009
# day 71: buy 1 unit at price 110.209999, total balance 8856.940010
# day 72: buy 1 unit at price 110.209999, total balance 8746.730011
# day 73, sell 1 unit at price 109.320000, investment -4.723722 %, total balance 8856.050011,
# day 74, sell 1 unit at price 111.720001, investment 1.609827 %, total balance 8967.770012,
# day 76, sell 1 unit at price 110.930000, investment 3.663207 %, total balance 9078.700012,
# day 77, sell 1 unit at price 110.410004, investment 0.090659 %, total balance 9189.110016,
# day 78, sell 1 unit at price 109.989998, investment 1.682536 %, total balance 9299.100014,
# day 79: buy 1 unit at price 110.099998, total balance 9189.000015
# day 80, sell 1 unit at price 109.400002, investment 1.296298 %, total balance 9298.400017,
# day 81, sell 1 unit at price 108.779999, investment -1.467394 %, total balance 9407.180016,
# day 83, sell 1 unit at price 107.919998, investment -4.807272 %, total balance 9515.100014,
# day 84: buy 1 unit at price 107.239998, total balance 9407.860016
# day 86: buy 1 unit at price 109.370003, total balance 9298.490013
# day 87: buy 1 unit at price 110.989998, total balance 9187.500015
# day 88, sell 1 unit at price 113.410004, investment 2.819583 %, total balance 9300.910019,
# day 89, sell 1 unit at price 114.290001, investment 3.702025 %, total balance 9415.200020,
# day 90, sell 1 unit at price 113.860001, investment 3.311861 %, total balance 9529.060020,
# day 94, sell 1 unit at price 112.959999, investment 2.597639 %, total balance 9642.020020,
# day 95, sell 1 unit at price 111.129997, investment 3.627377 %, total balance 9753.150017,
# day 96, sell 1 unit at price 112.150002, investment 2.541829 %, total balance 9865.300018,
# day 97, sell 1 unit at price 113.010002, investment 1.819988 %, total balance 9978.310020,
# day 98: buy 1 unit at price 112.489998, total balance 9865.820023
# day 99: buy 1 unit at price 111.230003, total balance 9754.590019
# day 100, sell 1 unit at price 110.660004, investment -1.626806 %, total balance 9865.250023,
# day 101, sell 1 unit at price 105.930000, investment -4.764904 %, total balance 9971.180023,
# day 115: buy 1 unit at price 108.180000, total balance 9863.000023
# day 116: buy 1 unit at price 107.550003, total balance 9755.450020
# day 117: buy 1 unit at price 107.540001, total balance 9647.910019
# day 118: buy 1 unit at price 107.510002, total balance 9540.400017
# day 119, sell 1 unit at price 105.750000, investment -2.246257 %, total balance 9646.150017,
# day 120: buy 1 unit at price 104.790001, total balance 9541.360016
# day 121, sell 1 unit at price 104.860001, investment -2.501164 %, total balance 9646.220016,
# day 122, sell 1 unit at price 103.239998, investment -3.998515 %, total balance 9749.460014,
# day 123, sell 1 unit at price 104.930000, investment -2.399778 %, total balance 9854.390015,
# day 124, sell 1 unit at price 104.199997, investment -0.563035 %, total balance 9958.590012,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig('output/'+name+'.png')
plt.show()

# %% [markdown]
# ### 3.9 DUEL Q-LEARNING AGENT

# %%
## Duel Q-learning agent

from collections import deque
import random

df= df_full.copy()
name = 'Duel Q-learning agent'

class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []

        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999

        tf.reset_default_graph()
        self.sess = tf.InteractiveSession()
        self.X = tf.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.placeholder(tf.float32, [None, self.action_size])
        feed = tf.layers.dense(self.X, 512, activation = tf.nn.relu)
        tensor_action, tensor_validation = tf.split(feed,2,1)
        feed_action = tf.layers.dense(tensor_action, self.action_size)
        feed_validation = tf.layers.dense(tensor_validation, 1)
        self.logits = feed_validation + tf.subtract(feed_action,tf.reduce_mean(feed_action,axis=1,keep_dims=True))
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.global_variables_initializer())

    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0]
        )
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest, 
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip, 
              batch_size = batch_size)
agent.train(iterations = 100, checkpoint = 10, initial_money = initial_money)

states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# D:\Program Files\Anaconda\lib\site-packages\tensorflow\python\client\session.py:1702: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch: 10, total rewards: 217.920044.3, cost: 0.319776, total money: 902.710060
# epoch: 20, total rewards: 460.740028.3, cost: 0.211403, total money: 846.320061
# epoch: 30, total rewards: 601.270042.3, cost: 0.167100, total money: 839.900047
# epoch: 40, total rewards: 655.160049.3, cost: 0.146801, total money: 850.320053
# epoch: 50, total rewards: 655.990044.3, cost: 0.111863, total money: 1574.850060
# epoch: 60, total rewards: 677.360046.3, cost: 0.095659, total money: 2058.490051
# epoch: 70, total rewards: 660.470062.3, cost: 0.092096, total money: 2252.020081
# epoch: 80, total rewards: 686.450058.3, cost: 0.068252, total money: 3158.450081
# epoch: 90, total rewards: 704.210052.3, cost: 0.066075, total money: 3294.210075
# epoch: 100, total rewards: 668.020050.3, cost: 0.065556, total money: 3167.260063
# day 4: buy 1 unit at price 108.500000, total balance 9891.500000
# day 5, sell 1 unit at price 109.050003, investment 0.506915 %, total balance 10000.550003,
# day 9: buy 1 unit at price 112.269997, total balance 9888.280006
# day 10: buy 1 unit at price 112.989998, total balance 9775.290009
# day 12: buy 1 unit at price 113.010002, total balance 9662.280006
# day 13: buy 1 unit at price 114.330002, total balance 9547.950005
# day 19: buy 1 unit at price 115.110001, total balance 9432.840004
# day 20: buy 1 unit at price 115.669998, total balance 9317.170006
# day 21, sell 1 unit at price 116.870003, investment 4.097271 %, total balance 9434.040009,
# day 22, sell 1 unit at price 114.279999, investment 1.141695 %, total balance 9548.320007,
# day 23: buy 1 unit at price 108.800003, total balance 9439.520004
# day 24, sell 1 unit at price 112.110001, investment -0.796391 %, total balance 9551.630005,
# day 25, sell 1 unit at price 112.870003, investment -1.277004 %, total balance 9664.500008,
# day 26: buy 1 unit at price 107.879997, total balance 9556.620010
# day 28, sell 1 unit at price 111.739998, investment -2.927637 %, total balance 9668.360008,
# day 29, sell 1 unit at price 112.430000, investment -2.801070 %, total balance 9780.790009,
# day 31, sell 1 unit at price 115.510002, investment 6.167278 %, total balance 9896.300011,
# day 32: buy 1 unit at price 114.680000, total balance 9781.620010
# day 33: buy 1 unit at price 114.709999, total balance 9666.910011
# day 34: buy 1 unit at price 115.190002, total balance 9551.720009
# day 35, sell 1 unit at price 114.980003, investment 6.581393 %, total balance 9666.700012,
# day 37: buy 1 unit at price 118.769997, total balance 9547.930016
# day 38: buy 1 unit at price 117.360001, total balance 9430.570015
# day 39: buy 1 unit at price 115.500000, total balance 9315.070015
# day 40: buy 1 unit at price 113.430000, total balance 9201.640015
# day 41: buy 1 unit at price 113.320000, total balance 9088.320015
# day 42: buy 1 unit at price 115.059998, total balance 8973.260017
# day 44, sell 1 unit at price 114.730003, investment 0.043602 %, total balance 9087.990021,
# day 47: buy 1 unit at price 117.660004, total balance 8970.330017
# day 48: buy 1 unit at price 116.250000, total balance 8854.080017
# day 50: buy 1 unit at price 115.239998, total balance 8738.840019
# day 53: buy 1 unit at price 114.639999, total balance 8624.200020
# day 54, sell 1 unit at price 114.739998, investment 0.026152 %, total balance 8738.940018,
# day 55: buy 1 unit at price 109.949997, total balance 8628.990021
# day 56, sell 1 unit at price 107.010002, investment -7.101311 %, total balance 8736.000023,
# day 57, sell 1 unit at price 110.309998, investment -7.123010 %, total balance 8846.310020,
# day 58: buy 1 unit at price 108.169998, total balance 8738.140022
# day 59, sell 1 unit at price 108.000000, investment -7.975461 %, total balance 8846.140022,
# day 61, sell 1 unit at price 107.849998, investment -6.623378 %, total balance 8953.990021,
# day 62, sell 1 unit at price 109.330002, investment -3.614563 %, total balance 9063.320023,
# day 64: buy 1 unit at price 111.879997, total balance 8951.440025
# day 66, sell 1 unit at price 110.400002, investment -2.576772 %, total balance 9061.840027,
# day 67, sell 1 unit at price 112.510002, investment -2.216231 %, total balance 9174.350029,
# day 68: buy 1 unit at price 110.620003, total balance 9063.730026
# day 70: buy 1 unit at price 110.300003, total balance 8953.430023
# day 72: buy 1 unit at price 110.209999, total balance 8843.220024
# day 73, sell 1 unit at price 109.320000, investment -7.088223 %, total balance 8952.540024,
# day 74, sell 1 unit at price 111.720001, investment -3.896773 %, total balance 9064.260025,
# day 75, sell 1 unit at price 111.470001, investment -3.271431 %, total balance 9175.730026,
# day 77: buy 1 unit at price 110.410004, total balance 9065.320023
# day 78: buy 1 unit at price 109.989998, total balance 8955.330025
# day 79: buy 1 unit at price 110.099998, total balance 8845.230026
# day 80, sell 1 unit at price 109.400002, investment -4.570829 %, total balance 8954.630028,
# day 81: buy 1 unit at price 108.779999, total balance 8845.850029
# day 82, sell 1 unit at price 108.779999, investment -1.064118 %, total balance 8954.630028,
# day 83, sell 1 unit at price 107.919998, investment -0.231118 %, total balance 9062.550026,
# day 84: buy 1 unit at price 107.239998, total balance 8955.310028
# day 85: buy 1 unit at price 108.430000, total balance 8846.880028
# day 86: buy 1 unit at price 109.370003, total balance 8737.510025
# day 87, sell 1 unit at price 110.989998, investment -0.795495 %, total balance 8848.500023,
# day 90, sell 1 unit at price 113.860001, investment 2.928944 %, total balance 8962.360023,
# day 92: buy 1 unit at price 113.029999, total balance 8849.330025
# day 93: buy 1 unit at price 113.339996, total balance 8735.990028
# day 95: buy 1 unit at price 111.129997, total balance 8624.860031
# day 97: buy 1 unit at price 113.010002, total balance 8511.850029
# day 98, sell 1 unit at price 112.489998, investment 1.985489 %, total balance 8624.340027,
# day 100: buy 1 unit at price 110.660004, total balance 8513.680023
# day 101: buy 1 unit at price 105.930000, total balance 8407.750023
# day 102, sell 1 unit at price 108.349998, investment -1.687688 %, total balance 8516.100021,
# day 103, sell 1 unit at price 107.010002, investment -3.079432 %, total balance 8623.110023,
# day 104, sell 1 unit at price 108.400002, investment -1.445583 %, total balance 8731.510025,
# day 107, sell 1 unit at price 110.360001, investment 0.236151 %, total balance 8841.870026,
# day 109, sell 1 unit at price 111.110001, investment 2.141940 %, total balance 8952.980026,
# day 110: buy 1 unit at price 110.830002, total balance 8842.150024
# day 111, sell 1 unit at price 110.190002, investment 2.750844 %, total balance 8952.340027,
# day 112: buy 1 unit at price 109.970001, total balance 8842.370026
# day 113: buy 1 unit at price 108.029999, total balance 8734.340027
# day 114: buy 1 unit at price 107.900002, total balance 8626.440025
# day 115: buy 1 unit at price 108.180000, total balance 8518.260025
# day 116: buy 1 unit at price 107.550003, total balance 8410.710022
# day 117, sell 1 unit at price 107.540001, investment -0.820805 %, total balance 8518.250023,
# day 118, sell 1 unit at price 107.510002, investment -1.700650 %, total balance 8625.760025,
# day 120, sell 1 unit at price 104.790001, investment -7.290098 %, total balance 8730.550026,
# day 122: buy 1 unit at price 103.239998, total balance 8627.310028
# day 123, sell 1 unit at price 104.930000, investment -7.420148 %, total balance 8732.240028,
# day 125, sell 1 unit at price 105.080002, investment -5.444071 %, total balance 8837.320030,
# day 127, sell 1 unit at price 103.720001, investment -8.220512 %, total balance 8941.040031,
# day 128: buy 1 unit at price 104.059998, total balance 8836.980034
# day 130: buy 1 unit at price 106.620003, total balance 8730.360031
# day 131, sell 1 unit at price 106.389999, investment -3.858670 %, total balance 8836.750031,
# day 133: buy 1 unit at price 106.360001, total balance 8730.390030
# day 134: buy 1 unit at price 110.580002, total balance 8619.810028
# day 135: buy 1 unit at price 110.500000, total balance 8509.310028
# day 136: buy 1 unit at price 111.529999, total balance 8397.780029
# day 139, sell 1 unit at price 113.349998, investment 7.004624 %, total balance 8511.130028,
# day 140: buy 1 unit at price 114.150002, total balance 8396.980026
# day 141: buy 1 unit at price 115.180000, total balance 8281.800026
# day 142, sell 1 unit at price 114.849998, investment 3.627174 %, total balance 8396.650024,
# day 146: buy 1 unit at price 115.660004, total balance 8280.990021
# day 147, sell 1 unit at price 116.150002, investment 5.619715 %, total balance 8397.140022,
# day 148, sell 1 unit at price 117.089996, investment 8.386557 %, total balance 8514.230019,
# day 149: buy 1 unit at price 117.120003, total balance 8397.110016
# day 150, sell 1 unit at price 117.550003, investment 8.943467 %, total balance 8514.660019,
# day 151: buy 1 unit at price 117.790001, total balance 8396.870018
# day 152, sell 1 unit at price 116.879997, investment 8.042149 %, total balance 8513.750015,
# day 153: buy 1 unit at price 115.730003, total balance 8398.020012
# day 154: buy 1 unit at price 113.889999, total balance 8284.130013
# day 155, sell 1 unit at price 114.650002, investment 6.601579 %, total balance 8398.780014,
# day 156: buy 1 unit at price 113.699997, total balance 8285.080017
# day 157, sell 1 unit at price 114.769997, investment 11.168151 %, total balance 8399.850014,
# day 158, sell 1 unit at price 114.769997, investment 10.292139 %, total balance 8514.620010,
# day 159, sell 1 unit at price 114.620003, investment 7.503282 %, total balance 8629.240013,
# day 160: buy 1 unit at price 115.320000, total balance 8513.920013
# day 161: buy 1 unit at price 114.970001, total balance 8398.950012
# day 162, sell 1 unit at price 114.730003, investment 7.869502 %, total balance 8513.680016,
# day 163, sell 1 unit at price 114.680000, investment 3.707721 %, total balance 8628.360016,
# day 164, sell 1 unit at price 116.709999, investment 5.619909 %, total balance 8745.070015,
# day 165: buy 1 unit at price 116.139999, total balance 8628.930016
# day 166: buy 1 unit at price 115.760002, total balance 8513.170013
# day 167, sell 1 unit at price 115.190002, investment 3.281632 %, total balance 8628.360016,
# day 168: buy 1 unit at price 114.580002, total balance 8513.780014
# day 169, sell 1 unit at price 115.150002, investment 0.876040 %, total balance 8628.930016,
# day 170: buy 1 unit at price 114.589996, total balance 8514.340019
# day 172, sell 1 unit at price 114.320000, investment -0.746658 %, total balance 8628.660019,
# day 173, sell 1 unit at price 113.709999, investment -1.685980 %, total balance 8742.370018,
# day 174: buy 1 unit at price 114.430000, total balance 8627.940018
# day 176: buy 1 unit at price 113.519997, total balance 8514.420021
# day 177: buy 1 unit at price 113.500000, total balance 8400.920021
# day 178, sell 1 unit at price 113.839996, investment -2.800552 %, total balance 8514.760017,
# day 180, sell 1 unit at price 117.620003, investment -0.144323 %, total balance 8632.380020,
# day 182: buy 1 unit at price 117.849998, total balance 8514.530022
# day 183: buy 1 unit at price 116.720001, total balance 8397.810020
# day 184, sell 1 unit at price 116.389999, investment 0.570289 %, total balance 8514.200020,
# day 185: buy 1 unit at price 115.019997, total balance 8399.180023
# day 186: buy 1 unit at price 114.519997, total balance 8284.660027
# day 187, sell 1 unit at price 112.839996, investment -0.921945 %, total balance 8397.500023,
# day 188, sell 1 unit at price 113.500000, investment -0.175899 %, total balance 8511.000023,
# day 190, sell 1 unit at price 115.040001, investment -0.242802 %, total balance 8626.040024,
# day 192: buy 1 unit at price 114.620003, total balance 8511.420021
# day 193, sell 1 unit at price 115.320000, investment 0.304426 %, total balance 8626.740021,
# day 195: buy 1 unit at price 111.470001, total balance 8515.270020
# day 196: buy 1 unit at price 108.129997, total balance 8407.140022
# day 197: buy 1 unit at price 106.949997, total balance 8300.190025
# day 198: buy 1 unit at price 106.339996, total balance 8193.850029
# day 203, sell 1 unit at price 106.360001, investment -8.420870 %, total balance 8300.210030,
# day 204, sell 1 unit at price 105.250000, investment -9.079131 %, total balance 8405.460030,
# day 205: buy 1 unit at price 103.290001, total balance 8302.170029
# day 206: buy 1 unit at price 104.860001, total balance 8197.310028
# day 207: buy 1 unit at price 103.419998, total balance 8093.890030
# day 208: buy 1 unit at price 104.849998, total balance 7989.040031
# day 211: buy 1 unit at price 108.980003, total balance 7880.060028
# day 212: buy 1 unit at price 108.379997, total balance 7771.680031
# day 213, sell 1 unit at price 109.089996, investment -4.791417 %, total balance 7880.770027,
# day 216: buy 1 unit at price 112.379997, total balance 7768.390030
# day 217: buy 1 unit at price 111.290001, total balance 7657.100029
# day 219: buy 1 unit at price 109.589996, total balance 7547.510033
# day 220: buy 1 unit at price 107.330002, total balance 7440.180031
# day 221: buy 1 unit at price 110.070000, total balance 7330.110031
# day 223, sell 1 unit at price 110.830002, investment -3.281259 %, total balance 7440.940033,
# day 225: buy 1 unit at price 107.639999, total balance 7333.300034
# day 226: buy 1 unit at price 106.650002, total balance 7226.650032
# day 227: buy 1 unit at price 109.260002, total balance 7117.390030
# day 228: buy 1 unit at price 109.720001, total balance 7007.670029
# day 229, sell 1 unit at price 110.940002, investment -3.049898 %, total balance 7118.610031,
# day 231, sell 1 unit at price 111.190002, investment -2.052497 %, total balance 7229.800034,
# day 232: buy 1 unit at price 112.239998, total balance 7117.560036
# day 233: buy 1 unit at price 107.230003, total balance 7010.330032
# day 234: buy 1 unit at price 105.190002, total balance 6905.140030
# day 235, sell 1 unit at price 103.290001, investment -8.995594 %, total balance 7008.430031,
# day 236, sell 1 unit at price 101.360001, investment -13.992362 %, total balance 7109.790031,
# day 237, sell 1 unit at price 100.370003, investment -14.007881 %, total balance 7210.160034,
# day 238: buy 1 unit at price 101.019997, total balance 7109.140038
# day 239: buy 1 unit at price 101.120003, total balance 7008.020035
# day 241: buy 1 unit at price 99.010002, total balance 6909.010033
# day 242, sell 1 unit at price 98.540001, investment -14.327940 %, total balance 7007.550034,
# day 244: buy 1 unit at price 96.449997, total balance 6911.100037
# day 245: buy 1 unit at price 94.169998, total balance 6816.930038
# day 246: buy 1 unit at price 92.139999, total balance 6724.790039
# day 247: buy 1 unit at price 95.959999, total balance 6628.830040
# day 249: buy 1 unit at price 96.830002, total balance 6532.000038
# day 250, sell 1 unit at price 97.620003, investment -14.757243 %, total balance 6629.620041,
# day 253: buy 1 unit at price 100.690002, total balance 6528.930038
# day 254: buy 1 unit at price 100.760002, total balance 6428.170036
# day 255: buy 1 unit at price 100.570000, total balance 6327.600037
# day 256: buy 1 unit at price 100.400002, total balance 6227.200035
# day 257: buy 1 unit at price 100.389999, total balance 6126.810036
# day 258, sell 1 unit at price 99.910004, investment -12.833710 %, total balance 6226.720039,
# day 260: buy 1 unit at price 101.680000, total balance 6125.040039
# day 261, sell 1 unit at price 102.500000, investment -8.047009 %, total balance 6227.540039,
# day 264: buy 1 unit at price 102.940002, total balance 6124.600037
# day 265: buy 1 unit at price 102.680000, total balance 6021.920036
# day 267, sell 1 unit at price 103.389999, investment -4.383610 %, total balance 6125.310036,
# day 268: buy 1 unit at price 103.879997, total balance 6021.430038
# day 270: buy 1 unit at price 104.410004, total balance 5917.020035
# day 271, sell 1 unit at price 103.500000, investment -3.225804 %, total balance 6020.520035,
# day 273: buy 1 unit at price 104.250000, total balance 5916.270035
# day 274, sell 1 unit at price 103.790001, investment -2.397965 %, total balance 6020.060036,
# day 276, sell 1 unit at price 102.379997, investment -0.881018 %, total balance 6122.440033,
# day 277, sell 1 unit at price 101.360001, investment -3.337784 %, total balance 6223.800034,
# day 280: buy 1 unit at price 103.089996, total balance 6120.710037
# day 281: buy 1 unit at price 102.419998, total balance 6018.290039
# day 285: buy 1 unit at price 105.470001, total balance 5912.820038
# day 286, sell 1 unit at price 105.000000, investment 1.527753 %, total balance 6017.820038,
# day 287: buy 1 unit at price 106.099998, total balance 5911.720039
# day 288: buy 1 unit at price 105.290001, total balance 5806.430038
# day 289, sell 1 unit at price 105.160004, investment 0.295665 %, total balance 5911.590042,
# day 290: buy 1 unit at price 104.360001, total balance 5807.230042
# day 292: buy 1 unit at price 104.190002, total balance 5703.040039
# day 295, sell 1 unit at price 102.970001, investment -5.514775 %, total balance 5806.010040,
# day 296, sell 1 unit at price 103.010002, investment -4.954784 %, total balance 5909.020042,
# day 297: buy 1 unit at price 104.349998, total balance 5804.670044
# day 298, sell 1 unit at price 104.040001, investment -7.421246 %, total balance 5908.710045,
# day 300: buy 1 unit at price 105.339996, total balance 5803.370049
# day 301, sell 1 unit at price 106.550003, investment -4.259141 %, total balance 5909.920052,
# day 304: buy 1 unit at price 104.519997, total balance 5805.400055
# day 305, sell 1 unit at price 102.870003, investment -6.131941 %, total balance 5908.270058,
# day 306: buy 1 unit at price 99.760002, total balance 5808.510056
# day 307: buy 1 unit at price 98.930000, total balance 5709.580055
# day 308, sell 1 unit at price 99.919998, investment -6.903944 %, total balance 5809.500053,
# day 310: buy 1 unit at price 100.709999, total balance 5708.790054
# day 312, sell 1 unit at price 104.639999, investment -4.933225 %, total balance 5813.430054,
# day 315: buy 1 unit at price 105.559998, total balance 5707.870056
# day 316, sell 1 unit at price 105.309998, investment -2.164625 %, total balance 5813.180054,
# day 317: buy 1 unit at price 105.650002, total balance 5707.530052
# day 318: buy 1 unit at price 104.870003, total balance 5602.660049
# day 319: buy 1 unit at price 105.339996, total balance 5497.320053
# day 320, sell 1 unit at price 106.230003, investment -0.393810 %, total balance 5603.550056,
# day 323, sell 1 unit at price 111.099998, investment 1.684053 %, total balance 5714.650055,
# day 325: buy 1 unit at price 113.459999, total balance 5601.190056
# day 326: buy 1 unit at price 113.599998, total balance 5487.590057
# day 327: buy 1 unit at price 113.739998, total balance 5373.850060
# day 328: buy 1 unit at price 113.550003, total balance 5260.300056
# day 329: buy 1 unit at price 113.610001, total balance 5146.690056
# day 331, sell 1 unit at price 116.120003, investment 5.833031 %, total balance 5262.810059,
# day 334: buy 1 unit at price 115.410004, total balance 5147.400055
# day 335, sell 1 unit at price 116.120003, investment 3.456883 %, total balance 5263.520058,
# day 336: buy 1 unit at price 115.089996, total balance 5148.430061
# day 337, sell 1 unit at price 113.209999, investment 5.576793 %, total balance 5261.640060,
# day 338: buy 1 unit at price 112.610001, total balance 5149.030060
# day 339, sell 1 unit at price 112.519997, investment 6.968337 %, total balance 5261.550056,
# day 340, sell 1 unit at price 112.510002, investment 11.373991 %, total balance 5374.060059,
# day 341: buy 1 unit at price 109.449997, total balance 5264.610062
# day 342, sell 1 unit at price 110.320000, investment 9.098098 %, total balance 5374.930061,
# day 344, sell 1 unit at price 111.309998, investment 12.422983 %, total balance 5486.240059,
# day 346, sell 1 unit at price 111.349998, investment 15.448421 %, total balance 5597.590057,
# day 347: buy 1 unit at price 111.730003, total balance 5485.860054
# day 348: buy 1 unit at price 110.820000, total balance 5375.040054
# day 349: buy 1 unit at price 108.639999, total balance 5266.400055
# day 350, sell 1 unit at price 109.709999, investment 16.502072 %, total balance 5376.110054,
# day 351: buy 1 unit at price 108.519997, total balance 5267.590057
# day 352: buy 1 unit at price 108.220001, total balance 5159.370056
# day 353, sell 1 unit at price 107.059998, investment 16.192748 %, total balance 5266.430054,
# day 354, sell 1 unit at price 105.959999, investment 10.421009 %, total balance 5372.390053,
# day 355, sell 1 unit at price 106.459999, investment 9.945262 %, total balance 5478.850052,
# day 357: buy 1 unit at price 110.129997, total balance 5368.720055
# day 358: buy 1 unit at price 110.370003, total balance 5258.350052
# day 360, sell 1 unit at price 110.339996, investment 9.583865 %, total balance 5368.690048,
# day 361: buy 1 unit at price 110.680000, total balance 5258.010048
# day 362: buy 1 unit at price 109.269997, total balance 5148.740051
# day 363: buy 1 unit at price 109.540001, total balance 5039.200050
# day 364, sell 1 unit at price 109.820000, investment 8.991661 %, total balance 5149.020050,
# day 365: buy 1 unit at price 109.220001, total balance 5039.800049
# day 368: buy 1 unit at price 110.190002, total balance 4929.610046
# day 369, sell 1 unit at price 109.440002, investment 8.819730 %, total balance 5039.050049,
# day 370: buy 1 unit at price 108.660004, total balance 4930.390045
# day 371, sell 1 unit at price 107.760002, investment 7.330678 %, total balance 5038.150047,
# day 373: buy 1 unit at price 108.839996, total balance 4929.310051
# day 374: buy 1 unit at price 111.800003, total balance 4817.510048
# day 378: buy 1 unit at price 113.489998, total balance 4704.020050
# day 379, sell 1 unit at price 112.870003, investment 12.431521 %, total balance 4816.890053,
# day 381, sell 1 unit at price 113.019997, investment 11.152632 %, total balance 4929.910049,
# day 382, sell 1 unit at price 114.099998, investment 10.841263 %, total balance 5044.010048,
# day 383: buy 1 unit at price 115.300003, total balance 4928.710045
# day 384: buy 1 unit at price 113.900002, total balance 4814.810043
# day 385, sell 1 unit at price 115.120003, investment 12.115312 %, total balance 4929.930046,
# day 386: buy 1 unit at price 113.989998, total balance 4815.940048
# day 387, sell 1 unit at price 114.669998, investment 10.386986 %, total balance 4930.610046,
# day 389, sell 1 unit at price 114.269997, investment 9.443533 %, total balance 5044.880043,
# day 392: buy 1 unit at price 115.709999, total balance 4929.170044
# day 394: buy 1 unit at price 115.849998, total balance 4813.320045
# day 397, sell 1 unit at price 112.940002, investment 8.335734 %, total balance 4926.260048,
# day 398: buy 1 unit at price 112.930000, total balance 4813.330048
# day 399: buy 1 unit at price 109.570000, total balance 4703.760048
# day 400: buy 1 unit at price 110.430000, total balance 4593.330048
# day 401: buy 1 unit at price 108.029999, total balance 4485.300049
# day 402: buy 1 unit at price 109.860001, total balance 4375.440048
# day 403, sell 1 unit at price 109.739998, investment 6.450676 %, total balance 4485.180046,
# day 404, sell 1 unit at price 107.680000, investment 5.135718 %, total balance 4592.860046,
# day 405, sell 1 unit at price 109.339996, investment 3.669285 %, total balance 4702.200043,
# day 406: buy 1 unit at price 104.800003, total balance 4597.400040
# day 407: buy 1 unit at price 105.199997, total balance 4492.200043
# day 408: buy 1 unit at price 107.720001, total balance 4384.480042
# day 409, sell 1 unit at price 108.690002, investment 2.441097 %, total balance 4493.170044,
# day 411: buy 1 unit at price 107.610001, total balance 4385.560043
# day 412, sell 1 unit at price 108.720001, investment 3.257670 %, total balance 4494.280045,
# day 413: buy 1 unit at price 106.019997, total balance 4388.260048
# day 414: buy 1 unit at price 106.870003, total balance 4281.390045
# day 415: buy 1 unit at price 105.739998, total balance 4175.650047
# day 416, sell 1 unit at price 106.800003, investment 2.338063 %, total balance 4282.450050,
# day 421, sell 1 unit at price 112.370003, investment 7.851041 %, total balance 4394.820053,
# day 426: buy 1 unit at price 117.910004, total balance 4276.910049
# day 427: buy 1 unit at price 120.230003, total balance 4156.680046
# day 428: buy 1 unit at price 119.160004, total balance 4037.520042
# day 429: buy 1 unit at price 118.570000, total balance 3918.950043
# day 431, sell 1 unit at price 119.379997, investment 14.403449 %, total balance 4038.330040,
# day 434: buy 1 unit at price 117.330002, total balance 3921.000038
# day 435: buy 1 unit at price 118.000000, total balance 3803.000038
# day 437, sell 1 unit at price 117.720001, investment 11.752426 %, total balance 3920.720039,
# day 438, sell 1 unit at price 117.690002, investment 12.600465 %, total balance 4038.410042,
# day 440: buy 1 unit at price 113.250000, total balance 3925.160042
# day 441, sell 1 unit at price 112.190002, investment 12.459904 %, total balance 4037.350044,
# day 442, sell 1 unit at price 114.620003, investment 15.859701 %, total balance 4151.970047,
# day 443: buy 1 unit at price 114.370003, total balance 4037.600044
# day 444: buy 1 unit at price 111.820000, total balance 3925.780045
# day 445, sell 1 unit at price 112.629997, investment 11.835963 %, total balance 4038.410042,
# day 446, sell 1 unit at price 114.209999, investment 8.194393 %, total balance 4152.620041,
# day 448: buy 1 unit at price 116.449997, total balance 4036.170044
# day 449: buy 1 unit at price 119.959999, total balance 3916.210045
# day 450: buy 1 unit at price 119.680000, total balance 3796.530045
# day 451: buy 1 unit at price 120.349998, total balance 3676.180046
# day 453, sell 1 unit at price 123.550003, investment 16.942737 %, total balance 3799.730049,
# day 454: buy 1 unit at price 124.790001, total balance 3674.940048
# day 455: buy 1 unit at price 125.120003, total balance 3549.820045
# day 459: buy 1 unit at price 126.430000, total balance 3423.390045
# day 460: buy 1 unit at price 125.730003, total balance 3297.660042
# day 461: buy 1 unit at price 124.919998, total balance 3172.740044
# day 464: buy 1 unit at price 129.100006, total balance 3043.640038
# day 468: buy 1 unit at price 129.919998, total balance 2913.720039
# day 469, sell 1 unit at price 129.160004, investment 23.162010 %, total balance 3042.880043,
# day 470, sell 1 unit at price 128.479996, investment 21.966964 %, total balance 3171.360039,
# day 471, sell 1 unit at price 128.600006, investment 13.343916 %, total balance 3299.960045,
# day 472, sell 1 unit at price 129.529999, investment 14.022888 %, total balance 3429.490044,
# day 473: buy 1 unit at price 130.619995, total balance 3298.870049
# day 474, sell 1 unit at price 130.580002, investment 14.805701 %, total balance 3429.450050,
# day 475: buy 1 unit at price 129.630005, total balance 3299.820045
# day 476, sell 1 unit at price 129.929993, investment 14.425354 %, total balance 3429.750038,
# day 477: buy 1 unit at price 130.789993, total balance 3298.960045
# day 478, sell 1 unit at price 131.490005, investment 15.738055 %, total balance 3430.450050,
# day 479: buy 1 unit at price 131.669998, total balance 3298.780052
# day 480: buy 1 unit at price 132.059998, total balance 3166.720055
# day 481: buy 1 unit at price 131.759995, total balance 3034.960060
# day 482, sell 1 unit at price 131.470001, investment 13.915603 %, total balance 3166.430061,
# day 483: buy 1 unit at price 129.779999, total balance 3036.650063
# day 484: buy 1 unit at price 132.339996, total balance 2904.310066
# day 485, sell 1 unit at price 133.059998, investment 15.613869 %, total balance 3037.370064,
# day 488: buy 1 unit at price 134.500000, total balance 2902.870064
# day 489: buy 1 unit at price 134.179993, total balance 2768.690071
# day 490: buy 1 unit at price 138.020004, total balance 2630.670067
# day 491: buy 1 unit at price 136.809998, total balance 2493.860069
# day 492: buy 1 unit at price 137.339996, total balance 2356.520073
# day 493, sell 1 unit at price 138.179993, investment 22.706680 %, total balance 2494.700066,
# day 495, sell 1 unit at price 137.350006, investment 25.491101 %, total balance 2632.050072,
# day 496: buy 1 unit at price 137.240005, total balance 2494.810066
# day 497: buy 1 unit at price 137.199997, total balance 2357.610069
# day 498, sell 1 unit at price 137.580002, investment 23.136130 %, total balance 2495.190071,
# day 500, sell 1 unit at price 139.139999, investment 25.554954 %, total balance 2634.330070,
# day 501, sell 1 unit at price 138.630005, investment 27.604939 %, total balance 2772.960075,
# day 503: buy 1 unit at price 141.089996, total balance 2631.870079
# day 504: buy 1 unit at price 138.339996, total balance 2493.530083
# day 505: buy 1 unit at price 138.229996, total balance 2355.300087
# day 506: buy 1 unit at price 135.880005, total balance 2219.420082
# day 507: buy 1 unit at price 136.940002, total balance 2082.480080
# day 508: buy 1 unit at price 137.440002, total balance 1945.040077
# day 509, sell 1 unit at price 136.070007, investment 25.387036 %, total balance 2081.110085,
# day 510: buy 1 unit at price 137.199997, total balance 1943.910088
# day 511, sell 1 unit at price 138.800003, investment 28.257255 %, total balance 2082.710091,
# day 512: buy 1 unit at price 136.720001, total balance 1945.990089
# day 513, sell 1 unit at price 137.250000, investment 24.625446 %, total balance 2083.240089,
# day 515, sell 1 unit at price 136.839996, investment 23.982960 %, total balance 2220.080086,
# day 517, sell 1 unit at price 136.539993, investment 23.364648 %, total balance 2356.620079,
# day 519, sell 1 unit at price 132.029999, investment 20.829141 %, total balance 2488.650078,
# day 521, sell 1 unit at price 134.229996, investment 22.539707 %, total balance 2622.880074,
# day 524, sell 1 unit at price 133.369995, investment 22.111329 %, total balance 2756.250069,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig('output/'+name+'.png')
plt.show()

# %% [markdown]
# ### 3.10. DOUBLE DUEL Q LEARNING AGENT

# %% [markdown]
# In recent years there have been many successes of using deep representations in reinforcement learning. Still, many of these applications use conventional architectures, such as convolutional networks, LSTMs, or auto-encoders. In this paper, we present a new neural network architecture for model-free reinforcement learning. Our dueling network represents two separate estimators: one for the state value function and one for the state-dependent action advantage function. The main benefit of this factoring is to generalize learning across actions without imposing any change to the underlying reinforcement learning algorithm. Our results show that this architecture leads to better policy evaluation in the presence of many similar-valued actions. Moreover, the dueling architecture enables our RL agent to outperform the state-of-the-art on the Atari 2600 domain.

# %%
## Double Duel Q-learning agent

from collections import deque
import random

df= df_full.copy()
name = 'Double Duel Q-learning agent'

class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate):
        self.X = tf.placeholder(tf.float32, (None, input_size))
        self.Y = tf.placeholder(tf.float32, (None, output_size))
        feed = tf.layers.dense(self.X, layer_size, activation = tf.nn.relu)
        tensor_action, tensor_validation = tf.split(feed,2,1)
        feed_action = tf.layers.dense(tensor_action, output_size)
        feed_validation = tf.layers.dense(tensor_validation, 1)
        self.logits = feed_validation + tf.subtract(feed_action,tf.reduce_mean(feed_action,axis=1,keep_dims=True))
        self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        self.trainable = tf.trainable_variables()
    
    def _assign(self):
        for i in range(len(self.trainable)//2):
            assign_op = self.trainable[i+len(self.trainable)//2].assign(self.trainable[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.predict(states)
        Q_new = self.predict(new_states)
        Q_new_negative = self.sess.run(self.model_negative.logits, feed_dict={self.model_negative.X:new_states})
        replay_size = len(replay)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, done_r = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not done_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
        return X, Y

    def predict(self, inputs):
        return self.sess.run(self.model.logits, feed_dict={self.model.X:inputs})
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign()
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                state = next_state
                replay = random.sample(self.MEMORIES, batch_size)
                X, Y = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.model.cost, self.model.optimizer], 
                                        feed_dict={self.model.X: X, self.model.Y:Y})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 100, checkpoint = 10, initial_money = initial_money)

states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# D:\Program Files\Anaconda\lib\site-packages\tensorflow\python\client\session.py:1702: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch: 10, total rewards: 83.590012.3, cost: 0.016299, total money: 9814.330017
# epoch: 20, total rewards: -6.219971.3, cost: 0.003634, total money: 9594.150040
# epoch: 30, total rewards: 562.899940.3, cost: 0.013938, total money: 8034.789932
# epoch: 40, total rewards: 54.620003.3, cost: 0.003916, total money: 9785.360008
# epoch: 50, total rewards: -9.049988.3, cost: 0.005215, total money: 9990.950012
# epoch: 60, total rewards: 14.299942.3, cost: 0.008442, total money: 9475.739960
# epoch: 70, total rewards: 39.789978.3, cost: 0.002630, total money: 10039.789978
# epoch: 80, total rewards: 39.820015.3, cost: 0.000927, total money: 9766.940025
# epoch: 90, total rewards: 65.730064.3, cost: 0.007150, total money: 9928.140068
# epoch: 100, total rewards: 56.439995.3, cost: 0.002518, total money: 10056.439995
# day 1: buy 1 unit at price 108.059998, total balance 9891.940002
# day 2, sell 1 unit at price 109.040001, investment 0.906907 %, total balance 10000.980003,
# day 9: buy 1 unit at price 112.269997, total balance 9888.710007
# day 10: buy 1 unit at price 112.989998, total balance 9775.720009
# day 11, sell 1 unit at price 113.260002, investment 0.881808 %, total balance 9888.980011,
# day 12, sell 1 unit at price 113.010002, investment 0.017704 %, total balance 10001.990013,
# day 25: buy 1 unit at price 112.870003, total balance 9889.120010
# day 26: buy 1 unit at price 107.879997, total balance 9781.240013
# day 27: buy 1 unit at price 110.040001, total balance 9671.200012
# day 29, sell 1 unit at price 112.430000, investment -0.389831 %, total balance 9783.630013,
# day 30, sell 1 unit at price 115.029999, investment 6.627736 %, total balance 9898.660011,
# day 31, sell 1 unit at price 115.510002, investment 4.970921 %, total balance 10014.170013,
# day 44: buy 1 unit at price 114.730003, total balance 9899.440010
# day 45, sell 1 unit at price 114.739998, investment 0.008711 %, total balance 10014.180008,
# day 48: buy 1 unit at price 116.250000, total balance 9897.930008
# day 49: buy 1 unit at price 114.949997, total balance 9782.980011
# day 50: buy 1 unit at price 115.239998, total balance 9667.740013
# day 53, sell 1 unit at price 114.639999, investment -1.384947 %, total balance 9782.380013,
# day 54: buy 1 unit at price 114.739998, total balance 9667.640015
# day 55: buy 1 unit at price 109.949997, total balance 9557.690018
# day 57, sell 1 unit at price 110.309998, investment -4.036537 %, total balance 9668.000015,
# day 58, sell 1 unit at price 108.169998, investment -6.135022 %, total balance 9776.170013,
# day 59, sell 1 unit at price 108.000000, investment -5.874149 %, total balance 9884.170013,
# day 60, sell 1 unit at price 109.970001, investment 0.018194 %, total balance 9994.140015,
# day 63: buy 1 unit at price 110.989998, total balance 9883.150017
# day 65, sell 1 unit at price 109.089996, investment -1.711867 %, total balance 9992.240013,
# day 79: buy 1 unit at price 110.099998, total balance 9882.140015
# day 80, sell 1 unit at price 109.400002, investment -0.635783 %, total balance 9991.540016,
# day 85: buy 1 unit at price 108.430000, total balance 9883.110016
# day 86, sell 1 unit at price 109.370003, investment 0.866921 %, total balance 9992.480019,
# day 92: buy 1 unit at price 113.029999, total balance 9879.450020
# day 93, sell 1 unit at price 113.339996, investment 0.274261 %, total balance 9992.790016,
# day 94: buy 1 unit at price 112.959999, total balance 9879.830017
# day 95: buy 1 unit at price 111.129997, total balance 9768.700020
# day 97, sell 1 unit at price 113.010002, investment 0.044266 %, total balance 9881.710022,
# day 99: buy 1 unit at price 111.230003, total balance 9770.480019
# day 100, sell 1 unit at price 110.660004, investment -0.422922 %, total balance 9881.140022,
# day 102, sell 1 unit at price 108.349998, investment -2.589234 %, total balance 9989.490021,
# day 104: buy 1 unit at price 108.400002, total balance 9881.090019
# day 107: buy 1 unit at price 110.360001, total balance 9770.730019
# day 108, sell 1 unit at price 110.800003, investment 2.214024 %, total balance 9881.530022,
# day 109, sell 1 unit at price 111.110001, investment 0.679594 %, total balance 9992.640022,
# day 116: buy 1 unit at price 107.550003, total balance 9885.090019
# day 117: buy 1 unit at price 107.540001, total balance 9777.550018
# day 118, sell 1 unit at price 107.510002, investment -0.037193 %, total balance 9885.060020,
# day 119, sell 1 unit at price 105.750000, investment -1.664498 %, total balance 9990.810020,
# day 120: buy 1 unit at price 104.790001, total balance 9886.020020
# day 121, sell 1 unit at price 104.860001, investment 0.066800 %, total balance 9990.880020,
# day 161: buy 1 unit at price 114.970001, total balance 9875.910019
# day 162, sell 1 unit at price 114.730003, investment -0.208748 %, total balance 9990.640022,
# day 167: buy 1 unit at price 115.190002, total balance 9875.450020
# day 168, sell 1 unit at price 114.580002, investment -0.529560 %, total balance 9990.030022,
# day 179: buy 1 unit at price 114.300003, total balance 9875.730019
# day 180, sell 1 unit at price 117.620003, investment 2.904637 %, total balance 9993.350021,
# day 183: buy 1 unit at price 116.720001, total balance 9876.630020
# day 185, sell 1 unit at price 115.019997, investment -1.456481 %, total balance 9991.650017,
# day 190: buy 1 unit at price 115.040001, total balance 9876.610016
# day 193: buy 1 unit at price 115.320000, total balance 9761.290016
# day 194, sell 1 unit at price 114.519997, investment -0.452020 %, total balance 9875.810013,
# day 195: buy 1 unit at price 111.470001, total balance 9764.340012
# day 196: buy 1 unit at price 108.129997, total balance 9656.210014
# day 197, sell 1 unit at price 106.949997, investment -7.258067 %, total balance 9763.160011,
# day 198, sell 1 unit at price 106.339996, investment -4.602139 %, total balance 9869.500008,
# day 199, sell 1 unit at price 108.620003, investment 0.453163 %, total balance 9978.120010,
# day 200: buy 1 unit at price 109.830002, total balance 9868.290009
# day 201, sell 1 unit at price 108.089996, investment -1.584272 %, total balance 9976.380005,
# day 207: buy 1 unit at price 103.419998, total balance 9872.960007
# day 208: buy 1 unit at price 104.849998, total balance 9768.110008
# day 209, sell 1 unit at price 106.699997, investment 3.171532 %, total balance 9874.810005,
# day 210: buy 1 unit at price 109.019997, total balance 9765.790009
# day 211, sell 1 unit at price 108.980003, investment 3.938965 %, total balance 9874.770012,
# day 212, sell 1 unit at price 108.379997, investment -0.587048 %, total balance 9983.150009,
# day 225: buy 1 unit at price 107.639999, total balance 9875.510010
# day 226, sell 1 unit at price 106.650002, investment -0.919730 %, total balance 9982.160011,
# day 228: buy 1 unit at price 109.720001, total balance 9872.440010
# day 230: buy 1 unit at price 110.059998, total balance 9762.380013
# day 231: buy 1 unit at price 111.190002, total balance 9651.190010
# day 232, sell 1 unit at price 112.239998, investment 2.296752 %, total balance 9763.430008,
# day 233, sell 1 unit at price 107.230003, investment -2.571320 %, total balance 9870.660011,
# day 234, sell 1 unit at price 105.190002, investment -5.396169 %, total balance 9975.850014,
# day 237: buy 1 unit at price 100.370003, total balance 9875.480011
# day 239, sell 1 unit at price 101.120003, investment 0.747235 %, total balance 9976.600014,
# day 240: buy 1 unit at price 100.290001, total balance 9876.310013
# day 241, sell 1 unit at price 99.010002, investment -1.276298 %, total balance 9975.320015,
# day 243: buy 1 unit at price 97.290001, total balance 9878.030014
# day 244, sell 1 unit at price 96.449997, investment -0.863402 %, total balance 9974.480011,
# day 251: buy 1 unit at price 99.309998, total balance 9875.170013
# day 252, sell 1 unit at price 97.110001, investment -2.215282 %, total balance 9972.280014,
# day 253: buy 1 unit at price 100.690002, total balance 9871.590012
# day 254, sell 1 unit at price 100.760002, investment 0.069520 %, total balance 9972.350014,
# day 255: buy 1 unit at price 100.570000, total balance 9871.780014
# day 256, sell 1 unit at price 100.400002, investment -0.169035 %, total balance 9972.180016,
# day 259: buy 1 unit at price 100.940002, total balance 9871.240013
# day 261: buy 1 unit at price 102.500000, total balance 9768.740013
# day 262: buy 1 unit at price 102.919998, total balance 9665.820015
# day 263: buy 1 unit at price 104.589996, total balance 9561.230019
# day 264, sell 1 unit at price 102.940002, investment 1.981375 %, total balance 9664.170021,
# day 265: buy 1 unit at price 102.680000, total balance 9561.490021
# day 266: buy 1 unit at price 102.739998, total balance 9458.750023
# day 267, sell 1 unit at price 103.389999, investment 0.868292 %, total balance 9562.140022,
# day 268, sell 1 unit at price 103.879997, investment 0.932762 %, total balance 9666.020020,
# day 269: buy 1 unit at price 104.169998, total balance 9561.850021
# day 270, sell 1 unit at price 104.410004, investment -0.172094 %, total balance 9666.260025,
# day 271: buy 1 unit at price 103.500000, total balance 9562.760025
# day 272: buy 1 unit at price 103.879997, total balance 9458.880028
# day 273: buy 1 unit at price 104.250000, total balance 9354.630028
# day 276, sell 1 unit at price 102.379997, investment -0.292173 %, total balance 9457.010025,
# day 277, sell 1 unit at price 101.360001, investment -1.343194 %, total balance 9558.370026,
# day 278, sell 1 unit at price 100.879997, investment -3.158300 %, total balance 9659.250023,
# day 279, sell 1 unit at price 102.599998, investment -0.869567 %, total balance 9761.850021,
# day 283: buy 1 unit at price 105.180000, total balance 9656.670021
# day 284, sell 1 unit at price 105.690002, investment 1.742400 %, total balance 9762.360023,
# day 285: buy 1 unit at price 105.470001, total balance 9656.890022
# day 286: buy 1 unit at price 105.000000, total balance 9551.890022
# day 287, sell 1 unit at price 106.099998, investment 1.774579 %, total balance 9657.990021,
# day 288, sell 1 unit at price 105.290001, investment 0.104583 %, total balance 9763.280022,
# day 289, sell 1 unit at price 105.160004, investment -0.293920 %, total balance 9868.440025,
# day 290, sell 1 unit at price 104.360001, investment -0.609523 %, total balance 9972.800026,
# day 296: buy 1 unit at price 103.010002, total balance 9869.790024
# day 297: buy 1 unit at price 104.349998, total balance 9765.440025
# day 298, sell 1 unit at price 104.040001, investment 0.999902 %, total balance 9869.480026,
# day 299, sell 1 unit at price 104.389999, investment 0.038333 %, total balance 9973.870026,
# day 302: buy 1 unit at price 107.190002, total balance 9866.680023
# day 303, sell 1 unit at price 106.800003, investment -0.363839 %, total balance 9973.480026,
# day 309: buy 1 unit at price 99.580002, total balance 9873.900024
# day 311, sell 1 unit at price 101.230003, investment 1.656961 %, total balance 9975.130028,
# day 312: buy 1 unit at price 104.639999, total balance 9870.490028
# day 313: buy 1 unit at price 105.139999, total balance 9765.350029
# day 314, sell 1 unit at price 105.349998, investment 0.678516 %, total balance 9870.700027,
# day 315, sell 1 unit at price 105.559998, investment 0.399466 %, total balance 9976.260025,
# day 322: buy 1 unit at price 109.940002, total balance 9866.320023
# day 323, sell 1 unit at price 111.099998, investment 1.055117 %, total balance 9977.420021,
# day 330: buy 1 unit at price 114.470001, total balance 9862.950020
# day 331: buy 1 unit at price 116.120003, total balance 9746.830017
# day 332, sell 1 unit at price 116.050003, investment 1.380276 %, total balance 9862.880020,
# day 333, sell 1 unit at price 115.160004, investment -0.826730 %, total balance 9978.040024,
# day 336: buy 1 unit at price 115.089996, total balance 9862.950027
# day 337, sell 1 unit at price 113.209999, investment -1.633502 %, total balance 9976.160027,
# day 339: buy 1 unit at price 112.519997, total balance 9863.640030
# day 340, sell 1 unit at price 112.510002, investment -0.008882 %, total balance 9976.150032,
# day 341: buy 1 unit at price 109.449997, total balance 9866.700035
# day 342, sell 1 unit at price 110.320000, investment 0.794886 %, total balance 9977.020035,
# day 343: buy 1 unit at price 109.900002, total balance 9867.120033
# day 344, sell 1 unit at price 111.309998, investment 1.282981 %, total balance 9978.430031,
# day 357: buy 1 unit at price 110.129997, total balance 9868.300034
# day 358: buy 1 unit at price 110.370003, total balance 9757.930031
# day 359, sell 1 unit at price 109.160004, investment -0.880771 %, total balance 9867.090034,
# day 360, sell 1 unit at price 110.339996, investment -0.027187 %, total balance 9977.430031,
# day 365: buy 1 unit at price 109.220001, total balance 9868.210030
# day 369, sell 1 unit at price 109.440002, investment 0.201429 %, total balance 9977.650032,
# day 376: buy 1 unit at price 113.800003, total balance 9863.850029
# day 377, sell 1 unit at price 112.820000, investment -0.861163 %, total balance 9976.670029,
# day 383: buy 1 unit at price 115.300003, total balance 9861.370026
# day 384, sell 1 unit at price 113.900002, investment -1.214225 %, total balance 9975.270027,
# day 387: buy 1 unit at price 114.669998, total balance 9860.600029
# day 388, sell 1 unit at price 113.540001, investment -0.985434 %, total balance 9974.140030,
# day 390: buy 1 unit at price 116.360001, total balance 9857.780029
# day 391, sell 1 unit at price 116.830002, investment 0.403920 %, total balance 9974.610031,
# day 394: buy 1 unit at price 115.849998, total balance 9858.760033
# day 395, sell 1 unit at price 115.589996, investment -0.224430 %, total balance 9974.350029,
# day 396: buy 1 unit at price 116.000000, total balance 9858.350029
# day 397, sell 1 unit at price 112.940002, investment -2.637929 %, total balance 9971.290031,
# day 404: buy 1 unit at price 107.680000, total balance 9863.610031
# day 405, sell 1 unit at price 109.339996, investment 1.541601 %, total balance 9972.950027,
# day 407: buy 1 unit at price 105.199997, total balance 9867.750031
# day 408, sell 1 unit at price 107.720001, investment 2.395441 %, total balance 9975.470032,
# day 409: buy 1 unit at price 108.690002, total balance 9866.780029
# day 410: buy 1 unit at price 107.309998, total balance 9759.470032
# day 411: buy 1 unit at price 107.610001, total balance 9651.860031
# day 412, sell 1 unit at price 108.720001, investment 0.027600 %, total balance 9760.580032,
# day 413: buy 1 unit at price 106.019997, total balance 9654.560036
# day 414, sell 1 unit at price 106.870003, investment -0.410022 %, total balance 9761.430038,
# day 416, sell 1 unit at price 106.800003, investment -0.752716 %, total balance 9868.230042,
# day 417, sell 1 unit at price 109.220001, investment 3.018303 %, total balance 9977.450043,
# day 421: buy 1 unit at price 112.370003, total balance 9865.080040
# day 423, sell 1 unit at price 115.400002, investment 2.696448 %, total balance 9980.480042,
# day 425: buy 1 unit at price 117.190002, total balance 9863.290039
# day 427: buy 1 unit at price 120.230003, total balance 9743.060036
# day 428, sell 1 unit at price 119.160004, investment 1.681032 %, total balance 9862.220039,
# day 430, sell 1 unit at price 119.760002, investment -0.390918 %, total balance 9981.980042,
# day 438: buy 1 unit at price 117.690002, total balance 9864.290039
# day 439, sell 1 unit at price 115.550003, investment -1.818336 %, total balance 9979.840042,
# day 441: buy 1 unit at price 112.190002, total balance 9867.650040
# day 442, sell 1 unit at price 114.620003, investment 2.165969 %, total balance 9982.270042,
# day 445: buy 1 unit at price 112.629997, total balance 9869.640045
# day 447, sell 1 unit at price 116.139999, investment 3.116401 %, total balance 9985.780045,
# day 450: buy 1 unit at price 119.680000, total balance 9866.100044
# day 451: buy 1 unit at price 120.349998, total balance 9745.750046
# day 452, sell 1 unit at price 120.559998, investment 0.735292 %, total balance 9866.310043,
# day 453: buy 1 unit at price 123.550003, total balance 9742.760040
# day 456: buy 1 unit at price 125.029999, total balance 9617.730042
# day 457, sell 1 unit at price 126.029999, investment 4.719568 %, total balance 9743.760040,
# day 458, sell 1 unit at price 126.510002, investment 2.395790 %, total balance 9870.270042,
# day 459, sell 1 unit at price 126.430000, investment 1.119732 %, total balance 9996.700043,
# day 462: buy 1 unit at price 127.800003, total balance 9868.900040
# day 464: buy 1 unit at price 129.100006, total balance 9739.800034
# day 465, sell 1 unit at price 129.300003, investment 1.173709 %, total balance 9869.100037,
# day 466: buy 1 unit at price 130.000000, total balance 9739.100037
# day 467: buy 1 unit at price 130.380005, total balance 9608.720032
# day 468, sell 1 unit at price 129.919998, investment 0.635160 %, total balance 9738.640030,
# day 469, sell 1 unit at price 129.160004, investment -0.646151 %, total balance 9867.800034,
# day 470: buy 1 unit at price 128.479996, total balance 9739.320038
# day 474: buy 1 unit at price 130.580002, total balance 9608.740036
# day 475, sell 1 unit at price 129.630005, investment -0.575242 %, total balance 9738.370041,
# day 476: buy 1 unit at price 129.929993, total balance 9608.440048
# day 477, sell 1 unit at price 130.789993, investment 1.797943 %, total balance 9739.230042,
# day 478, sell 1 unit at price 131.490005, investment 0.696894 %, total balance 9870.720047,
# day 479, sell 1 unit at price 131.669998, investment 1.339187 %, total balance 10002.390045,
# day 482: buy 1 unit at price 131.470001, total balance 9870.920044
# day 484, sell 1 unit at price 132.339996, investment 0.661744 %, total balance 10003.260040,
# day 485: buy 1 unit at price 133.059998, total balance 9870.200043
# day 486, sell 1 unit at price 135.039993, investment 1.488047 %, total balance 10005.240036,
# day 500: buy 1 unit at price 139.139999, total balance 9866.100037
# day 501, sell 1 unit at price 138.630005, investment -0.366533 %, total balance 10004.730042,
# day 511: buy 1 unit at price 138.800003, total balance 9865.930038
# day 512, sell 1 unit at price 136.720001, investment -1.498560 %, total balance 10002.650040,
# day 514: buy 1 unit at price 138.199997, total balance 9864.450043
# day 515, sell 1 unit at price 136.839996, investment -0.984082 %, total balance 10001.290039,
# day 520: buy 1 unit at price 134.429993, total balance 9866.860046
# day 521, sell 1 unit at price 134.229996, investment -0.148774 %, total balance 10001.090042,
# day 522: buy 1 unit at price 135.889999, total balance 9865.200043
# day 523: buy 1 unit at price 132.360001, total balance 9732.840042
# day 524: buy 1 unit at price 133.369995, total balance 9599.470047
# day 525, sell 1 unit at price 135.289993, investment -0.441538 %, total balance 9734.760040,
# day 526, sell 1 unit at price 137.589996, investment 3.951342 %, total balance 9872.350037,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig('output/'+name+'.png')
plt.show()

# %% [markdown]
# ### 3.11 DOUBLE DUEL RECURRENT Q LEARNING AGENT

# %%
## Double Duel Recurrent Q-learning agent

from collections import deque
import random

df= df_full.copy()
name = 'Double Duel Recurrent Q-learning agent'

class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate, name):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, None, input_size))
            self.Y = tf.placeholder(tf.float32, (None, output_size))
            cell = tf.nn.rnn_cell.LSTMCell(layer_size, state_is_tuple = False)
            self.hidden_layer = tf.placeholder(tf.float32, (None, 2 * layer_size))
            self.rnn,self.last_state = tf.nn.dynamic_rnn(inputs=self.X,cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
            tensor_action, tensor_validation = tf.split(self.rnn[:,-1],2,1)
            feed_action = tf.layers.dense(tensor_action, output_size)
            feed_validation = tf.layers.dense(tensor_validation, 1)
            self.logits = feed_validation + tf.subtract(feed_action,tf.reduce_mean(feed_action,axis=1,keep_dims=True))
            self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
            self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.INITIAL_FEATURES = np.zeros((4, self.state_size))
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE,
                           'real_model')
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE,
                                   'negative_model')
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        self.trainable = tf.trainable_variables()
    
    def _assign(self, from_name, to_name):
        from_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=from_name)
        to_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=to_name)
        for i in range(len(from_w)):
            assign_op = to_w[i].assign(from_w[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, dead, rnn_state):
        self.MEMORIES.append((state, action, reward, new_state, dead, rnn_state))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        init_values = np.array([a[-1] for a in replay])
        Q = self.sess.run(self.model.logits, feed_dict={self.model.X:states, 
                                                   self.model.hidden_layer:init_values})
        Q_new = self.sess.run(self.model.logits, feed_dict={self.model.X:new_states, 
                                                       self.model.hidden_layer:init_values})
        Q_new_negative = self.sess.run(self.model_negative.logits, 
                                  feed_dict={self.model_negative.X:new_states, 
                                             self.model_negative.hidden_layer:init_values})
        replay_size = len(replay)
        X = np.empty((replay_size, 4, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        INIT_VAL = np.empty((replay_size, 2 * self.LAYER_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, dead_r, rnn_memory = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not dead_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
            INIT_VAL[i] = rnn_memory
        return X, Y, INIT_VAL
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        init_value = np.zeros((1, 2 * self.LAYER_SIZE))
        for k in range(self.INITIAL_FEATURES.shape[0]):
            self.INITIAL_FEATURES[k,:] = state
        for t in range(0, len(self.trend) - 1, self.skip):
            action, last_state = self.sess.run([self.model.logits,self.model.last_state],
                                                feed_dict={self.model.X:[self.INITIAL_FEATURES],
                                                            self.model.hidden_layer:init_value})
            action, init_value = np.argmax(action[0]), last_state
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
            self.INITIAL_FEATURES = new_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            init_value = np.zeros((1, 2 * self.LAYER_SIZE))
            for k in range(self.INITIAL_FEATURES.shape[0]):
                self.INITIAL_FEATURES[k,:] = state
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign('real_model', 'negative_model')
                
                if np.random.rand() < self.EPSILON:
                    action = np.random.randint(self.OUTPUT_SIZE)
                else:
                    action, last_state = self.sess.run([self.model.logits,
                                                  self.model.last_state],
                                                  feed_dict={self.model.X:[self.INITIAL_FEATURES],
                                                             self.model.hidden_layer:init_value})
                    action, init_value = np.argmax(action[0]), last_state
                    
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
                
                self._memorize(self.INITIAL_FEATURES, action, invest, new_state, 
                               starting_money < initial_money, init_value[0])
                self.INITIAL_FEATURES = new_state
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                X, Y, INIT_VAL = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.model.cost, self.model.optimizer], 
                                        feed_dict={self.model.X: X, self.model.Y:Y,
                                                  self.model.hidden_layer: INIT_VAL})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 20, checkpoint = 10, initial_money = initial_money)

states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000027493829C18>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000027493829828>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# D:\Program Files\Anaconda\lib\site-packages\tensorflow\python\client\session.py:1702: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch: 10, total rewards: 377.289970.3, cost: 0.002301, total money: 9017.790001
# epoch: 20, total rewards: 432.799965.3, cost: 0.009770, total money: 6269.909981
# day 0: buy 1 unit at price 107.949997, total balance 9892.050003
# day 1: buy 1 unit at price 108.059998, total balance 9783.990005
# day 2, sell 1 unit at price 109.040001, investment 1.009730 %, total balance 9893.030006,
# day 3, sell 1 unit at price 108.339996, investment 0.259114 %, total balance 10001.370003,
# day 29: buy 1 unit at price 112.430000, total balance 9888.940002
# day 30, sell 1 unit at price 115.029999, investment 2.312549 %, total balance 10003.970001,
# day 32: buy 1 unit at price 114.680000, total balance 9889.290001
# day 33, sell 1 unit at price 114.709999, investment 0.026159 %, total balance 10004.000000,
# day 59: buy 1 unit at price 108.000000, total balance 9896.000000
# day 60: buy 1 unit at price 109.970001, total balance 9786.029999
# day 61, sell 1 unit at price 107.849998, investment -0.138890 %, total balance 9893.879997,
# day 62, sell 1 unit at price 109.330002, investment -0.581976 %, total balance 10003.209999,
# day 68: buy 1 unit at price 110.620003, total balance 9892.589996
# day 69, sell 1 unit at price 113.370003, investment 2.485988 %, total balance 10005.959999,
# day 70: buy 1 unit at price 110.300003, total balance 9895.659996
# day 71, sell 1 unit at price 110.209999, investment -0.081599 %, total balance 10005.869995,
# day 77: buy 1 unit at price 110.410004, total balance 9895.459991
# day 79, sell 1 unit at price 110.099998, investment -0.280776 %, total balance 10005.559990,
# day 83: buy 1 unit at price 107.919998, total balance 9897.639992
# day 84, sell 1 unit at price 107.239998, investment -0.630097 %, total balance 10004.879990,
# day 97: buy 1 unit at price 113.010002, total balance 9891.869987
# day 98, sell 1 unit at price 112.489998, investment -0.460140 %, total balance 10004.359985,
# day 100: buy 1 unit at price 110.660004, total balance 9893.699982
# day 101, sell 1 unit at price 105.930000, investment -4.274357 %, total balance 9999.629982,
# day 111: buy 1 unit at price 110.190002, total balance 9889.439980
# day 112, sell 1 unit at price 109.970001, investment -0.199656 %, total balance 9999.409981,
# day 117: buy 1 unit at price 107.540001, total balance 9891.869980
# day 118, sell 1 unit at price 107.510002, investment -0.027895 %, total balance 9999.379982,
# day 122: buy 1 unit at price 103.239998, total balance 9896.139984
# day 124: buy 1 unit at price 104.199997, total balance 9791.939987
# day 125, sell 1 unit at price 105.080002, investment 1.782259 %, total balance 9897.019989,
# day 126, sell 1 unit at price 103.610001, investment -0.566215 %, total balance 10000.629990,
# day 131: buy 1 unit at price 106.389999, total balance 9894.239990
# day 132, sell 1 unit at price 106.849998, investment 0.432371 %, total balance 10001.089989,
# day 135: buy 1 unit at price 110.500000, total balance 9890.589989
# day 136: buy 1 unit at price 111.529999, total balance 9779.059990
# day 137, sell 1 unit at price 109.889999, investment -0.552037 %, total balance 9888.949989,
# day 139, sell 1 unit at price 113.349998, investment 1.631848 %, total balance 10002.299988,
# day 142: buy 1 unit at price 114.849998, total balance 9887.449989
# day 143, sell 1 unit at price 116.029999, investment 1.027427 %, total balance 10003.479988,
# day 150: buy 1 unit at price 117.550003, total balance 9885.929985
# day 151, sell 1 unit at price 117.790001, investment 0.204167 %, total balance 10003.719986,
# day 155: buy 1 unit at price 114.650002, total balance 9889.069984
# day 156, sell 1 unit at price 113.699997, investment -0.828613 %, total balance 10002.769981,
# day 164: buy 1 unit at price 116.709999, total balance 9886.059982
# day 165: buy 1 unit at price 116.139999, total balance 9769.919983
# day 166: buy 1 unit at price 115.760002, total balance 9654.159981
# day 167, sell 1 unit at price 115.190002, investment -1.302371 %, total balance 9769.349983,
# day 168, sell 1 unit at price 114.580002, investment -1.343204 %, total balance 9883.929985,
# day 169, sell 1 unit at price 115.150002, investment -0.526953 %, total balance 9999.079987,
# day 172: buy 1 unit at price 114.320000, total balance 9884.759987
# day 173, sell 1 unit at price 113.709999, investment -0.533590 %, total balance 9998.469986,
# day 217: buy 1 unit at price 111.290001, total balance 9887.179985
# day 219, sell 1 unit at price 109.589996, investment -1.527545 %, total balance 9996.769981,
# day 242: buy 1 unit at price 98.540001, total balance 9898.229980
# day 243: buy 1 unit at price 97.290001, total balance 9800.939980
# day 244, sell 1 unit at price 96.449997, investment -2.120970 %, total balance 9897.389977,
# day 245: buy 1 unit at price 94.169998, total balance 9803.219978
# day 248, sell 1 unit at price 97.040001, investment -0.256964 %, total balance 9900.259979,
# day 249: buy 1 unit at price 96.830002, total balance 9803.429977
# day 250, sell 1 unit at price 97.620003, investment 3.663592 %, total balance 9901.049980,
# day 251, sell 1 unit at price 99.309998, investment 2.561185 %, total balance 10000.359978,
# day 253: buy 1 unit at price 100.690002, total balance 9899.669975
# day 254, sell 1 unit at price 100.760002, investment 0.069520 %, total balance 10000.429977,
# day 273: buy 1 unit at price 104.250000, total balance 9896.179977
# day 274, sell 1 unit at price 103.790001, investment -0.441246 %, total balance 9999.969978,
# day 326: buy 1 unit at price 113.599998, total balance 9886.369980
# day 327: buy 1 unit at price 113.739998, total balance 9772.629982
# day 328, sell 1 unit at price 113.550003, investment -0.044010 %, total balance 9886.179985,
# day 329, sell 1 unit at price 113.610001, investment -0.114293 %, total balance 9999.789986,
# day 371: buy 1 unit at price 107.760002, total balance 9892.029984
# day 372: buy 1 unit at price 108.480003, total balance 9783.549980
# day 373, sell 1 unit at price 108.839996, investment 1.002222 %, total balance 9892.389977,
# day 374, sell 1 unit at price 111.800003, investment 3.060472 %, total balance 10004.189980,
# day 382: buy 1 unit at price 114.099998, total balance 9890.089981
# day 383, sell 1 unit at price 115.300003, investment 1.051713 %, total balance 10005.389984,
# day 416: buy 1 unit at price 106.800003, total balance 9898.589981
# day 418, sell 1 unit at price 109.860001, investment 2.865166 %, total balance 10008.449982,
# day 450: buy 1 unit at price 119.680000, total balance 9888.769981
# day 451: buy 1 unit at price 120.349998, total balance 9768.419983
# day 452, sell 1 unit at price 120.559998, investment 0.735292 %, total balance 9888.979980,
# day 453, sell 1 unit at price 123.550003, investment 2.658915 %, total balance 10012.529984,
# day 516: buy 1 unit at price 136.679993, total balance 9875.849991
# day 517, sell 1 unit at price 136.539993, investment -0.102429 %, total balance 10012.389984,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig('output/'+name+'.png')
plt.show()

# %% [markdown]
# ## 3.12 ACTOR-CRITIC DUEL AGENT

# %%
## Actor-critic Duel agent

from collections import deque
import random

df= df_full.copy()
name = 'Actor-critic Duel agent'

class Actor:
    def __init__(self, name, input_size, output_size, size_layer):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, input_size))
            feed_actor = tf.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            tensor_action, tensor_validation = tf.split(feed_actor,2,1)
            feed_action = tf.layers.dense(tensor_action, output_size)
            feed_validation = tf.layers.dense(tensor_validation, 1)
            self.logits = feed_validation + tf.subtract(feed_action,
                                                        tf.reduce_mean(feed_action,axis=1,keep_dims=True))

class Critic:
    def __init__(self, name, input_size, output_size, size_layer, learning_rate):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, input_size))
            self.Y = tf.placeholder(tf.float32, (None, output_size))
            self.REWARD = tf.placeholder(tf.float32, (None, 1))
            feed_critic = tf.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            tensor_action, tensor_validation = tf.split(feed_critic,2,1)
            feed_action = tf.layers.dense(tensor_action, output_size)
            feed_validation = tf.layers.dense(tensor_validation, 1)
            feed_critic = feed_validation + tf.subtract(feed_action,tf.reduce_mean(feed_action,axis=1,keep_dims=True))
            feed_critic = tf.nn.relu(feed_critic) + self.Y
            feed_critic = tf.layers.dense(feed_critic, size_layer//2, activation = tf.nn.relu)
            self.logits = tf.layers.dense(feed_critic, 1)
            self.cost = tf.reduce_mean(tf.square(self.REWARD - self.logits))
            self.optimizer = tf.train.AdamOptimizer(learning_rate).minimize(self.cost)
            
class Agent:

    LEARNING_RATE = 0.001
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    MEMORY_SIZE = 300
    COPY = 1000
    T_COPY = 0

    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.actor = Actor('actor-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.actor_target = Actor('actor-target', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.critic = Critic('critic-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.critic_target = Critic('critic-target', self.state_size, self.OUTPUT_SIZE, 
                                    self.LAYER_SIZE, self.LEARNING_RATE)
        self.grad_critic = tf.gradients(self.critic.logits, self.critic.Y)
        self.actor_critic_grad = tf.placeholder(tf.float32, [None, self.OUTPUT_SIZE])
        weights_actor = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope='actor')
        self.grad_actor = tf.gradients(self.actor.logits, weights_actor, -self.actor_critic_grad)
        grads = zip(self.grad_actor, weights_actor)
        self.optimizer = tf.train.AdamOptimizer(self.LEARNING_RATE).apply_gradients(grads)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def _assign(self, from_name, to_name):
        from_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=from_name)
        to_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=to_name)
        for i in range(len(from_w)):
            assign_op = to_w[i].assign(from_w[i])
            self.sess.run(assign_op)
            
    def _memorize(self, state, action, reward, new_state, dead):
        self.MEMORIES.append((state, action, reward, new_state, dead))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()
            
    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            prediction = self.sess.run(self.actor.logits, feed_dict={self.actor.X:[state]})[0]
            action = np.argmax(prediction)
        return action
    
    def _construct_memories_and_train(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.sess.run(self.actor.logits, feed_dict={self.actor.X: states})
        Q_target = self.sess.run(self.actor_target.logits, feed_dict={self.actor_target.X: states})
        grads = self.sess.run(self.grad_critic, feed_dict={self.critic.X:states, self.critic.Y:Q})[0]
        self.sess.run(self.optimizer, feed_dict={self.actor.X:states, self.actor_critic_grad:grads})
        
        rewards = np.array([a[2] for a in replay]).reshape((-1, 1))
        rewards_target = self.sess.run(self.critic_target.logits, 
                                       feed_dict={self.critic_target.X:new_states,self.critic_target.Y:Q_target})
        for i in range(len(replay)):
            if not replay[0][-1]:
                rewards[i] += self.GAMMA * rewards_target[i]
        cost, _ = self.sess.run([self.critic.cost, self.critic.optimizer], 
                                feed_dict={self.critic.X:states, self.critic.Y:Q, self.critic.REWARD:rewards})
        return cost
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign('actor-original', 'actor-target')
                    self._assign('critic-original', 'critic-target')
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                state = next_state
                replay = random.sample(self.MEMORIES, batch_size)
                cost = self._construct_memories_and_train(replay)
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 20, checkpoint = 10, initial_money = initial_money)

states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# D:\Program Files\Anaconda\lib\site-packages\tensorflow\python\client\session.py:1702: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch: 10, total rewards: 387.049980.3, cost: 0.002153, total money: 8882.400017
# epoch: 20, total rewards: 325.980011.3, cost: 0.001460, total money: 8416.180023
# day 0: buy 1 unit at price 107.949997, total balance 9892.050003
# day 1: buy 1 unit at price 108.059998, total balance 9783.990005
# day 2, sell 1 unit at price 109.040001, investment 1.009730 %, total balance 9893.030006,
# day 4: buy 1 unit at price 108.500000, total balance 9784.530006
# day 5, sell 1 unit at price 109.050003, investment 0.916163 %, total balance 9893.580009,
# day 6, sell 1 unit at price 110.250000, investment 1.612903 %, total balance 10003.830009,
# day 9: buy 1 unit at price 112.269997, total balance 9891.560013
# day 12, sell 1 unit at price 113.010002, investment 0.659130 %, total balance 10004.570015,
# day 16: buy 1 unit at price 115.699997, total balance 9888.870018
# day 18: buy 1 unit at price 116.199997, total balance 9772.670021
# day 19, sell 1 unit at price 115.110001, investment -0.509936 %, total balance 9887.780022,
# day 20: buy 1 unit at price 115.669998, total balance 9772.110023
# day 24, sell 1 unit at price 112.110001, investment -3.519790 %, total balance 9884.220024,
# day 25, sell 1 unit at price 112.870003, investment -2.420676 %, total balance 9997.090027,
# day 27: buy 1 unit at price 110.040001, total balance 9887.050026
# day 28, sell 1 unit at price 111.739998, investment 1.544890 %, total balance 9998.790024,
# day 29: buy 1 unit at price 112.430000, total balance 9886.360023
# day 30, sell 1 unit at price 115.029999, investment 2.312549 %, total balance 10001.390022,
# day 31: buy 1 unit at price 115.510002, total balance 9885.880020
# day 32: buy 1 unit at price 114.680000, total balance 9771.200020
# day 33: buy 1 unit at price 114.709999, total balance 9656.490021
# day 35, sell 1 unit at price 114.980003, investment -0.458834 %, total balance 9771.470024,
# day 38, sell 1 unit at price 117.360001, investment 2.336938 %, total balance 9888.830025,
# day 39: buy 1 unit at price 115.500000, total balance 9773.330025
# day 40: buy 1 unit at price 113.430000, total balance 9659.900024
# day 42, sell 1 unit at price 115.059998, investment 0.305116 %, total balance 9774.960022,
# day 47: buy 1 unit at price 117.660004, total balance 9657.300018
# day 48: buy 1 unit at price 116.250000, total balance 9541.050018
# day 50, sell 1 unit at price 115.239998, investment -0.225110 %, total balance 9656.290016,
# day 51, sell 1 unit at price 115.440002, investment 1.772020 %, total balance 9771.730019,
# day 52: buy 1 unit at price 114.529999, total balance 9657.200020
# day 53: buy 1 unit at price 114.639999, total balance 9542.560020
# day 55, sell 1 unit at price 109.949997, investment -6.552785 %, total balance 9652.510017,
# day 56: buy 1 unit at price 107.010002, total balance 9545.500015
# day 59, sell 1 unit at price 108.000000, investment -7.096774 %, total balance 9653.500015,
# day 65, sell 1 unit at price 109.089996, investment -4.749849 %, total balance 9762.590012,
# day 66, sell 1 unit at price 110.400002, investment -3.698533 %, total balance 9872.990013,
# day 68, sell 1 unit at price 110.620003, investment 3.373517 %, total balance 9983.610016,
# day 76: buy 1 unit at price 110.930000, total balance 9872.680016
# day 77, sell 1 unit at price 110.410004, investment -0.468761 %, total balance 9983.090019,
# day 78: buy 1 unit at price 109.989998, total balance 9873.100021
# day 79: buy 1 unit at price 110.099998, total balance 9763.000023
# day 80, sell 1 unit at price 109.400002, investment -0.536409 %, total balance 9872.400024,
# day 83, sell 1 unit at price 107.919998, investment -1.980018 %, total balance 9980.320023,
# day 84: buy 1 unit at price 107.239998, total balance 9873.080025
# day 85, sell 1 unit at price 108.430000, investment 1.109663 %, total balance 9981.510025,
# day 89: buy 1 unit at price 114.290001, total balance 9867.220024
# day 90, sell 1 unit at price 113.860001, investment -0.376236 %, total balance 9981.080025,
# day 92: buy 1 unit at price 113.029999, total balance 9868.050026
# day 94: buy 1 unit at price 112.959999, total balance 9755.090027
# day 95: buy 1 unit at price 111.129997, total balance 9643.960030
# day 96: buy 1 unit at price 112.150002, total balance 9531.810028
# day 97: buy 1 unit at price 113.010002, total balance 9418.800026
# day 98: buy 1 unit at price 112.489998, total balance 9306.310028
# day 100, sell 1 unit at price 110.660004, investment -2.096784 %, total balance 9416.970032,
# day 101: buy 1 unit at price 105.930000, total balance 9311.040031
# day 103: buy 1 unit at price 107.010002, total balance 9204.030029
# day 104, sell 1 unit at price 108.400002, investment -4.036825 %, total balance 9312.430031,
# day 106, sell 1 unit at price 107.839996, investment -2.960498 %, total balance 9420.270027,
# day 110, sell 1 unit at price 110.830002, investment -1.176995 %, total balance 9531.100029,
# day 112, sell 1 unit at price 109.970001, investment -2.690028 %, total balance 9641.070030,
# day 113: buy 1 unit at price 108.029999, total balance 9533.040031
# day 114: buy 1 unit at price 107.900002, total balance 9425.140030
# day 115, sell 1 unit at price 108.180000, investment -3.831450 %, total balance 9533.320030,
# day 116, sell 1 unit at price 107.550003, investment 1.529314 %, total balance 9640.870033,
# day 120: buy 1 unit at price 104.790001, total balance 9536.080032
# day 124, sell 1 unit at price 104.199997, investment -2.625928 %, total balance 9640.280029,
# day 125: buy 1 unit at price 105.080002, total balance 9535.200027
# day 127, sell 1 unit at price 103.720001, investment -3.989630 %, total balance 9638.920029,
# day 129, sell 1 unit at price 107.279999, investment -0.574609 %, total balance 9746.200027,
# day 130: buy 1 unit at price 106.620003, total balance 9639.580025
# day 132: buy 1 unit at price 106.849998, total balance 9532.730026
# day 133: buy 1 unit at price 106.360001, total balance 9426.370026
# day 134: buy 1 unit at price 110.580002, total balance 9315.790024
# day 135, sell 1 unit at price 110.500000, investment 5.448992 %, total balance 9426.290024,
# day 136, sell 1 unit at price 111.529999, investment 6.138177 %, total balance 9537.820023,
# day 137, sell 1 unit at price 109.889999, investment 3.066964 %, total balance 9647.710022,
# day 138, sell 1 unit at price 111.279999, investment 4.145999 %, total balance 9758.990021,
# day 139: buy 1 unit at price 113.349998, total balance 9645.640022
# day 140, sell 1 unit at price 114.150002, investment 7.324183 %, total balance 9759.790024,
# day 141, sell 1 unit at price 115.180000, investment 4.159883 %, total balance 9874.970024,
# day 142, sell 1 unit at price 114.849998, investment 1.323335 %, total balance 9989.820023,
# day 143: buy 1 unit at price 116.029999, total balance 9873.790024
# day 144: buy 1 unit at price 116.730003, total balance 9757.060020
# day 146, sell 1 unit at price 115.660004, investment -0.318879 %, total balance 9872.720024,
# day 147, sell 1 unit at price 116.150002, investment -0.496875 %, total balance 9988.870026,
# day 151: buy 1 unit at price 117.790001, total balance 9871.080025
# day 152: buy 1 unit at price 116.879997, total balance 9754.200027
# day 154, sell 1 unit at price 113.889999, investment -3.310978 %, total balance 9868.090027,
# day 156, sell 1 unit at price 113.699997, investment -2.720740 %, total balance 9981.790024,
# day 157: buy 1 unit at price 114.769997, total balance 9867.020027
# day 158, sell 1 unit at price 114.769997, investment 0.000000 %, total balance 9981.790024,
# day 159: buy 1 unit at price 114.620003, total balance 9867.170021
# day 160: buy 1 unit at price 115.320000, total balance 9751.850021
# day 161: buy 1 unit at price 114.970001, total balance 9636.880020
# day 164, sell 1 unit at price 116.709999, investment 1.823413 %, total balance 9753.590019,
# day 165, sell 1 unit at price 116.139999, investment 0.711065 %, total balance 9869.730019,
# day 166, sell 1 unit at price 115.760002, investment 0.687137 %, total balance 9985.490021,
# day 173: buy 1 unit at price 113.709999, total balance 9871.780022
# day 174, sell 1 unit at price 114.430000, investment 0.633191 %, total balance 9986.210022,
# day 176: buy 1 unit at price 113.519997, total balance 9872.690025
# day 177: buy 1 unit at price 113.500000, total balance 9759.190025
# day 178: buy 1 unit at price 113.839996, total balance 9645.350029
# day 180: buy 1 unit at price 117.620003, total balance 9527.730026
# day 181, sell 1 unit at price 118.629997, investment 4.501410 %, total balance 9646.360023,
# day 183: buy 1 unit at price 116.720001, total balance 9529.640022
# day 184: buy 1 unit at price 116.389999, total balance 9413.250023
# day 186, sell 1 unit at price 114.519997, investment 0.898675 %, total balance 9527.770020,
# day 187: buy 1 unit at price 112.839996, total balance 9414.930023
# day 188: buy 1 unit at price 113.500000, total balance 9301.430023
# day 189: buy 1 unit at price 113.970001, total balance 9187.460022
# day 190, sell 1 unit at price 115.040001, investment 1.054115 %, total balance 9302.500023,
# day 193, sell 1 unit at price 115.320000, investment -1.955452 %, total balance 9417.820023,
# day 194: buy 1 unit at price 114.519997, total balance 9303.300026
# day 195: buy 1 unit at price 111.470001, total balance 9191.830025
# day 196: buy 1 unit at price 108.129997, total balance 9083.700027
# day 197, sell 1 unit at price 106.949997, investment -8.370463 %, total balance 9190.650024,
# day 198: buy 1 unit at price 106.339996, total balance 9084.310028
# day 200: buy 1 unit at price 109.830002, total balance 8974.480026
# day 201, sell 1 unit at price 108.089996, investment -7.131199 %, total balance 9082.570023,
# day 202: buy 1 unit at price 107.910004, total balance 8974.660019
# day 203, sell 1 unit at price 106.360001, investment -5.742641 %, total balance 9081.020020,
# day 204, sell 1 unit at price 105.250000, investment -7.268722 %, total balance 9186.270020,
# day 205, sell 1 unit at price 103.290001, investment -9.370887 %, total balance 9289.560020,
# day 208: buy 1 unit at price 104.849998, total balance 9184.710022
# day 209, sell 1 unit at price 106.699997, investment -6.828502 %, total balance 9291.410019,
# day 210: buy 1 unit at price 109.019997, total balance 9182.390022
# day 212, sell 1 unit at price 108.379997, investment -2.772050 %, total balance 9290.770020,
# day 215, sell 1 unit at price 111.480003, investment 3.098128 %, total balance 9402.250023,
# day 216: buy 1 unit at price 112.379997, total balance 9289.870026
# day 218: buy 1 unit at price 108.949997, total balance 9180.920029
# day 220: buy 1 unit at price 107.330002, total balance 9073.590027
# day 221: buy 1 unit at price 110.070000, total balance 8963.520027
# day 223: buy 1 unit at price 110.830002, total balance 8852.690025
# day 224: buy 1 unit at price 108.449997, total balance 8744.240028
# day 226: buy 1 unit at price 106.650002, total balance 8637.590027
# day 227: buy 1 unit at price 109.260002, total balance 8528.330025
# day 229: buy 1 unit at price 110.940002, total balance 8417.390022
# day 230: buy 1 unit at price 110.059998, total balance 8307.330025
# day 231: buy 1 unit at price 111.190002, total balance 8196.140022
# day 232: buy 1 unit at price 112.239998, total balance 8083.900024
# day 235: buy 1 unit at price 103.290001, total balance 7980.610023
# day 239, sell 1 unit at price 101.120003, investment -4.908777 %, total balance 8081.730026,
# day 246: buy 1 unit at price 92.139999, total balance 7989.590027
# day 248: buy 1 unit at price 97.040001, total balance 7892.550026
# day 249: buy 1 unit at price 96.830002, total balance 7795.720024
# day 250: buy 1 unit at price 97.620003, total balance 7698.100021
# day 251: buy 1 unit at price 99.309998, total balance 7598.790024
# day 252, sell 1 unit at price 97.110001, investment -11.581536 %, total balance 7695.900024,
# day 253: buy 1 unit at price 100.690002, total balance 7595.210022
# day 255, sell 1 unit at price 100.570000, investment -6.801968 %, total balance 7695.780022,
# day 259, sell 1 unit at price 100.940002, investment -3.729133 %, total balance 7796.720024,
# day 260, sell 1 unit at price 101.680000, investment -6.732706 %, total balance 7898.400024,
# day 263: buy 1 unit at price 104.589996, total balance 7793.810028
# day 264: buy 1 unit at price 102.940002, total balance 7690.870026
# day 265, sell 1 unit at price 102.680000, investment -8.631427 %, total balance 7793.550026,
# day 266, sell 1 unit at price 102.739998, investment -5.699862 %, total balance 7896.290024,
# day 268: buy 1 unit at price 103.879997, total balance 7792.410027
# day 270: buy 1 unit at price 104.410004, total balance 7688.000023
# day 273: buy 1 unit at price 104.250000, total balance 7583.750023
# day 274: buy 1 unit at price 103.790001, total balance 7479.960022
# day 275: buy 1 unit at price 103.739998, total balance 7376.220024
# day 276, sell 1 unit at price 102.379997, investment -4.611949 %, total balance 7478.600021,
# day 277: buy 1 unit at price 101.360001, total balance 7377.240021
# day 279: buy 1 unit at price 102.599998, total balance 7274.640022
# day 282: buy 1 unit at price 105.550003, total balance 7169.090019
# day 283: buy 1 unit at price 105.180000, total balance 7063.910019
# day 284, sell 1 unit at price 105.690002, investment -3.979283 %, total balance 7169.600021,
# day 286, sell 1 unit at price 105.000000, investment -5.260310 %, total balance 7274.600021,
# day 289, sell 1 unit at price 105.160004, investment -3.033650 %, total balance 7379.760025,
# day 290: buy 1 unit at price 104.360001, total balance 7275.400024
# day 292, sell 1 unit at price 104.190002, investment -2.306610 %, total balance 7379.590027,
# day 293: buy 1 unit at price 104.110001, total balance 7275.480026
# day 294: buy 1 unit at price 103.720001, total balance 7171.760025
# day 297: buy 1 unit at price 104.349998, total balance 7067.410027
# day 298, sell 1 unit at price 104.040001, investment -4.777596 %, total balance 7171.450027,
# day 299: buy 1 unit at price 104.389999, total balance 7067.060028
# day 300: buy 1 unit at price 105.339996, total balance 6961.720032
# day 301: buy 1 unit at price 106.550003, total balance 6855.170029
# day 302, sell 1 unit at price 107.190002, investment -3.380205 %, total balance 6962.360031,
# day 303, sell 1 unit at price 106.800003, investment -2.962016 %, total balance 7069.160034,
# day 304: buy 1 unit at price 104.519997, total balance 6964.640038
# day 307: buy 1 unit at price 98.930000, total balance 6865.710037
# day 309: buy 1 unit at price 99.580002, total balance 6766.130035
# day 310: buy 1 unit at price 100.709999, total balance 6665.420036
# day 312: buy 1 unit at price 104.639999, total balance 6560.780037
# day 313: buy 1 unit at price 105.139999, total balance 6455.640038
# day 316: buy 1 unit at price 105.309998, total balance 6350.330040
# day 317, sell 1 unit at price 105.650002, investment -4.982463 %, total balance 6455.980042,
# day 319: buy 1 unit at price 105.339996, total balance 6350.640045
# day 321: buy 1 unit at price 111.209999, total balance 6239.430046
# day 322: buy 1 unit at price 109.940002, total balance 6129.490044
# day 325, sell 1 unit at price 113.459999, investment 1.086958 %, total balance 6242.950043,
# day 326, sell 1 unit at price 113.599998, investment 9.981603 %, total balance 6356.550041,
# day 327: buy 1 unit at price 113.739998, total balance 6242.810043
# day 330, sell 1 unit at price 114.470001, investment 24.234862 %, total balance 6357.280045,
# day 331, sell 1 unit at price 116.120003, investment 19.661997 %, total balance 6473.400047,
# day 335, sell 1 unit at price 116.120003, investment 19.921512 %, total balance 6589.520050,
# day 336, sell 1 unit at price 115.089996, investment 17.895916 %, total balance 6704.610046,
# day 337: buy 1 unit at price 113.209999, total balance 6591.400047
# day 338: buy 1 unit at price 112.610001, total balance 6478.790047
# day 339, sell 1 unit at price 112.519997, investment 13.301782 %, total balance 6591.310043,
# day 340, sell 1 unit at price 112.510002, investment 11.739000 %, total balance 6703.820045,
# day 342, sell 1 unit at price 110.320000, investment 5.478539 %, total balance 6814.140045,
# day 343, sell 1 unit at price 109.900002, investment 6.761219 %, total balance 6924.040047,
# day 345: buy 1 unit at price 110.769997, total balance 6813.270050
# day 347, sell 1 unit at price 111.730003, investment 7.556802 %, total balance 6925.000053,
# day 348: buy 1 unit at price 110.820000, total balance 6814.180054
# day 349, sell 1 unit at price 108.639999, investment 4.051332 %, total balance 6922.820053,
# day 350, sell 1 unit at price 109.709999, investment 5.237409 %, total balance 7032.530052,
# day 351, sell 1 unit at price 108.519997, investment 4.557275 %, total balance 7141.050049,
# day 353, sell 1 unit at price 107.059998, investment 3.200308 %, total balance 7248.110046,
# day 354: buy 1 unit at price 105.959999, total balance 7142.150047
# day 355: buy 1 unit at price 106.459999, total balance 7035.690048
# day 356: buy 1 unit at price 109.739998, total balance 6925.950050
# day 357, sell 1 unit at price 110.129997, investment 8.652325 %, total balance 7036.080048,
# day 358, sell 1 unit at price 110.370003, investment 7.573104 %, total balance 7146.450050,
# day 359: buy 1 unit at price 109.160004, total balance 7037.290047
# day 360, sell 1 unit at price 110.339996, investment 4.538127 %, total balance 7147.630043,
# day 361, sell 1 unit at price 110.680000, investment 5.229131 %, total balance 7258.310043,
# day 362: buy 1 unit at price 109.269997, total balance 7149.040047
# day 365, sell 1 unit at price 109.220001, investment 4.656957 %, total balance 7258.260048,
# day 366: buy 1 unit at price 110.709999, total balance 7147.550049
# day 367: buy 1 unit at price 109.910004, total balance 7037.640045
# day 369, sell 1 unit at price 109.440002, investment 5.119587 %, total balance 7147.080048,
# day 372, sell 1 unit at price 108.480003, investment 4.589281 %, total balance 7255.560051,
# day 374: buy 1 unit at price 111.800003, total balance 7143.760048
# day 376: buy 1 unit at price 113.800003, total balance 7029.960045
# day 377, sell 1 unit at price 112.820000, investment 8.116916 %, total balance 7142.780045,
# day 379: buy 1 unit at price 112.870003, total balance 7029.910042
# day 381, sell 1 unit at price 113.019997, investment 8.267073 %, total balance 7142.930038,
# day 382, sell 1 unit at price 114.099998, investment 8.315932 %, total balance 7257.030037,
# day 383: buy 1 unit at price 115.300003, total balance 7141.730034
# day 384: buy 1 unit at price 113.900002, total balance 7027.830032
# day 385, sell 1 unit at price 115.120003, investment 8.043172 %, total balance 7142.950035,
# day 386: buy 1 unit at price 113.989998, total balance 7028.960037
# day 387, sell 1 unit at price 114.669998, investment 9.711062 %, total balance 7143.630035,
# day 388: buy 1 unit at price 113.540001, total balance 7030.090034
# day 393: buy 1 unit at price 116.220001, total balance 6913.870033
# day 394, sell 1 unit at price 115.849998, investment 17.103000 %, total balance 7029.720032,
# day 396: buy 1 unit at price 116.000000, total balance 6913.720032
# day 397, sell 1 unit at price 112.940002, investment 13.416349 %, total balance 7026.660034,
# day 398: buy 1 unit at price 112.930000, total balance 6913.730034
# day 399: buy 1 unit at price 109.570000, total balance 6804.160034
# day 400, sell 1 unit at price 110.430000, investment 9.651476 %, total balance 6914.590034,
# day 401, sell 1 unit at price 108.029999, investment 3.239678 %, total balance 7022.620033,
# day 403: buy 1 unit at price 109.739998, total balance 6912.880035
# day 405, sell 1 unit at price 109.339996, investment 3.994671 %, total balance 7022.220032,
# day 406, sell 1 unit at price 104.800003, investment -0.484279 %, total balance 7127.020035,
# day 407: buy 1 unit at price 105.199997, total balance 7021.820038
# day 408, sell 1 unit at price 107.720001, investment 2.259355 %, total balance 7129.540039,
# day 409: buy 1 unit at price 108.690002, total balance 7020.850037
# day 411, sell 1 unit at price 107.610001, investment -3.237118 %, total balance 7128.460037,
# day 412: buy 1 unit at price 108.720001, total balance 7019.740036
# day 415: buy 1 unit at price 105.739998, total balance 6914.000038
# day 416, sell 1 unit at price 106.800003, investment -2.856103 %, total balance 7020.800041,
# day 417: buy 1 unit at price 109.220001, total balance 6911.580040
# day 418: buy 1 unit at price 109.860001, total balance 6801.720039
# day 422, sell 1 unit at price 112.610001, investment -0.993492 %, total balance 6914.330040,
# day 424: buy 1 unit at price 116.870003, total balance 6797.460037
# day 427: buy 1 unit at price 120.230003, total balance 6677.230034
# day 428: buy 1 unit at price 119.160004, total balance 6558.070030
# day 429, sell 1 unit at price 118.570000, investment 4.734565 %, total balance 6676.640030,
# day 430, sell 1 unit at price 119.760002, investment 6.349349 %, total balance 6796.400032,
# day 431: buy 1 unit at price 119.379997, total balance 6677.020035
# day 432: buy 1 unit at price 118.900002, total balance 6558.120033
# day 433, sell 1 unit at price 118.879997, investment 7.321478 %, total balance 6677.000031,
# day 434: buy 1 unit at price 117.330002, total balance 6559.670029
# day 435, sell 1 unit at price 118.000000, investment 6.478975 %, total balance 6677.670029,
# day 437: buy 1 unit at price 117.720001, total balance 6559.950027
# day 439, sell 1 unit at price 115.550003, investment 9.050589 %, total balance 6675.500031,
# day 440, sell 1 unit at price 113.250000, investment 6.377983 %, total balance 6788.750031,
# day 441, sell 1 unit at price 112.190002, investment 2.232554 %, total balance 6900.940033,
# day 443: buy 1 unit at price 114.370003, total balance 6786.570030
# day 444: buy 1 unit at price 111.820000, total balance 6674.750031
# day 445, sell 1 unit at price 112.629997, investment 3.178814 %, total balance 6787.380028,
# day 446: buy 1 unit at price 114.209999, total balance 6673.170029
# day 449: buy 1 unit at price 119.959999, total balance 6553.210030
# day 450: buy 1 unit at price 119.680000, total balance 6433.530029
# day 451, sell 1 unit at price 120.349998, investment 10.140022 %, total balance 6553.880028,
# day 454: buy 1 unit at price 124.790001, total balance 6429.090027
# day 455, sell 1 unit at price 125.120003, investment 13.015991 %, total balance 6554.210030,
# day 456, sell 1 unit at price 125.029999, investment 13.756705 %, total balance 6679.240028,
# day 459, sell 1 unit at price 126.430000, investment 13.085865 %, total balance 6805.670029,
# day 460: buy 1 unit at price 125.730003, total balance 6679.940025
# day 461, sell 1 unit at price 124.919998, investment 9.771524 %, total balance 6804.860023,
# day 462: buy 1 unit at price 127.800003, total balance 6677.060020
# day 464, sell 1 unit at price 129.100006, investment 14.379377 %, total balance 6806.160027,
# day 465: buy 1 unit at price 129.300003, total balance 6676.860023
# day 466: buy 1 unit at price 130.000000, total balance 6546.860023
# day 467, sell 1 unit at price 130.380005, investment 13.078926 %, total balance 6677.240028,
# day 472, sell 1 unit at price 129.529999, investment 13.722561 %, total balance 6806.770027,
# day 474: buy 1 unit at price 130.580002, total balance 6676.190025
# day 475: buy 1 unit at price 129.630005, total balance 6546.560020
# day 476, sell 1 unit at price 129.929993, investment 13.983678 %, total balance 6676.490013,
# day 477: buy 1 unit at price 130.789993, total balance 6545.700020
# day 478: buy 1 unit at price 131.490005, total balance 6414.210014
# day 479, sell 1 unit at price 131.669998, investment 15.967938 %, total balance 6545.880013,
# day 481: buy 1 unit at price 131.759995, total balance 6414.120018
# day 482: buy 1 unit at price 131.470001, total balance 6282.650017
# day 483: buy 1 unit at price 129.779999, total balance 6152.870018
# day 484: buy 1 unit at price 132.339996, total balance 6020.530022
# day 485: buy 1 unit at price 133.059998, total balance 5887.470024
# day 487: buy 1 unit at price 134.410004, total balance 5753.060020
# day 489, sell 1 unit at price 134.179993, investment 15.453443 %, total balance 5887.240013,
# day 490, sell 1 unit at price 138.020004, investment 18.982762 %, total balance 6025.260017,
# day 491: buy 1 unit at price 136.809998, total balance 5888.450020
# day 493, sell 1 unit at price 138.179993, investment 22.358977 %, total balance 6026.630013,
# day 494: buy 1 unit at price 138.039993, total balance 5888.590019
# day 495: buy 1 unit at price 137.350006, total balance 5751.240013
# day 499, sell 1 unit at price 139.039993, investment 26.896042 %, total balance 5890.280006,
# day 500, sell 1 unit at price 139.139999, investment 26.790598 %, total balance 6029.420006,
# day 501: buy 1 unit at price 138.630005, total balance 5890.790001
# day 502: buy 1 unit at price 139.399994, total balance 5751.390007
# day 503, sell 1 unit at price 141.089996, investment 34.115970 %, total balance 5892.480003,
# day 504: buy 1 unit at price 138.339996, total balance 5754.140007
# day 505: buy 1 unit at price 138.229996, total balance 5615.910011
# day 506: buy 1 unit at price 135.880005, total balance 5480.030006
# day 508, sell 1 unit at price 137.440002, investment 26.451375 %, total balance 5617.470009,
# day 509, sell 1 unit at price 136.070007, investment 25.156370 %, total balance 5753.540016,
# day 510, sell 1 unit at price 137.199997, investment 29.752222 %, total balance 5890.740013,
# day 511: buy 1 unit at price 138.800003, total balance 5751.940010
# day 512: buy 1 unit at price 136.720001, total balance 5615.220009
# day 513: buy 1 unit at price 137.250000, total balance 5477.970009
# day 515: buy 1 unit at price 136.839996, total balance 5341.130013
# day 518: buy 1 unit at price 133.149994, total balance 5207.980019
# day 519, sell 1 unit at price 132.029999, investment 20.884451 %, total balance 5340.010017,
# day 521: buy 1 unit at price 134.229996, total balance 5205.780022
# day 525: buy 1 unit at price 135.289993, total balance 5070.490028
# day 526, sell 1 unit at price 137.589996, investment 25.241212 %, total balance 5208.080025,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig('output/'+name+'.png')
plt.show()

# %% [markdown]
# ### 3.13 CURIOSITY Q-LEARNING AGENT

# %%
## Curiosity Q-learning agent

from collections import deque
import random


df= df_full.copy()
name = 'Curiosity Q-learning agent'

class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.X = tf.placeholder(tf.float32, (None, self.state_size))
        self.Y = tf.placeholder(tf.float32, (None, self.state_size))
        self.ACTION = tf.placeholder(tf.float32, (None))
        self.REWARD = tf.placeholder(tf.float32, (None))
        self.batch_size = tf.shape(self.ACTION)[0]
        
        with tf.variable_scope('curiosity_model'):
            action = tf.reshape(self.ACTION, (-1,1))
            state_action = tf.concat([self.X, action], axis=1)
            save_state = tf.identity(self.Y)
            
            feed = tf.layers.dense(state_action, 32, activation=tf.nn.relu)
            self.curiosity_logits = tf.layers.dense(feed, self.state_size)
            self.curiosity_cost = tf.reduce_sum(tf.square(save_state - self.curiosity_logits), axis=1)
            
            self.curiosity_optimizer = tf.train.RMSPropOptimizer(self.LEARNING_RATE)\
            .minimize(tf.reduce_mean(self.curiosity_cost))
        
        total_reward = tf.add(self.curiosity_cost, self.REWARD)
        
        with tf.variable_scope("q_model"):
            with tf.variable_scope("eval_net"):
                x_action = tf.layers.dense(self.X, 128, tf.nn.relu)
                self.logits = tf.layers.dense(x_action, self.OUTPUT_SIZE)
            
            with tf.variable_scope("target_net"):
                y_action = tf.layers.dense(self.Y, 128, tf.nn.relu)
                y_q = tf.layers.dense(y_action, self.OUTPUT_SIZE)
            
            q_target = total_reward + self.GAMMA * tf.reduce_max(y_q, axis=1)
            action = tf.cast(self.ACTION, tf.int32)
            action_indices = tf.stack([tf.range(self.batch_size, dtype=tf.int32), action], axis=1)
            q = tf.gather_nd(params=self.logits, indices=action_indices)
            self.cost = tf.losses.mean_squared_error(labels=q_target, predictions=q)
            self.optimizer = tf.train.RMSPropOptimizer(self.LEARNING_RATE).minimize(
            self.cost, var_list=tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, "q_model/eval_net"))
            
        t_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='q_model/target_net')
        e_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='q_model/eval_net')
        self.target_replace_op = [tf.assign(t, e) for t, e in zip(t_params, e_params)]
        
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()
            
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def predict(self, inputs):
        return self.sess.run(self.logits, feed_dict={self.X:inputs})
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action
    
    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        actions = np.array([a[1] for a in replay])
        rewards = np.array([a[2] for a in replay])
        new_states = np.array([a[3] for a in replay])
        if (self.T_COPY + 1) % self.COPY == 0:
            self.sess.run(self.target_replace_op)
            
        cost, _ = self.sess.run([self.cost, self.optimizer], feed_dict = {
            self.X: states, self.Y: new_states, self.ACTION: actions, self.REWARD: rewards
        })
        
        if (self.T_COPY + 1) % self.COPY == 0:
            self.sess.run(self.curiosity_optimizer, feed_dict = {
                self.X: states, self.Y: new_states, self.ACTION: actions, self.REWARD: rewards
            })
        return cost
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                state = next_state
                replay = random.sample(self.MEMORIES, batch_size)
                cost = self._construct_memories(replay)
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 100, checkpoint = 10, initial_money = initial_money)

states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# D:\Program Files\Anaconda\lib\site-packages\tensorflow\python\client\session.py:1702: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch: 10, total rewards: 314.109962.3, cost: 131.999481, total money: 7332.460014
# epoch: 20, total rewards: 489.180061.3, cost: 52.078110, total money: 6201.750076
# epoch: 30, total rewards: 445.950020.3, cost: 65.271889, total money: 5895.270065
# epoch: 40, total rewards: 504.949921.3, cost: 836.778503, total money: 4415.319946
# epoch: 50, total rewards: 350.099998.3, cost: 824.261841, total money: 9676.230019
# epoch: 60, total rewards: 593.629944.3, cost: 311.763977, total money: 6096.509933
# epoch: 70, total rewards: 663.070045.3, cost: 436.215118, total money: 5271.190056
# epoch: 80, total rewards: 49.510033.3, cost: 1631.971558, total money: 9512.240044
# epoch: 90, total rewards: 596.819962.3, cost: 454.428345, total money: 6960.079994
# epoch: 100, total rewards: 843.050049.3, cost: 399.924500, total money: 6246.340111
# day 1: buy 1 unit at price 108.059998, total balance 9891.940002
# day 2: buy 1 unit at price 109.040001, total balance 9782.900002
# day 3, sell 1 unit at price 108.339996, investment 0.259114 %, total balance 9891.239998,
# day 4: buy 1 unit at price 108.500000, total balance 9782.739998
# day 5, sell 1 unit at price 109.050003, investment 0.009173 %, total balance 9891.790001,
# day 6: buy 1 unit at price 110.250000, total balance 9781.540001
# day 7: buy 1 unit at price 110.839996, total balance 9670.700005
# day 9: buy 1 unit at price 112.269997, total balance 9558.430008
# day 10: buy 1 unit at price 112.989998, total balance 9445.440010
# day 11, sell 1 unit at price 113.260002, investment 4.387099 %, total balance 9558.700012,
# day 14: buy 1 unit at price 114.209999, total balance 9444.490013
# day 15: buy 1 unit at price 115.669998, total balance 9328.820015
# day 17: buy 1 unit at price 116.320000, total balance 9212.500015
# day 20: buy 1 unit at price 115.669998, total balance 9096.830017
# day 21: buy 1 unit at price 116.870003, total balance 8979.960014
# day 24, sell 1 unit at price 112.110001, investment 1.687075 %, total balance 9092.070015,
# day 25, sell 1 unit at price 112.870003, investment 1.831475 %, total balance 9204.940018,
# day 26, sell 1 unit at price 107.879997, investment -3.910216 %, total balance 9312.820015,
# day 28, sell 1 unit at price 111.739998, investment -1.106293 %, total balance 9424.560013,
# day 31, sell 1 unit at price 115.510002, investment 1.138257 %, total balance 9540.070015,
# day 32: buy 1 unit at price 114.680000, total balance 9425.390015
# day 33, sell 1 unit at price 114.709999, investment -0.829946 %, total balance 9540.100014,
# day 34: buy 1 unit at price 115.190002, total balance 9424.910011
# day 35, sell 1 unit at price 114.980003, investment -1.151991 %, total balance 9539.890015,
# day 41, sell 1 unit at price 113.320000, investment -2.031640 %, total balance 9653.210014,
# day 42: buy 1 unit at price 115.059998, total balance 9538.150017
# day 43, sell 1 unit at price 115.160004, investment -1.463163 %, total balance 9653.310020,
# day 44: buy 1 unit at price 114.730003, total balance 9538.580017
# day 45, sell 1 unit at price 114.739998, investment 0.052317 %, total balance 9653.320015,
# day 47: buy 1 unit at price 117.660004, total balance 9535.660011
# day 48, sell 1 unit at price 116.250000, investment 0.920217 %, total balance 9651.910011,
# day 49, sell 1 unit at price 114.949997, investment -0.095603 %, total balance 9766.860008,
# day 50, sell 1 unit at price 115.239998, investment 0.444517 %, total balance 9882.100006,
# day 51: buy 1 unit at price 115.440002, total balance 9766.660004
# day 52: buy 1 unit at price 114.529999, total balance 9652.130005
# day 54: buy 1 unit at price 114.739998, total balance 9537.390007
# day 56, sell 1 unit at price 107.010002, investment -9.051505 %, total balance 9644.400009,
# day 58: buy 1 unit at price 108.169998, total balance 9536.230011
# day 60, sell 1 unit at price 109.970001, investment -4.738393 %, total balance 9646.200012,
# day 61, sell 1 unit at price 107.849998, investment -5.832533 %, total balance 9754.050011,
# day 62: buy 1 unit at price 109.330002, total balance 9644.720009
# day 63, sell 1 unit at price 110.989998, investment -3.268259 %, total balance 9755.710007,
# day 64, sell 1 unit at price 111.879997, investment 3.429786 %, total balance 9867.590004,
# day 67: buy 1 unit at price 112.510002, total balance 9755.080002
# day 69, sell 1 unit at price 113.370003, investment 3.695235 %, total balance 9868.450005,
# day 71: buy 1 unit at price 110.209999, total balance 9758.240005
# day 72: buy 1 unit at price 110.209999, total balance 9648.030006
# day 74, sell 1 unit at price 111.720001, investment -0.702161 %, total balance 9759.750008,
# day 77, sell 1 unit at price 110.410004, investment 0.181476 %, total balance 9870.160011,
# day 78: buy 1 unit at price 109.989998, total balance 9760.170013
# day 79: buy 1 unit at price 110.099998, total balance 9650.070015
# day 80, sell 1 unit at price 109.400002, investment -0.734958 %, total balance 9759.470016,
# day 82, sell 1 unit at price 108.779999, investment -1.100099 %, total balance 9868.250015,
# day 83, sell 1 unit at price 107.919998, investment -1.980018 %, total balance 9976.170013,
# day 85: buy 1 unit at price 108.430000, total balance 9867.740013
# day 87, sell 1 unit at price 110.989998, investment 2.360968 %, total balance 9978.730011,
# day 89: buy 1 unit at price 114.290001, total balance 9864.440010
# day 92: buy 1 unit at price 113.029999, total balance 9751.410011
# day 94: buy 1 unit at price 112.959999, total balance 9638.450012
# day 97, sell 1 unit at price 113.010002, investment -1.119957 %, total balance 9751.460014,
# day 98: buy 1 unit at price 112.489998, total balance 9638.970016
# day 99, sell 1 unit at price 111.230003, investment -1.592494 %, total balance 9750.200020,
# day 100, sell 1 unit at price 110.660004, investment -2.036115 %, total balance 9860.860023,
# day 101: buy 1 unit at price 105.930000, total balance 9754.930023
# day 103, sell 1 unit at price 107.010002, investment -4.871540 %, total balance 9861.940025,
# day 104, sell 1 unit at price 108.400002, investment 2.331730 %, total balance 9970.340027,
# day 108: buy 1 unit at price 110.800003, total balance 9859.540024
# day 110, sell 1 unit at price 110.830002, investment 0.027075 %, total balance 9970.370026,
# day 111: buy 1 unit at price 110.190002, total balance 9860.180023
# day 114: buy 1 unit at price 107.900002, total balance 9752.280022
# day 115, sell 1 unit at price 108.180000, investment -1.824124 %, total balance 9860.460022,
# day 117, sell 1 unit at price 107.540001, investment -0.333643 %, total balance 9968.000023,
# day 118: buy 1 unit at price 107.510002, total balance 9860.490021
# day 119, sell 1 unit at price 105.750000, investment -1.637059 %, total balance 9966.240021,
# day 126: buy 1 unit at price 103.610001, total balance 9862.630020
# day 132, sell 1 unit at price 106.849998, investment 3.127109 %, total balance 9969.480019,
# day 135: buy 1 unit at price 110.500000, total balance 9858.980019
# day 138, sell 1 unit at price 111.279999, investment 0.705881 %, total balance 9970.260017,
# day 145: buy 1 unit at price 114.949997, total balance 9855.310020
# day 146, sell 1 unit at price 115.660004, investment 0.617666 %, total balance 9970.970024,
# day 148: buy 1 unit at price 117.089996, total balance 9853.880028
# day 149: buy 1 unit at price 117.120003, total balance 9736.760025
# day 151: buy 1 unit at price 117.790001, total balance 9618.970024
# day 153, sell 1 unit at price 115.730003, investment -1.161494 %, total balance 9734.700027,
# day 154, sell 1 unit at price 113.889999, investment -2.757858 %, total balance 9848.590027,
# day 155, sell 1 unit at price 114.650002, investment -2.665761 %, total balance 9963.240028,
# day 157: buy 1 unit at price 114.769997, total balance 9848.470032
# day 158: buy 1 unit at price 114.769997, total balance 9733.700035
# day 160, sell 1 unit at price 115.320000, investment 0.479222 %, total balance 9849.020035,
# day 161, sell 1 unit at price 114.970001, investment 0.174266 %, total balance 9963.990036,
# day 163: buy 1 unit at price 114.680000, total balance 9849.310036
# day 166: buy 1 unit at price 115.760002, total balance 9733.550034
# day 167, sell 1 unit at price 115.190002, investment 0.444718 %, total balance 9848.740036,
# day 169: buy 1 unit at price 115.150002, total balance 9733.590034
# day 170: buy 1 unit at price 114.589996, total balance 9619.000038
# day 172, sell 1 unit at price 114.320000, investment -1.243955 %, total balance 9733.320038,
# day 173: buy 1 unit at price 113.709999, total balance 9619.610039
# day 175, sell 1 unit at price 113.080002, investment -1.797655 %, total balance 9732.690041,
# day 177: buy 1 unit at price 113.500000, total balance 9619.190041
# day 178: buy 1 unit at price 113.839996, total balance 9505.350044
# day 179, sell 1 unit at price 114.300003, investment -0.253070 %, total balance 9619.650047,
# day 180: buy 1 unit at price 117.620003, total balance 9502.030045
# day 181, sell 1 unit at price 118.629997, investment 4.326795 %, total balance 9620.660042,
# day 184, sell 1 unit at price 116.389999, investment 2.546255 %, total balance 9737.050041,
# day 186: buy 1 unit at price 114.519997, total balance 9622.530045
# day 188: buy 1 unit at price 113.500000, total balance 9509.030045
# day 189: buy 1 unit at price 113.970001, total balance 9395.060043
# day 191, sell 1 unit at price 115.269997, investment 1.256149 %, total balance 9510.330040,
# day 192: buy 1 unit at price 114.620003, total balance 9395.710037
# day 193, sell 1 unit at price 115.320000, investment -1.955452 %, total balance 9511.030037,
# day 194, sell 1 unit at price 114.519997, investment 0.000000 %, total balance 9625.550034,
# day 195, sell 1 unit at price 111.470001, investment -1.788545 %, total balance 9737.020035,
# day 196, sell 1 unit at price 108.129997, investment -5.124159 %, total balance 9845.150032,
# day 197, sell 1 unit at price 106.949997, investment -6.691682 %, total balance 9952.100029,
# day 198: buy 1 unit at price 106.339996, total balance 9845.760033
# day 199: buy 1 unit at price 108.620003, total balance 9737.140030
# day 200, sell 1 unit at price 109.830002, investment 3.281931 %, total balance 9846.970032,
# day 201: buy 1 unit at price 108.089996, total balance 9738.880035
# day 202, sell 1 unit at price 107.910004, investment -0.653654 %, total balance 9846.790039,
# day 204: buy 1 unit at price 105.250000, total balance 9741.540039
# day 206, sell 1 unit at price 104.860001, investment -2.988247 %, total balance 9846.400040,
# day 207, sell 1 unit at price 103.419998, investment -1.738719 %, total balance 9949.820038,
# day 212: buy 1 unit at price 108.379997, total balance 9841.440041
# day 213: buy 1 unit at price 109.089996, total balance 9732.350044
# day 216: buy 1 unit at price 112.379997, total balance 9619.970047
# day 217, sell 1 unit at price 111.290001, investment 2.685001 %, total balance 9731.260048,
# day 220: buy 1 unit at price 107.330002, total balance 9623.930046
# day 221, sell 1 unit at price 110.070000, investment 0.898344 %, total balance 9734.000046,
# day 223: buy 1 unit at price 110.830002, total balance 9623.170044
# day 224, sell 1 unit at price 108.449997, investment -3.497064 %, total balance 9731.620041,
# day 226, sell 1 unit at price 106.650002, investment -0.633560 %, total balance 9838.270042,
# day 227: buy 1 unit at price 109.260002, total balance 9729.010040
# day 228: buy 1 unit at price 109.720001, total balance 9619.290039
# day 229: buy 1 unit at price 110.940002, total balance 9508.350037
# day 230: buy 1 unit at price 110.059998, total balance 9398.290039
# day 233: buy 1 unit at price 107.230003, total balance 9291.060036
# day 234, sell 1 unit at price 105.190002, investment -5.088874 %, total balance 9396.250038,
# day 235, sell 1 unit at price 103.290001, investment -5.464032 %, total balance 9499.540039,
# day 236, sell 1 unit at price 101.360001, investment -7.619395 %, total balance 9600.900040,
# day 237, sell 1 unit at price 100.370003, investment -9.527672 %, total balance 9701.270042,
# day 239, sell 1 unit at price 101.120003, investment -8.122838 %, total balance 9802.390045,
# day 240: buy 1 unit at price 100.290001, total balance 9702.100044
# day 241: buy 1 unit at price 99.010002, total balance 9603.090042
# day 242, sell 1 unit at price 98.540001, investment -8.104077 %, total balance 9701.630043,
# day 244: buy 1 unit at price 96.449997, total balance 9605.180046
# day 245: buy 1 unit at price 94.169998, total balance 9511.010048
# day 247, sell 1 unit at price 95.959999, investment -4.317481 %, total balance 9606.970047,
# day 249, sell 1 unit at price 96.830002, investment -2.201798 %, total balance 9703.800049,
# day 250, sell 1 unit at price 97.620003, investment 1.213070 %, total balance 9801.420052,
# day 251: buy 1 unit at price 99.309998, total balance 9702.110054
# day 252: buy 1 unit at price 97.110001, total balance 9605.000053
# day 254, sell 1 unit at price 100.760002, investment 6.997987 %, total balance 9705.760056,
# day 255, sell 1 unit at price 100.570000, investment 1.268757 %, total balance 9806.330055,
# day 258: buy 1 unit at price 99.910004, total balance 9706.420052
# day 259, sell 1 unit at price 100.940002, investment 3.943983 %, total balance 9807.360054,
# day 260: buy 1 unit at price 101.680000, total balance 9705.680054
# day 261, sell 1 unit at price 102.500000, investment 2.592329 %, total balance 9808.180054,
# day 263, sell 1 unit at price 104.589996, investment 2.861916 %, total balance 9912.770050,
# day 265: buy 1 unit at price 102.680000, total balance 9810.090050
# day 266, sell 1 unit at price 102.739998, investment 0.058432 %, total balance 9912.830048,
# day 269: buy 1 unit at price 104.169998, total balance 9808.660049
# day 270, sell 1 unit at price 104.410004, investment 0.230398 %, total balance 9913.070053,
# day 272: buy 1 unit at price 103.879997, total balance 9809.190056
# day 273: buy 1 unit at price 104.250000, total balance 9704.940056
# day 274, sell 1 unit at price 103.790001, investment -0.086635 %, total balance 9808.730057,
# day 277: buy 1 unit at price 101.360001, total balance 9707.370056
# day 278, sell 1 unit at price 100.879997, investment -3.232617 %, total balance 9808.250053,
# day 279: buy 1 unit at price 102.599998, total balance 9705.650055
# day 280: buy 1 unit at price 103.089996, total balance 9602.560059
# day 281, sell 1 unit at price 102.419998, investment 1.045775 %, total balance 9704.980057,
# day 282: buy 1 unit at price 105.550003, total balance 9599.430054
# day 283: buy 1 unit at price 105.180000, total balance 9494.250053
# day 284: buy 1 unit at price 105.690002, total balance 9388.560051
# day 285, sell 1 unit at price 105.470001, investment 2.797274 %, total balance 9494.030052,
# day 286, sell 1 unit at price 105.000000, investment 1.852754 %, total balance 9599.030052,
# day 287, sell 1 unit at price 106.099998, investment 0.521076 %, total balance 9705.130051,
# day 288: buy 1 unit at price 105.290001, total balance 9599.840050
# day 290: buy 1 unit at price 104.360001, total balance 9495.480049
# day 291, sell 1 unit at price 104.430000, investment -0.713063 %, total balance 9599.910049,
# day 293, sell 1 unit at price 104.110001, investment -1.494940 %, total balance 9704.020050,
# day 297, sell 1 unit at price 104.349998, investment -0.892775 %, total balance 9808.370049,
# day 298, sell 1 unit at price 104.040001, investment -0.306631 %, total balance 9912.410049,
# day 299: buy 1 unit at price 104.389999, total balance 9808.020050
# day 300: buy 1 unit at price 105.339996, total balance 9702.680054
# day 301, sell 1 unit at price 106.550003, investment 2.069167 %, total balance 9809.230057,
# day 302, sell 1 unit at price 107.190002, investment 1.756224 %, total balance 9916.420059,
# day 307: buy 1 unit at price 98.930000, total balance 9817.490059
# day 309, sell 1 unit at price 99.580002, investment 0.657032 %, total balance 9917.070061,
# day 310: buy 1 unit at price 100.709999, total balance 9816.360062
# day 312, sell 1 unit at price 104.639999, investment 3.902294 %, total balance 9921.000061,
# day 316: buy 1 unit at price 105.309998, total balance 9815.690063
# day 317: buy 1 unit at price 105.650002, total balance 9710.040062
# day 319, sell 1 unit at price 105.339996, investment 0.028486 %, total balance 9815.380058,
# day 320, sell 1 unit at price 106.230003, investment 0.548984 %, total balance 9921.610062,
# day 321: buy 1 unit at price 111.209999, total balance 9810.400063
# day 322: buy 1 unit at price 109.940002, total balance 9700.460060
# day 324: buy 1 unit at price 114.300003, total balance 9586.160057
# day 327, sell 1 unit at price 113.739998, investment 2.274974 %, total balance 9699.900055,
# day 330: buy 1 unit at price 114.470001, total balance 9585.430054
# day 331: buy 1 unit at price 116.120003, total balance 9469.310051
# day 332: buy 1 unit at price 116.050003, total balance 9353.260048
# day 333: buy 1 unit at price 115.160004, total balance 9238.100044
# day 335: buy 1 unit at price 116.120003, total balance 9121.980042
# day 338, sell 1 unit at price 112.610001, investment 2.428596 %, total balance 9234.590042,
# day 342, sell 1 unit at price 110.320000, investment -3.482068 %, total balance 9344.910042,
# day 343: buy 1 unit at price 109.900002, total balance 9235.010040
# day 344, sell 1 unit at price 111.309998, investment -2.760552 %, total balance 9346.320038,
# day 347, sell 1 unit at price 111.730003, investment -3.780571 %, total balance 9458.050041,
# day 349, sell 1 unit at price 108.639999, investment -6.385182 %, total balance 9566.690041,
# day 350, sell 1 unit at price 109.709999, investment -4.732550 %, total balance 9676.400040,
# day 351, sell 1 unit at price 108.519997, investment -6.544959 %, total balance 9784.920036,
# day 353: buy 1 unit at price 107.059998, total balance 9677.860039
# day 354, sell 1 unit at price 105.959999, investment -3.585080 %, total balance 9783.820038,
# day 355: buy 1 unit at price 106.459999, total balance 9677.360039
# day 356: buy 1 unit at price 109.739998, total balance 9567.620041
# day 357, sell 1 unit at price 110.129997, investment 2.867551 %, total balance 9677.750038,
# day 359, sell 1 unit at price 109.160004, investment 2.536168 %, total balance 9786.910042,
# day 361, sell 1 unit at price 110.680000, investment 0.856572 %, total balance 9897.590042,
# day 364: buy 1 unit at price 109.820000, total balance 9787.770042
# day 365: buy 1 unit at price 109.220001, total balance 9678.550041
# day 366: buy 1 unit at price 110.709999, total balance 9567.840042
# day 367: buy 1 unit at price 109.910004, total balance 9457.930038
# day 368, sell 1 unit at price 110.190002, investment 0.336917 %, total balance 9568.120041,
# day 369: buy 1 unit at price 109.440002, total balance 9458.680038
# day 371, sell 1 unit at price 107.760002, investment -1.336751 %, total balance 9566.440041,
# day 372, sell 1 unit at price 108.480003, investment -2.014268 %, total balance 9674.920044,
# day 374, sell 1 unit at price 111.800003, investment 1.719588 %, total balance 9786.720047,
# day 375: buy 1 unit at price 113.680000, total balance 9673.040047
# day 376: buy 1 unit at price 113.800003, total balance 9559.240044
# day 378: buy 1 unit at price 113.489998, total balance 9445.750046
# day 385: buy 1 unit at price 115.120003, total balance 9330.630043
# day 386, sell 1 unit at price 113.989998, investment 4.157525 %, total balance 9444.620041,
# day 387, sell 1 unit at price 114.669998, investment 0.870864 %, total balance 9559.290039,
# day 388, sell 1 unit at price 113.540001, investment -0.228473 %, total balance 9672.830040,
# day 389, sell 1 unit at price 114.269997, investment 0.687284 %, total balance 9787.100037,
# day 390: buy 1 unit at price 116.360001, total balance 9670.740036
# day 391, sell 1 unit at price 116.830002, investment 1.485406 %, total balance 9787.570038,
# day 392, sell 1 unit at price 115.709999, investment -0.558613 %, total balance 9903.280037,
# day 395: buy 1 unit at price 115.589996, total balance 9787.690041
# day 396, sell 1 unit at price 116.000000, investment 0.354705 %, total balance 9903.690041,
# day 400: buy 1 unit at price 110.430000, total balance 9793.260040
# day 402: buy 1 unit at price 109.860001, total balance 9683.400040
# day 404: buy 1 unit at price 107.680000, total balance 9575.720039
# day 405: buy 1 unit at price 109.339996, total balance 9466.380043
# day 406, sell 1 unit at price 104.800003, investment -5.098250 %, total balance 9571.180046,
# day 407, sell 1 unit at price 105.199997, investment -4.241766 %, total balance 9676.380043,
# day 410, sell 1 unit at price 107.309998, investment -0.343613 %, total balance 9783.690041,
# day 411: buy 1 unit at price 107.610001, total balance 9676.080040
# day 412, sell 1 unit at price 108.720001, investment -0.567034 %, total balance 9784.800041,
# day 413: buy 1 unit at price 106.019997, total balance 9678.780045
# day 414, sell 1 unit at price 106.870003, investment -0.687666 %, total balance 9785.650047,
# day 415: buy 1 unit at price 105.739998, total balance 9679.910049
# day 417, sell 1 unit at price 109.220001, investment 3.018303 %, total balance 9789.130051,
# day 418, sell 1 unit at price 109.860001, investment 3.896352 %, total balance 9898.990051,
# day 421: buy 1 unit at price 112.370003, total balance 9786.620049
# day 422, sell 1 unit at price 112.610001, investment 0.213578 %, total balance 9899.230049,
# day 424: buy 1 unit at price 116.870003, total balance 9782.360046
# day 426: buy 1 unit at price 117.910004, total balance 9664.450043
# day 427, sell 1 unit at price 120.230003, investment 2.874990 %, total balance 9784.680046,
# day 428: buy 1 unit at price 119.160004, total balance 9665.520042
# day 429: buy 1 unit at price 118.570000, total balance 9546.950043
# day 432, sell 1 unit at price 118.900002, investment 0.839622 %, total balance 9665.850044,
# day 433: buy 1 unit at price 118.879997, total balance 9546.970047
# day 435: buy 1 unit at price 118.000000, total balance 9428.970047
# day 436, sell 1 unit at price 117.029999, investment -1.787517 %, total balance 9546.000046,
# day 437, sell 1 unit at price 117.720001, investment -0.716875 %, total balance 9663.720047,
# day 438: buy 1 unit at price 117.690002, total balance 9546.030045
# day 440: buy 1 unit at price 113.250000, total balance 9432.780045
# day 441: buy 1 unit at price 112.190002, total balance 9320.590042
# day 442, sell 1 unit at price 114.620003, investment -3.583441 %, total balance 9435.210045,
# day 444, sell 1 unit at price 111.820000, investment -5.237288 %, total balance 9547.030045,
# day 445, sell 1 unit at price 112.629997, investment -4.299435 %, total balance 9659.660042,
# day 447: buy 1 unit at price 116.139999, total balance 9543.520042
# day 449, sell 1 unit at price 119.959999, investment 5.924944 %, total balance 9663.480042,
# day 452, sell 1 unit at price 120.559998, investment 7.460553 %, total balance 9784.040039,
# day 455: buy 1 unit at price 125.120003, total balance 9658.920036
# day 458: buy 1 unit at price 126.510002, total balance 9532.410034
# day 459: buy 1 unit at price 126.430000, total balance 9405.980034
# day 461, sell 1 unit at price 124.919998, investment 7.559841 %, total balance 9530.900032,
# day 462, sell 1 unit at price 127.800003, investment 2.141944 %, total balance 9658.700035,
# day 463: buy 1 unit at price 128.820007, total balance 9529.880028
# day 464: buy 1 unit at price 129.100006, total balance 9400.780022
# day 465, sell 1 unit at price 129.300003, investment 2.205360 %, total balance 9530.080025,
# day 466, sell 1 unit at price 130.000000, investment 2.823697 %, total balance 9660.080025,
# day 467: buy 1 unit at price 130.380005, total balance 9529.700020
# day 468: buy 1 unit at price 129.919998, total balance 9399.780022
# day 473: buy 1 unit at price 130.619995, total balance 9269.160027
# day 474, sell 1 unit at price 130.580002, investment 1.366243 %, total balance 9399.740028,
# day 475, sell 1 unit at price 129.630005, investment 0.410534 %, total balance 9529.370033,
# day 479, sell 1 unit at price 131.669998, investment 0.989410 %, total balance 9661.040031,
# day 480, sell 1 unit at price 132.059998, investment 1.647167 %, total balance 9793.100029,
# day 482: buy 1 unit at price 131.470001, total balance 9661.630028
# day 483: buy 1 unit at price 129.779999, total balance 9531.850029
# day 484: buy 1 unit at price 132.339996, total balance 9399.510033
# day 485, sell 1 unit at price 133.059998, investment 1.868016 %, total balance 9532.570030,
# day 487: buy 1 unit at price 134.410004, total balance 9398.160027
# day 488, sell 1 unit at price 134.500000, investment 2.304707 %, total balance 9532.660027,
# day 490: buy 1 unit at price 138.020004, total balance 9394.640022
# day 491: buy 1 unit at price 136.809998, total balance 9257.830025
# day 492, sell 1 unit at price 137.339996, investment 5.825241 %, total balance 9395.170021,
# day 493: buy 1 unit at price 138.179993, total balance 9256.990028
# day 494, sell 1 unit at price 138.039993, investment 4.307086 %, total balance 9395.030022,
# day 495: buy 1 unit at price 137.350006, total balance 9257.680016
# day 496, sell 1 unit at price 137.240005, investment 2.105499 %, total balance 9394.920021,
# day 497: buy 1 unit at price 137.199997, total balance 9257.720024
# day 498: buy 1 unit at price 137.580002, total balance 9120.140022
# day 500, sell 1 unit at price 139.139999, investment 0.811473 %, total balance 9259.280022,
# day 501: buy 1 unit at price 138.630005, total balance 9120.650017
# day 502, sell 1 unit at price 139.399994, investment 1.893134 %, total balance 9260.050011,
# day 504, sell 1 unit at price 138.339996, investment 0.115794 %, total balance 9398.390007,
# day 507: buy 1 unit at price 136.940002, total balance 9261.450005
# day 508: buy 1 unit at price 137.440002, total balance 9124.010002
# day 509: buy 1 unit at price 136.070007, total balance 8987.939995
# day 512, sell 1 unit at price 136.720001, investment -0.458686 %, total balance 9124.659996,
# day 513: buy 1 unit at price 137.250000, total balance 8987.409996
# day 514, sell 1 unit at price 138.199997, investment 0.728863 %, total balance 9125.609993,
# day 515, sell 1 unit at price 136.839996, investment -0.537873 %, total balance 9262.449989,
# day 516, sell 1 unit at price 136.679993, investment -1.406631 %, total balance 9399.129982,
# day 517, sell 1 unit at price 136.539993, investment -0.292105 %, total balance 9535.669975,
# day 520, sell 1 unit at price 134.429993, investment -2.190054 %, total balance 9670.099968,
# day 521: buy 1 unit at price 134.229996, total balance 9535.869972
# day 522: buy 1 unit at price 135.889999, total balance 9399.979973
# day 523: buy 1 unit at price 132.360001, total balance 9267.619972
# day 525: buy 1 unit at price 135.289993, total balance 9132.329979
# day 526: buy 1 unit at price 137.589996, total balance 8994.739983

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig('output/'+name+'.png')
plt.show()

# %% [markdown]
# ### 3.14. NEURO EVOLUTION AGENT

# %%
## Neuro-evolution agent

df= df_full.copy()
name = 'Neuro-evolution agent'

close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1

class neuralnetwork:
    def __init__(self, id_, hidden_size = 128):
        self.W1 = np.random.randn(window_size, hidden_size) / np.sqrt(window_size)
        self.W2 = np.random.randn(hidden_size, 3) / np.sqrt(hidden_size)
        self.fitness = 0
        self.id = id_

def relu(X):
    return np.maximum(X, 0)
    
def softmax(X):
    e_x = np.exp(X - np.max(X, axis=-1, keepdims=True))
    return e_x / np.sum(e_x, axis=-1, keepdims=True)

def feed_forward(X, nets):
    a1 = np.dot(X, nets.W1)
    z1 = relu(a1)
    a2 = np.dot(z1, nets.W2)
    return softmax(a2)

class NeuroEvolution:
    def __init__(self, population_size, mutation_rate, model_generator,
                state_size, window_size, trend, skip, initial_money):
        self.population_size = population_size
        self.mutation_rate = mutation_rate
        self.model_generator = model_generator
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        
    def _initialize_population(self):
        self.population = []
        for i in range(self.population_size):
            self.population.append(self.model_generator(i))
    
    def mutate(self, individual, scale=1.0):
        mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=individual.W1.shape)
        individual.W1 += np.random.normal(loc=0, scale=scale, size=individual.W1.shape) * mutation_mask
        mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=individual.W2.shape)
        individual.W2 += np.random.normal(loc=0, scale=scale, size=individual.W2.shape) * mutation_mask
        return individual
    
    def inherit_weights(self, parent, child):
        child.W1 = parent.W1.copy()
        child.W2 = parent.W2.copy()
        return child
    
    def crossover(self, parent1, parent2):
        child1 = self.model_generator((parent1.id+1)*10)
        child1 = self.inherit_weights(parent1, child1)
        child2 = self.model_generator((parent2.id+1)*10)
        child2 = self.inherit_weights(parent2, child2)
        # first W
        n_neurons = child1.W1.shape[1]
        cutoff = np.random.randint(0, n_neurons)
        child1.W1[:, cutoff:] = parent2.W1[:, cutoff:].copy()
        child2.W1[:, cutoff:] = parent1.W1[:, cutoff:].copy()
        # second W
        n_neurons = child1.W2.shape[1]
        cutoff = np.random.randint(0, n_neurons)
        child1.W2[:, cutoff:] = parent2.W2[:, cutoff:].copy()
        child2.W2[:, cutoff:] = parent1.W2[:, cutoff:].copy()
        return child1, child2
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])
    
    def act(self, p, state):
        logits = feed_forward(state, p)
        return np.argmax(logits, 1)[0]
    
    def buy(self, individual):
        initial_money = self.initial_money
        starting_money = initial_money
        state = self.get_state(0)
        inventory = []
        states_sell = []
        states_buy = []
        
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(individual, state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((self.trend[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, self.trend[t], invest, initial_money)
                )
            state = next_state
        
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    
    def calculate_fitness(self):
        for i in range(self.population_size):
            initial_money = self.initial_money
            starting_money = initial_money
            state = self.get_state(0)
            inventory = []
            
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(self.population[i], state)
                next_state = self.get_state(t + 1)
            
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]

                elif action == 2 and len(inventory):
                    bought_price = inventory.pop(0)
                    starting_money += self.trend[t]

                state = next_state
            invest = ((starting_money - initial_money) / initial_money) * 100
            self.population[i].fitness = invest
    
    def evolve(self, generations=20, checkpoint= 5):
        self._initialize_population()
        n_winners = int(self.population_size * 0.4)
        n_parents = self.population_size - n_winners
        for epoch in range(generations):
            self.calculate_fitness()
            fitnesses = [i.fitness for i in self.population]
            sort_fitness = np.argsort(fitnesses)[::-1]
            self.population = [self.population[i] for i in sort_fitness]
            fittest_individual = self.population[0]
            if (epoch+1) % checkpoint == 0:
                print('epoch %d, fittest individual %d with accuracy %f'%(epoch+1, sort_fitness[0], 
                                                                          fittest_individual.fitness))
            next_population = [self.population[i] for i in range(n_winners)]
            total_fitness = np.sum([np.abs(i.fitness) for i in self.population])
            parent_probabilities = [np.abs(i.fitness / total_fitness) for i in self.population]
            parents = np.random.choice(self.population, size=n_parents, p=parent_probabilities, replace=False)
            for i in np.arange(0, len(parents), 2):
                child1, child2 = self.crossover(parents[i], parents[i+1])
                next_population += [self.mutate(child1), self.mutate(child2)]
            self.population = next_population
        return fittest_individual

population_size = 100
generations = 10
mutation_rate = 0.1
neural_evolve = NeuroEvolution(population_size, mutation_rate, neuralnetwork,
                              window_size, window_size, close, skip, initial_money)

fittest_nets = neural_evolve.evolve(50)

states_buy, states_sell, total_gains, invest = neural_evolve.buy(fittest_nets)
# Out:
# epoch 5, fittest individual 0 with accuracy 2.023499
# epoch 10, fittest individual 48 with accuracy 2.674100
# epoch 15, fittest individual 95 with accuracy 3.300900
# epoch 20, fittest individual 44 with accuracy 5.858300
# epoch 25, fittest individual 0 with accuracy 5.858300
# epoch 30, fittest individual 0 with accuracy 5.858300
# epoch 35, fittest individual 0 with accuracy 5.858300
# epoch 40, fittest individual 0 with accuracy 5.858300
# epoch 45, fittest individual 0 with accuracy 5.858300
# epoch 50, fittest individual 0 with accuracy 5.858300
# day 1: buy 1 unit at price 108.059998, total balance 9891.940002
# day 4, sell 1 unit at price 108.500000, investment 0.407183 %, total balance 10000.440002,
# day 11: buy 1 unit at price 113.260002, total balance 9887.180000
# day 12, sell 1 unit at price 113.010002, investment -0.220731 %, total balance 10000.190002,
# day 14: buy 1 unit at price 114.209999, total balance 9885.980003
# day 17, sell 1 unit at price 116.320000, investment 1.847475 %, total balance 10002.300003,
# day 26: buy 1 unit at price 107.879997, total balance 9894.420006
# day 27, sell 1 unit at price 110.040001, investment 2.002228 %, total balance 10004.460007,
# day 30: buy 1 unit at price 115.029999, total balance 9889.430008
# day 31, sell 1 unit at price 115.510002, investment 0.417285 %, total balance 10004.940010,
# day 32: buy 1 unit at price 114.680000, total balance 9890.260010
# day 34, sell 1 unit at price 115.190002, investment 0.444718 %, total balance 10005.450012,
# day 35: buy 1 unit at price 114.980003, total balance 9890.470009
# day 36, sell 1 unit at price 117.309998, investment 2.026434 %, total balance 10007.780006,
# day 37: buy 1 unit at price 118.769997, total balance 9889.010010
# day 38: buy 1 unit at price 117.360001, total balance 9771.650009
# day 39, sell 1 unit at price 115.500000, investment -2.753218 %, total balance 9887.150009,
# day 40: buy 1 unit at price 113.430000, total balance 9773.720009
# day 41, sell 1 unit at price 113.320000, investment -3.442400 %, total balance 9887.040009,
# day 42, sell 1 unit at price 115.059998, investment 1.437007 %, total balance 10002.100006,
# day 49: buy 1 unit at price 114.949997, total balance 9887.150009
# day 50, sell 1 unit at price 115.239998, investment 0.252284 %, total balance 10002.390007,
# day 54: buy 1 unit at price 114.739998, total balance 9887.650009
# day 56, sell 1 unit at price 107.010002, investment -6.736967 %, total balance 9994.660011,
# day 59: buy 1 unit at price 108.000000, total balance 9886.660011
# day 62: buy 1 unit at price 109.330002, total balance 9777.330009
# day 63, sell 1 unit at price 110.989998, investment 2.768517 %, total balance 9888.320007,
# day 64: buy 1 unit at price 111.879997, total balance 9776.440010
# day 66: buy 1 unit at price 110.400002, total balance 9666.040009
# day 67, sell 1 unit at price 112.510002, investment 2.908625 %, total balance 9778.550011,
# day 68: buy 1 unit at price 110.620003, total balance 9667.930008
# day 69, sell 1 unit at price 113.370003, investment 1.331789 %, total balance 9781.300011,
# day 70: buy 1 unit at price 110.300003, total balance 9671.000008
# day 71: buy 1 unit at price 110.209999, total balance 9560.790009
# day 72: buy 1 unit at price 110.209999, total balance 9450.580009
# day 73, sell 1 unit at price 109.320000, investment -0.978263 %, total balance 9559.900009,
# day 74, sell 1 unit at price 111.720001, investment 0.994394 %, total balance 9671.620010,
# day 75: buy 1 unit at price 111.470001, total balance 9560.150009
# day 76, sell 1 unit at price 110.930000, investment 0.571167 %, total balance 9671.080009,
# day 77, sell 1 unit at price 110.410004, investment 0.181476 %, total balance 9781.490013,
# day 78: buy 1 unit at price 109.989998, total balance 9671.500015
# day 79: buy 1 unit at price 110.099998, total balance 9561.400017
# day 80: buy 1 unit at price 109.400002, total balance 9452.000015
# day 81, sell 1 unit at price 108.779999, investment -1.297523 %, total balance 9560.780014,
# day 82: buy 1 unit at price 108.779999, total balance 9452.000015
# day 83, sell 1 unit at price 107.919998, investment -3.184716 %, total balance 9559.920013,
# day 84: buy 1 unit at price 107.239998, total balance 9452.680016
# day 85: buy 1 unit at price 108.430000, total balance 9344.250015
# day 86, sell 1 unit at price 109.370003, investment -0.563683 %, total balance 9453.620018,
# day 88, sell 1 unit at price 113.410004, investment 3.006363 %, total balance 9567.030022,
# day 89: buy 1 unit at price 114.290001, total balance 9452.740021
# day 91: buy 1 unit at price 113.900002, total balance 9338.840019
# day 92: buy 1 unit at price 113.029999, total balance 9225.810020
# day 93, sell 1 unit at price 113.339996, investment 3.601458 %, total balance 9339.150017,
# day 95, sell 1 unit at price 111.129997, investment 2.160322 %, total balance 9450.280014,
# day 98, sell 1 unit at price 112.489998, investment 4.895561 %, total balance 9562.770012,
# day 99: buy 1 unit at price 111.230003, total balance 9451.540009
# day 100, sell 1 unit at price 110.660004, investment 2.056629 %, total balance 9562.200012,
# day 101: buy 1 unit at price 105.930000, total balance 9456.270012
# day 102, sell 1 unit at price 108.349998, investment -5.197307 %, total balance 9564.620010,
# day 104: buy 1 unit at price 108.400002, total balance 9456.220009
# day 106: buy 1 unit at price 107.839996, total balance 9348.380013
# day 107: buy 1 unit at price 110.360001, total balance 9238.020012
# day 108: buy 1 unit at price 110.800003, total balance 9127.220009
# day 109, sell 1 unit at price 111.110001, investment -2.449518 %, total balance 9238.330009,
# day 110: buy 1 unit at price 110.830002, total balance 9127.500008
# day 113: buy 1 unit at price 108.029999, total balance 9019.470009
# day 114, sell 1 unit at price 107.900002, investment -4.538616 %, total balance 9127.370010,
# day 115: buy 1 unit at price 108.180000, total balance 9019.190010
# day 117, sell 1 unit at price 107.540001, investment -3.317452 %, total balance 9126.730011,
# day 118: buy 1 unit at price 107.510002, total balance 9019.220009
# day 119, sell 1 unit at price 105.750000, investment -0.169924 %, total balance 9124.970009,
# day 120: buy 1 unit at price 104.790001, total balance 9020.180008
# day 121: buy 1 unit at price 104.860001, total balance 8915.320007
# day 122: buy 1 unit at price 103.239998, total balance 8812.080009
# day 123, sell 1 unit at price 104.930000, investment -3.201108 %, total balance 8917.010010,
# day 124: buy 1 unit at price 104.199997, total balance 8812.810013
# day 125: buy 1 unit at price 105.080002, total balance 8707.730011
# day 126: buy 1 unit at price 103.610001, total balance 8604.120010
# day 127: buy 1 unit at price 103.720001, total balance 8500.400009
# day 128: buy 1 unit at price 104.059998, total balance 8396.340012
# day 129: buy 1 unit at price 107.279999, total balance 8289.060013
# day 131, sell 1 unit at price 106.389999, investment -1.344582 %, total balance 8395.450012,
# day 133, sell 1 unit at price 106.360001, investment -3.624502 %, total balance 8501.810013,
# day 134: buy 1 unit at price 110.580002, total balance 8391.230011
# day 136: buy 1 unit at price 111.529999, total balance 8279.700012
# day 137, sell 1 unit at price 109.889999, investment -0.821303 %, total balance 8389.590012,
# day 140: buy 1 unit at price 114.150002, total balance 8275.440010
# day 141: buy 1 unit at price 115.180000, total balance 8160.260010
# day 142, sell 1 unit at price 114.849998, investment 3.627174 %, total balance 8275.110008,
# day 144, sell 1 unit at price 116.730003, investment 8.053323 %, total balance 8391.840012,
# day 145: buy 1 unit at price 114.949997, total balance 8276.890015
# day 146, sell 1 unit at price 115.660004, investment 6.914405 %, total balance 8392.550018,
# day 147: buy 1 unit at price 116.150002, total balance 8276.400017
# day 150, sell 1 unit at price 117.550003, investment 9.338667 %, total balance 8393.950020,
# day 151, sell 1 unit at price 117.790001, investment 12.405764 %, total balance 8511.740021,
# day 152: buy 1 unit at price 116.879997, total balance 8394.860023
# day 153, sell 1 unit at price 115.730003, investment 10.366205 %, total balance 8510.590027,
# day 154: buy 1 unit at price 113.889999, total balance 8396.700027
# day 155, sell 1 unit at price 114.650002, investment 11.051922 %, total balance 8511.350029,
# day 157, sell 1 unit at price 114.769997, investment 10.143954 %, total balance 8626.120026,
# day 158, sell 1 unit at price 114.769997, investment 9.221540 %, total balance 8740.890022,
# day 159: buy 1 unit at price 114.620003, total balance 8626.270020
# day 160, sell 1 unit at price 115.320000, investment 11.301997 %, total balance 8741.590019,
# day 161: buy 1 unit at price 114.970001, total balance 8626.620018
# day 162, sell 1 unit at price 114.730003, investment 10.615120 %, total balance 8741.350021,
# day 163: buy 1 unit at price 114.680000, total balance 8626.670021
# day 165: buy 1 unit at price 116.139999, total balance 8510.530022
# day 166, sell 1 unit at price 115.760002, investment 11.243518 %, total balance 8626.290024,
# day 167, sell 1 unit at price 115.190002, investment 7.373232 %, total balance 8741.480026,
# day 168: buy 1 unit at price 114.580002, total balance 8626.900024
# day 169: buy 1 unit at price 115.150002, total balance 8511.750023
# day 170, sell 1 unit at price 114.589996, investment 3.626329 %, total balance 8626.340019,
# day 171: buy 1 unit at price 114.099998, total balance 8512.240021
# day 172, sell 1 unit at price 114.320000, investment 2.501570 %, total balance 8626.560020,
# day 173: buy 1 unit at price 113.709999, total balance 8512.850021
# day 174, sell 1 unit at price 114.430000, investment 0.245290 %, total balance 8627.280022,
# day 175: buy 1 unit at price 113.080002, total balance 8514.200020
# day 176, sell 1 unit at price 113.519997, investment -1.441226 %, total balance 8627.720016,
# day 177: buy 1 unit at price 113.500000, total balance 8514.220016
# day 178, sell 1 unit at price 113.839996, investment -0.965638 %, total balance 8628.060013,
# day 180: buy 1 unit at price 117.620003, total balance 8510.440010
# day 182: buy 1 unit at price 117.849998, total balance 8392.590012
# day 183: buy 1 unit at price 116.720001, total balance 8275.870010
# day 184: buy 1 unit at price 116.389999, total balance 8159.480011
# day 186, sell 1 unit at price 114.519997, investment -1.403362 %, total balance 8274.000008,
# day 187, sell 1 unit at price 112.839996, investment -3.456537 %, total balance 8386.840004,
# day 188, sell 1 unit at price 113.500000, investment -0.342435 %, total balance 8500.340004,
# day 190, sell 1 unit at price 115.040001, investment 0.366427 %, total balance 8615.380005,
# day 191, sell 1 unit at price 115.269997, investment 0.260934 %, total balance 8730.650002,
# day 192: buy 1 unit at price 114.620003, total balance 8616.029999
# day 193: buy 1 unit at price 115.320000, total balance 8500.709999
# day 194: buy 1 unit at price 114.519997, total balance 8386.190002
# day 195, sell 1 unit at price 111.470001, investment -2.799092 %, total balance 8497.660004,
# day 196, sell 1 unit at price 108.129997, investment -6.896851 %, total balance 8605.790001,
# day 197: buy 1 unit at price 106.949997, total balance 8498.840004
# day 198: buy 1 unit at price 106.339996, total balance 8392.500008
# day 199: buy 1 unit at price 108.620003, total balance 8283.880005
# day 200: buy 1 unit at price 109.830002, total balance 8174.050003
# day 201: buy 1 unit at price 108.089996, total balance 8065.960007
# day 203: buy 1 unit at price 106.360001, total balance 7959.600006
# day 204: buy 1 unit at price 105.250000, total balance 7854.350006
# day 205: buy 1 unit at price 103.290001, total balance 7751.060005
# day 206: buy 1 unit at price 104.860001, total balance 7646.200005
# day 209: buy 1 unit at price 106.699997, total balance 7539.500008
# day 210: buy 1 unit at price 109.019997, total balance 7430.480011
# day 211: buy 1 unit at price 108.980003, total balance 7321.500008
# day 212: buy 1 unit at price 108.379997, total balance 7213.120010
# day 213: buy 1 unit at price 109.089996, total balance 7104.030014
# day 215: buy 1 unit at price 111.480003, total balance 6992.550011
# day 216: buy 1 unit at price 112.379997, total balance 6880.170013
# day 217: buy 1 unit at price 111.290001, total balance 6768.880013
# day 219, sell 1 unit at price 109.589996, investment -4.355041 %, total balance 6878.470009,
# day 220, sell 1 unit at price 107.330002, investment -6.791142 %, total balance 6985.800011,
# day 221: buy 1 unit at price 110.070000, total balance 6875.730011
# day 222: buy 1 unit at price 109.989998, total balance 6765.740013
# day 223, sell 1 unit at price 110.830002, investment -2.865904 %, total balance 6876.570015,
# day 224: buy 1 unit at price 108.449997, total balance 6768.120018
# day 225, sell 1 unit at price 107.639999, investment -5.338141 %, total balance 6875.760017,
# day 226, sell 1 unit at price 106.650002, investment -5.686240 %, total balance 6982.410019,
# day 227: buy 1 unit at price 109.260002, total balance 6873.150017
# day 229, sell 1 unit at price 110.940002, investment -2.255504 %, total balance 6984.090019,
# day 231, sell 1 unit at price 111.190002, investment -5.466757 %, total balance 7095.280022,
# day 232, sell 1 unit at price 112.239998, investment -4.760289 %, total balance 7207.520020,
# day 233: buy 1 unit at price 107.230003, total balance 7100.290016
# day 234: buy 1 unit at price 105.190002, total balance 6995.100014
# day 235, sell 1 unit at price 103.290001, investment -11.506169 %, total balance 7098.390015,
# day 236, sell 1 unit at price 101.360001, investment -12.913480 %, total balance 7199.750015,
# day 238, sell 1 unit at price 101.019997, investment -11.865299 %, total balance 7300.770012,
# day 239: buy 1 unit at price 101.120003, total balance 7199.650009
# day 242: buy 1 unit at price 98.540001, total balance 7101.110008
# day 243: buy 1 unit at price 97.290001, total balance 7003.820007
# day 244: buy 1 unit at price 96.449997, total balance 6907.370010
# day 245: buy 1 unit at price 94.169998, total balance 6813.200012
# day 247: buy 1 unit at price 95.959999, total balance 6717.240013
# day 248: buy 1 unit at price 97.040001, total balance 6620.200012
# day 249, sell 1 unit at price 96.830002, investment -16.033644 %, total balance 6717.030014,
# day 250: buy 1 unit at price 97.620003, total balance 6619.410011
# day 251: buy 1 unit at price 99.309998, total balance 6520.100014
# day 253: buy 1 unit at price 100.690002, total balance 6419.410011
# day 254: buy 1 unit at price 100.760002, total balance 6318.650009
# day 255, sell 1 unit at price 100.570000, investment -12.181276 %, total balance 6419.220009,
# day 256: buy 1 unit at price 100.400002, total balance 6318.820007
# day 257, sell 1 unit at price 100.389999, investment -6.133705 %, total balance 6419.210007,
# day 258, sell 1 unit at price 99.910004, investment -6.046636 %, total balance 6519.120010,
# day 259: buy 1 unit at price 100.940002, total balance 6418.180008
# day 260: buy 1 unit at price 101.680000, total balance 6316.500008
# day 261: buy 1 unit at price 102.500000, total balance 6214.000008
# day 263, sell 1 unit at price 104.589996, investment -3.710188 %, total balance 6318.590004,
# day 264, sell 1 unit at price 102.940002, investment -6.273331 %, total balance 6421.530006,
# day 265, sell 1 unit at price 102.680000, investment -5.005085 %, total balance 6524.210007,
# day 266, sell 1 unit at price 102.739998, investment -3.403538 %, total balance 6626.950005,
# day 267: buy 1 unit at price 103.389999, total balance 6523.560005
# day 268, sell 1 unit at price 103.879997, investment -1.301665 %, total balance 6627.440002,
# day 269: buy 1 unit at price 104.169998, total balance 6523.270004
# day 270, sell 1 unit at price 104.410004, investment 1.084328 %, total balance 6627.680008,
# day 272: buy 1 unit at price 103.879997, total balance 6523.800011
# day 273: buy 1 unit at price 104.250000, total balance 6419.550011
# day 274, sell 1 unit at price 103.790001, investment -1.020408 %, total balance 6523.340012,
# day 276, sell 1 unit at price 102.379997, investment -4.048735 %, total balance 6625.720009,
# day 277, sell 1 unit at price 101.360001, investment -7.026230 %, total balance 6727.080009,
# day 278: buy 1 unit at price 100.879997, total balance 6626.200012
# day 279, sell 1 unit at price 102.599998, investment -5.854289 %, total balance 6728.800011,
# day 280: buy 1 unit at price 103.089996, total balance 6625.710014
# day 282, sell 1 unit at price 105.550003, investment -2.611178 %, total balance 6731.260017,
# day 284, sell 1 unit at price 105.690002, investment -3.116687 %, total balance 6836.950020,
# day 285: buy 1 unit at price 105.470001, total balance 6731.480019
# day 286, sell 1 unit at price 105.000000, investment -5.812705 %, total balance 6836.480019,
# day 288: buy 1 unit at price 105.290001, total balance 6731.190018
# day 289, sell 1 unit at price 105.160004, investment -6.424625 %, total balance 6836.350021,
# day 290, sell 1 unit at price 104.360001, investment -6.226975 %, total balance 6940.710022,
# day 292: buy 1 unit at price 104.190002, total balance 6836.520020
# day 293, sell 1 unit at price 104.110001, investment -5.414735 %, total balance 6940.630020,
# day 294, sell 1 unit at price 103.720001, investment -5.700515 %, total balance 7044.350021,
# day 295: buy 1 unit at price 102.970001, total balance 6941.380020
# day 296, sell 1 unit at price 103.010002, investment -5.016132 %, total balance 7044.390022,
# day 298: buy 1 unit at price 104.040001, total balance 6940.350021
# day 299, sell 1 unit at price 104.389999, investment -4.457260 %, total balance 7044.740021,
# day 300: buy 1 unit at price 105.339996, total balance 6939.400024
# day 303, sell 1 unit at price 106.800003, investment -0.401007 %, total balance 7046.200027,
# day 304: buy 1 unit at price 104.519997, total balance 6941.680031
# day 305, sell 1 unit at price 102.870003, investment -2.205533 %, total balance 7044.550034,
# day 306, sell 1 unit at price 99.760002, investment -1.344937 %, total balance 7144.310036,
# day 307: buy 1 unit at price 98.930000, total balance 7045.380035
# day 308, sell 1 unit at price 99.919998, investment 1.400444 %, total balance 7145.300034,
# day 312: buy 1 unit at price 104.639999, total balance 7040.660034
# day 313: buy 1 unit at price 105.139999, total balance 6935.520035
# day 314: buy 1 unit at price 105.349998, total balance 6830.170036
# day 315: buy 1 unit at price 105.559998, total balance 6724.610039
# day 318: buy 1 unit at price 104.870003, total balance 6619.740036
# day 319: buy 1 unit at price 105.339996, total balance 6514.400040
# day 322: buy 1 unit at price 109.940002, total balance 6404.460037
# day 323, sell 1 unit at price 111.099998, investment 14.194673 %, total balance 6515.560036,
# day 324, sell 1 unit at price 114.300003, investment 18.507005 %, total balance 6629.860039,
# day 325: buy 1 unit at price 113.459999, total balance 6516.400040
# day 326: buy 1 unit at price 113.599998, total balance 6402.800041
# day 327: buy 1 unit at price 113.739998, total balance 6289.060043
# day 328, sell 1 unit at price 113.550003, investment 20.579808 %, total balance 6402.610046,
# day 329, sell 1 unit at price 113.610001, investment 18.393082 %, total balance 6516.220047,
# day 331: buy 1 unit at price 116.120003, total balance 6400.100044
# day 332: buy 1 unit at price 116.050003, total balance 6284.050041
# day 333, sell 1 unit at price 115.160004, investment 18.672715 %, total balance 6399.210045,
# day 334: buy 1 unit at price 115.410004, total balance 6283.800041
# day 335, sell 1 unit at price 116.120003, investment 18.951034 %, total balance 6399.920044,
# day 336, sell 1 unit at price 115.089996, investment 15.889638 %, total balance 6515.010040,
# day 337: buy 1 unit at price 113.209999, total balance 6401.800041
# day 338, sell 1 unit at price 112.610001, investment 11.838314 %, total balance 6514.410042,
# day 340, sell 1 unit at price 112.510002, investment 11.661373 %, total balance 6626.920044,
# day 341, sell 1 unit at price 109.449997, investment 9.013940 %, total balance 6736.370041,
# day 342, sell 1 unit at price 110.320000, investment 9.292646 %, total balance 6846.690041,
# day 343: buy 1 unit at price 109.900002, total balance 6736.790039
# day 344, sell 1 unit at price 111.309998, investment 9.470886 %, total balance 6848.100037,
# day 345, sell 1 unit at price 110.769997, investment 8.068289 %, total balance 6958.870033,
# day 346: buy 1 unit at price 111.349998, total balance 6847.520035
# day 347, sell 1 unit at price 111.730003, investment 8.066548 %, total balance 6959.250038,
# day 349: buy 1 unit at price 108.639999, total balance 6850.610039
# day 350, sell 1 unit at price 109.709999, investment 5.318231 %, total balance 6960.320038,
# day 352, sell 1 unit at price 108.220001, investment 4.177902 %, total balance 7068.540039,
# day 354, sell 1 unit at price 105.959999, investment 1.640287 %, total balance 7174.500038,
# day 355: buy 1 unit at price 106.459999, total balance 7068.040039
# day 357: buy 1 unit at price 110.129997, total balance 6957.910042
# day 360: buy 1 unit at price 110.339996, total balance 6847.570045
# day 361: buy 1 unit at price 110.680000, total balance 6736.890045
# day 363, sell 1 unit at price 109.540001, investment 8.584461 %, total balance 6846.430046,
# day 364: buy 1 unit at price 109.820000, total balance 6736.610046
# day 365, sell 1 unit at price 109.220001, investment 5.946265 %, total balance 6845.830048,
# day 367: buy 1 unit at price 109.910004, total balance 6735.920044
# day 368: buy 1 unit at price 110.190002, total balance 6625.730042
# day 369: buy 1 unit at price 109.440002, total balance 6516.290039
# day 370: buy 1 unit at price 108.660004, total balance 6407.630035
# day 371, sell 1 unit at price 107.760002, investment 2.171234 %, total balance 6515.390038,
# day 372: buy 1 unit at price 108.480003, total balance 6406.910034
# day 373, sell 1 unit at price 108.839996, investment 3.371636 %, total balance 6515.750031,
# day 376: buy 1 unit at price 113.800003, total balance 6401.950027
# day 377, sell 1 unit at price 112.820000, investment 8.282942 %, total balance 6514.770027,
# day 378: buy 1 unit at price 113.489998, total balance 6401.280029
# day 379, sell 1 unit at price 112.870003, investment 9.614452 %, total balance 6514.150032,
# day 380: buy 1 unit at price 113.349998, total balance 6400.800034
# day 381, sell 1 unit at price 113.019997, investment 8.631291 %, total balance 6513.820030,
# day 382: buy 1 unit at price 114.099998, total balance 6399.720032
# day 385, sell 1 unit at price 115.120003, investment 9.284229 %, total balance 6514.840034,
# day 386: buy 1 unit at price 113.989998, total balance 6400.850037
# day 387, sell 1 unit at price 114.669998, investment 9.711062 %, total balance 6515.520035,
# day 389, sell 1 unit at price 114.269997, investment 15.505910 %, total balance 6629.790031,
# day 392: buy 1 unit at price 115.709999, total balance 6514.080032
# day 393: buy 1 unit at price 116.220001, total balance 6397.860031
# day 395, sell 1 unit at price 115.589996, investment 10.464447 %, total balance 6513.450027,
# day 397, sell 1 unit at price 112.940002, investment 7.418683 %, total balance 6626.390030,
# day 398, sell 1 unit at price 112.930000, investment 7.195066 %, total balance 6739.320030,
# day 399, sell 1 unit at price 109.570000, investment 3.798790 %, total balance 6848.890030,
# day 400, sell 1 unit at price 110.430000, investment 5.301800 %, total balance 6959.320030,
# day 401, sell 1 unit at price 108.029999, investment 2.553638 %, total balance 7067.350029,
# day 402, sell 1 unit at price 109.860001, investment -0.072769 %, total balance 7177.210030,
# day 403: buy 1 unit at price 109.739998, total balance 7067.470032
# day 404, sell 1 unit at price 107.680000, investment -5.094305 %, total balance 7175.150032,
# day 405: buy 1 unit at price 109.339996, total balance 7065.810036
# day 406: buy 1 unit at price 104.800003, total balance 6961.010033
# day 407, sell 1 unit at price 105.199997, investment -7.394368 %, total balance 7066.210030,
# day 408: buy 1 unit at price 107.720001, total balance 6958.490028
# day 411, sell 1 unit at price 107.610001, investment -5.389482 %, total balance 7066.100029,
# day 412: buy 1 unit at price 108.720001, total balance 6957.380028
# day 413: buy 1 unit at price 106.019997, total balance 6851.360031
# day 414, sell 1 unit at price 106.870003, investment -7.965897 %, total balance 6958.230034,
# day 415: buy 1 unit at price 105.739998, total balance 6852.490036
# day 416: buy 1 unit at price 106.800003, total balance 6745.690033
# day 419: buy 1 unit at price 108.559998, total balance 6637.130035
# day 420: buy 1 unit at price 109.870003, total balance 6527.260033
# day 422, sell 1 unit at price 112.610001, investment -2.964242 %, total balance 6639.870033,
# day 423: buy 1 unit at price 115.400002, total balance 6524.470032
# day 424, sell 1 unit at price 116.870003, investment 1.265054 %, total balance 6641.340034,
# day 427: buy 1 unit at price 120.230003, total balance 6521.110031
# day 428: buy 1 unit at price 119.160004, total balance 6401.950027
# day 429, sell 1 unit at price 118.570000, investment 4.734565 %, total balance 6520.520027,
# day 431, sell 1 unit at price 119.379997, investment 8.626020 %, total balance 6639.900024,
# day 433, sell 1 unit at price 118.879997, investment 6.762460 %, total balance 6758.780022,
# day 434: buy 1 unit at price 117.330002, total balance 6641.450020
# day 435, sell 1 unit at price 118.000000, investment 8.615612 %, total balance 6759.450020,
# day 437, sell 1 unit at price 117.720001, investment 10.576745 %, total balance 6877.170021,
# day 438, sell 1 unit at price 117.690002, investment 6.864619 %, total balance 6994.860023,
# day 439: buy 1 unit at price 115.550003, total balance 6879.310020
# day 440: buy 1 unit at price 113.250000, total balance 6766.060020
# day 441, sell 1 unit at price 112.190002, investment 1.676641 %, total balance 6878.250023,
# day 442, sell 1 unit at price 114.620003, investment 3.559814 %, total balance 6992.870026,
# day 443: buy 1 unit at price 114.370003, total balance 6878.500023
# day 444, sell 1 unit at price 111.820000, investment 1.821162 %, total balance 6990.320023,
# day 445, sell 1 unit at price 112.629997, investment 2.474746 %, total balance 7102.950020,
# day 447, sell 1 unit at price 116.139999, investment 5.399761 %, total balance 7219.090019,
# day 448: buy 1 unit at price 116.449997, total balance 7102.640022
# day 449: buy 1 unit at price 119.959999, total balance 6982.680023
# day 452: buy 1 unit at price 120.559998, total balance 6862.120026
# day 453, sell 1 unit at price 123.550003, investment 12.892910 %, total balance 6985.670029,
# day 456, sell 1 unit at price 125.029999, investment 15.065336 %, total balance 7110.700027,
# day 458, sell 1 unit at price 126.510002, investment 16.620574 %, total balance 7237.210030,
# day 459, sell 1 unit at price 126.430000, investment 11.098416 %, total balance 7363.640030,
# day 460: buy 1 unit at price 125.730003, total balance 7237.910027
# day 461, sell 1 unit at price 124.919998, investment 10.071372 %, total balance 7362.830025,
# day 464, sell 1 unit at price 129.100006, investment 13.895022 %, total balance 7491.930031,
# day 465, sell 1 unit at price 129.300003, investment 13.321652 %, total balance 7621.230034,
# day 466: buy 1 unit at price 130.000000, total balance 7491.230034
# day 467: buy 1 unit at price 130.380005, total balance 7360.850029
# day 468, sell 1 unit at price 129.919998, investment 13.974911 %, total balance 7490.770027,
# day 469, sell 1 unit at price 129.160004, investment 11.623891 %, total balance 7619.930031,
# day 470, sell 1 unit at price 128.479996, investment 10.548954 %, total balance 7748.410027,
# day 471: buy 1 unit at price 128.600006, total balance 7619.810020
# day 472, sell 1 unit at price 129.529999, investment 18.033535 %, total balance 7749.340019,
# day 473, sell 1 unit at price 130.619995, investment 19.462227 %, total balance 7879.960014,
# day 474, sell 1 unit at price 130.580002, investment 24.599235 %, total balance 8010.540016,
# day 475, sell 1 unit at price 129.630005, investment 20.339773 %, total balance 8140.170021,
# day 476, sell 1 unit at price 129.929993, investment 19.508822 %, total balance 8270.100014,
# day 478, sell 1 unit at price 131.490005, investment 24.023778 %, total balance 8401.590019,
# day 479, sell 1 unit at price 131.669998, investment 24.522414 %, total balance 8533.260017,
# day 480: buy 1 unit at price 132.059998, total balance 8401.200020
# day 482, sell 1 unit at price 131.470001, investment 23.099249 %, total balance 8532.670021,
# day 483, sell 1 unit at price 129.779999, investment 19.546796 %, total balance 8662.450020,
# day 484, sell 1 unit at price 132.339996, investment 20.451436 %, total balance 8794.790016,
# day 486, sell 1 unit at price 135.039993, investment 17.019057 %, total balance 8929.830009,
# day 488, sell 1 unit at price 134.500000, investment 11.868915 %, total balance 9064.330009,
# day 489, sell 1 unit at price 134.179993, investment 12.604891 %, total balance 9198.510002,
# day 491: buy 1 unit at price 136.809998, total balance 9061.700005
# day 492, sell 1 unit at price 137.339996, investment 17.054457 %, total balance 9199.040001,
# day 494, sell 1 unit at price 138.039993, investment 19.463427 %, total balance 9337.079994,
# day 495, sell 1 unit at price 137.350006, investment 21.280359 %, total balance 9474.430000,
# day 496, sell 1 unit at price 137.240005, investment 19.996505 %, total balance 9611.670006,
# day 497: buy 1 unit at price 137.199997, total balance 9474.470009
# day 499, sell 1 unit at price 139.039993, investment 19.398881 %, total balance 9613.510002,
# day 501, sell 1 unit at price 138.630005, investment 15.563526 %, total balance 9752.140007,
# day 502, sell 1 unit at price 139.399994, investment 15.627071 %, total balance 9891.540001,
# day 503, sell 1 unit at price 141.089996, investment 12.216649 %, total balance 10032.629997,
# day 505, sell 1 unit at price 138.229996, investment 6.330766 %, total balance 10170.859993,
# day 506: buy 1 unit at price 135.880005, total balance 10034.979988
# day 507, sell 1 unit at price 136.940002, investment 5.031444 %, total balance 10171.919991,
# day 509: buy 1 unit at price 136.070007, total balance 10035.849983
# day 510, sell 1 unit at price 137.199997, investment 6.687395 %, total balance 10173.049980,
# day 511, sell 1 unit at price 138.800003, investment 5.103745 %, total balance 10311.849983,
# day 513, sell 1 unit at price 137.250000, investment 0.321616 %, total balance 10449.099983,
# day 515: buy 1 unit at price 136.839996, total balance 10312.259987
# day 518: buy 1 unit at price 133.149994, total balance 10179.109993
# day 519, sell 1 unit at price 132.029999, investment -3.768220 %, total balance 10311.139992,
# day 520, sell 1 unit at price 134.429993, investment -1.067127 %, total balance 10445.569984,
# day 521: buy 1 unit at price 134.229996, total balance 10311.339989
# day 522, sell 1 unit at price 135.889999, investment -0.132291 %, total balance 10447.229988,
# day 523: buy 1 unit at price 132.360001, total balance 10314.869987
# day 524, sell 1 unit at price 133.369995, investment -2.535809 %, total balance 10448.239983,
# day 526, sell 1 unit at price 137.589996, investment 3.334587 %, total balance 10585.829979,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig('output/'+name+'.png')
plt.show()

# %% [markdown]
# ### 3.15 DEEP EVOLUTION AGENT

# %%
## Deep Evolution Strategy

plt.figure(figsize = (10, 5))
bins = np.linspace(-10, 10, 100)

solution = np.random.randn(100)
w = np.random.randn(100)

plt.hist(solution, bins, alpha = 0.5, label = 'solution', color = 'r')
plt.hist(w, bins, alpha = 0.5, label = 'random', color = 'y')
plt.legend()
plt.show()

def f(w):
    return -np.sum(np.square(solution - w))


npop = 50
sigma = 0.1
alpha = 0.001

for i in range(5000):

    if (i + 1) % 1000 == 0:
        print(
            'iter %d. w: %s, solution: %s, reward: %f'
            % (i + 1, str(w[-1]), str(solution[-1]), f(w))
        )
    N = np.random.randn(npop, 100)
    R = np.zeros(npop)
    for j in range(npop):
        w_try = w + sigma * N[j]
        R[j] = f(w_try)

    A = (R - np.mean(R)) / np.std(R)
    w = w + alpha / (npop * sigma) * np.dot(N.T, A)

'''
I want to compare my first two individuals with my real w
'''
plt.figure(figsize=(10,5))

sigma = 0.1
N = np.random.randn(npop, 100)
individuals = []
for j in range(2):
    individuals.append(w + sigma * N[j])
    
    
plt.hist(w, bins, alpha=0.5, label='w',color='r')
plt.hist(individuals[0], bins, alpha=0.5, label='individual 1')
plt.hist(individuals[1], bins, alpha=0.5, label='individual 2')
plt.legend()
plt.show()

df= df_full.copy()
name = 'Deep Evolution Strategy'

def get_state(data, t, n):
    d = t - n + 1
    block = data[d : t + 1] if d >= 0 else -d * [data[0]] + data[: t + 1]
    res = []
    for i in range(n - 1):
        res.append(block[i + 1] - block[i])
    return np.array([res])

close = df.Close.values.tolist()
get_state(close, 0, 10)

get_state(close, 1, 10)

get_state(close, 2, 10)

class Deep_Evolution_Strategy:
    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights

    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / np.std(rewards)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')

class Model:
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.randn(input_size, layer_size),
            np.random.randn(layer_size, output_size),
            np.random.randn(layer_size, 1),
            np.random.randn(1, layer_size),
        ]

    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-1]
        decision = np.dot(feed, self.weights[1])
        buy = np.dot(feed, self.weights[2])
        return decision, buy

    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights

window_size = 30
model = Model(window_size, 500, 3)

initial_money = 10000
starting_money = initial_money
len_close = len(close) - 1
weight = model
skip = 1

state = get_state(close, 0, window_size + 1)
inventory = []
quantity = 0

max_buy = 5
max_sell = 5


def act(model, sequence):
    decision, buy = model.predict(np.array(sequence))
    return np.argmax(decision[0]), int(buy[0])


for t in range(0, len_close, skip):
    action, buy = act(weight, state)
    next_state = get_state(close, t + 1, window_size + 1)
    if action == 1 and initial_money >= close[t]:
        if buy < 0:
            buy = 1
        if buy > max_buy:
            buy_units = max_buy
        else:
            buy_units = buy
        total_buy = buy_units * close[t]
        initial_money -= total_buy
        inventory.append(total_buy)
        quantity += buy_units
    elif action == 2 and len(inventory) > 0:
        if quantity > max_sell:
            sell_units = max_sell
        else:
            sell_units = quantity
        quantity -= sell_units
        total_sell = sell_units * close[t]
        initial_money += total_sell

    state = next_state
((initial_money - starting_money) / starting_money) * 100

import time


class Agent:

    POPULATION_SIZE = 15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(
        self, model, money, max_buy, max_sell, close, window_size, skip
    ):
        self.window_size = window_size
        self.skip = skip
        self.close = close
        self.model = model
        self.initial_money = money
        self.max_buy = max_buy
        self.max_sell = max_sell
        self.es = Deep_Evolution_Strategy(
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )

    def act(self, sequence):
        decision, buy = self.model.predict(np.array(sequence))
        return np.argmax(decision[0]), int(buy[0])

    def get_reward(self, weights):
        initial_money = self.initial_money
        starting_money = initial_money
        len_close = len(self.close) - 1

        self.model.weights = weights
        state = get_state(self.close, 0, self.window_size + 1)
        inventory = []
        quantity = 0
        for t in range(0, len_close, self.skip):
            action, buy = self.act(state)
            next_state = get_state(self.close, t + 1, self.window_size + 1)
            if action == 1 and initial_money >= self.close[t]:
                if buy < 0:
                    buy = 1
                if buy > self.max_buy:
                    buy_units = self.max_buy
                else:
                    buy_units = buy
                total_buy = buy_units * self.close[t]
                initial_money -= total_buy
                inventory.append(total_buy)
                quantity += buy_units
            elif action == 2 and len(inventory) > 0:
                if quantity > self.max_sell:
                    sell_units = self.max_sell
                else:
                    sell_units = quantity
                quantity -= sell_units
                total_sell = sell_units * self.close[t]
                initial_money += total_sell

            state = next_state
        return ((initial_money - starting_money) / starting_money) * 100

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self):
        initial_money = self.initial_money
        len_close = len(self.close) - 1
        state = get_state(self.close, 0, self.window_size + 1)
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        quantity = 0
        for t in range(0, len_close, self.skip):
            action, buy = self.act(state)
            next_state = get_state(self.close, t + 1, self.window_size + 1)
            if action == 1 and initial_money >= self.close[t]:
                if buy < 0:
                    buy = 1
                if buy > self.max_buy:
                    buy_units = self.max_buy
                else:
                    buy_units = buy
                total_buy = buy_units * self.close[t]
                initial_money -= total_buy
                inventory.append(total_buy)
                quantity += buy_units
                states_buy.append(t)
                print(
                    'day %d: buy %d units at price %f, total balance %f'
                    % (t, buy_units, total_buy, initial_money)
                )
            elif action == 2 and len(inventory) > 0:
                bought_price = inventory.pop(0)
                if quantity > self.max_sell:
                    sell_units = self.max_sell
                else:
                    sell_units = quantity
                if sell_units < 1:
                    continue
                quantity -= sell_units
                total_sell = sell_units * self.close[t]
                initial_money += total_sell
                states_sell.append(t)
                try:
                    invest = ((total_sell - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell %d units at price %f, investment %f %%, total balance %f,'
                    % (t, sell_units, total_sell, invest, initial_money)
                )
            state = next_state

        invest = ((initial_money - starting_money) / starting_money) * 100
        print(
            '\ntotal gained %f, total investment %f %%'
            % (initial_money - starting_money, invest)
        )
        plt.figure(figsize = (20, 10))
        plt.plot(close, label = 'true close', c = 'g')
        plt.plot(
            close, 'X', label = 'predict buy', markevery = states_buy, c = 'b'
        )
        plt.plot(
            close, 'o', label = 'predict sell', markevery = states_sell, c = 'r'
        )
        plt.legend()
        plt.savefig('output/'+name+'.png')
        plt.show()

model = Model(input_size = window_size, layer_size = 500, output_size = 3)
agent = Agent(
    model = model,
    money = 10000,
    max_buy = 5,
    max_sell = 5,
    close = close,
    window_size = window_size,
    skip = 1,
)

agent.fit(iterations = 500, checkpoint = 10)

agent.buy()
# Out:
# iter 1000. w: 0.7945617060366326, solution: 1.3732662064069734, reward: -36.817704
# iter 2000. w: 1.3883476310739775, solution: 1.3732662064069734, reward: -0.006056
# iter 3000. w: 1.3729840452543918, solution: 1.3732662064069734, reward: -0.008243
# iter 4000. w: 1.3694037909441665, solution: 1.3732662064069734, reward: -0.007895
# iter 5000. w: 1.3750746044578301, solution: 1.3732662064069734, reward: -0.007078
# iter 10. reward: 18.698903
# iter 20. reward: 19.102502
# iter 30. reward: 41.217004
# iter 40. reward: 40.348502
# iter 50. reward: 42.694803
# iter 60. reward: 41.097303
# iter 70. reward: 42.418503
# iter 80. reward: 45.155803
# iter 90. reward: 47.294100
# iter 100. reward: 46.113702
# iter 110. reward: 49.104503
# iter 120. reward: 46.833801
# iter 130. reward: 49.258300
# iter 140. reward: 47.549802
# iter 150. reward: 47.436901
# iter 160. reward: 50.917200
# iter 170. reward: 49.719901
# iter 180. reward: 51.097801
# iter 190. reward: 47.244601
# iter 200. reward: 48.689201
# iter 210. reward: 46.906600
# iter 220. reward: 48.755099
# iter 230. reward: 49.747498
# iter 240. reward: 53.302098
# iter 250. reward: 51.675399
# iter 260. reward: 53.522299
# iter 270. reward: 54.789200
# iter 280. reward: 55.726100
# iter 290. reward: 56.392099
# iter 300. reward: 56.263499
# iter 310. reward: 54.608299
# iter 320. reward: 54.241198
# iter 330. reward: 49.844799
# iter 340. reward: 53.787299
# iter 350. reward: 54.915899
# iter 360. reward: 56.245499
# iter 370. reward: 57.565898
# iter 380. reward: 54.717199
# iter 390. reward: 54.189199
# iter 400. reward: 54.834100
# iter 410. reward: 52.666700
# iter 420. reward: 54.736200
# iter 430. reward: 53.193699
# iter 440. reward: 52.296901
# iter 450. reward: 52.278902
# iter 460. reward: 54.822300
# iter 470. reward: 53.585401
# iter 480. reward: 55.485200
# iter 490. reward: 54.911201
# iter 500. reward: 54.759701
# time taken to train: 780.3423099517822 seconds
# day 0: buy 5 units at price 539.749985, total balance 9460.250015
# day 1: buy 5 units at price 540.299988, total balance 8919.950027
# day 2, sell 5 units at price 545.200005, investment 1.009730 %, total balance 9465.150032,
# day 3: buy 5 units at price 541.699982, total balance 8923.450050
# day 4: buy 5 units at price 542.500000, total balance 8380.950050
# day 5, sell 5 units at price 545.250015, investment 0.916163 %, total balance 8926.200066,
# day 6: buy 5 units at price 551.250000, total balance 8374.950066
# day 7, sell 5 units at price 554.199982, investment 2.307550 %, total balance 8929.150047,
# day 8, sell 5 units at price 563.349991, investment 3.843316 %, total balance 9492.500038,
# day 10, sell 5 units at price 564.949989, investment 2.485259 %, total balance 10057.450027,
# day 22: buy 5 units at price 571.399994, total balance 9486.050034
# day 24, sell 5 units at price 560.550003, investment -1.898843 %, total balance 10046.600037,
# day 25: buy 5 units at price 564.350014, total balance 9482.250023
# day 26: buy 5 units at price 539.399986, total balance 8942.850037
# day 27, sell 5 units at price 550.200005, investment -2.507311 %, total balance 9493.050041,
# day 29: buy 5 units at price 562.150002, total balance 8930.900040
# day 30, sell 5 units at price 575.149994, investment 6.627736 %, total balance 9506.050034,
# day 33, sell 5 units at price 573.549995, investment 2.027927 %, total balance 10079.600029,
# day 34: buy 1 units at price 115.190002, total balance 9964.410027
# day 36, sell 1 units at price 117.309998, investment 1.840433 %, total balance 10081.720024,
# day 40: buy 1 units at price 113.430000, total balance 9968.290024
# day 41: buy 5 units at price 566.599998, total balance 9401.690025
# day 42, sell 5 units at price 575.299988, investment 407.185036 %, total balance 9976.990013,
# day 43: buy 1 units at price 115.160004, total balance 9861.830009
# day 44: buy 5 units at price 573.650017, total balance 9288.179993
# day 45, sell 5 units at price 573.699989, investment 1.253087 %, total balance 9861.879982,
# day 46, sell 2 units at price 236.080002, investment 105.001732 %, total balance 10097.959984,
# day 55: buy 1 units at price 109.949997, total balance 9988.009987
# day 56: buy 1 units at price 107.010002, total balance 9880.999985
# day 57, sell 2 units at price 220.619995, investment 100.654844 %, total balance 10101.619980,
# day 58: buy 5 units at price 540.849991, total balance 9560.769989
# day 59, sell 5 units at price 540.000000, investment 404.625726 %, total balance 10100.769989,
# day 61: buy 5 units at price 539.249992, total balance 9561.519997
# day 62: buy 5 units at price 546.650009, total balance 9014.869987
# day 63, sell 5 units at price 554.949989, investment 2.607007 %, total balance 9569.819977,
# day 64: buy 5 units at price 559.399986, total balance 9010.419991
# day 66, sell 5 units at price 552.000008, investment 2.364398 %, total balance 9562.419998,
# day 68, sell 5 units at price 553.100014, investment 1.179915 %, total balance 10115.520012,
# day 71: buy 5 units at price 551.049995, total balance 9564.470016
# day 72, sell 5 units at price 551.049995, investment 0.000000 %, total balance 10115.520012,
# day 73: buy 5 units at price 546.599998, total balance 9568.920013
# day 74, sell 5 units at price 558.600006, investment 2.195391 %, total balance 10127.520020,
# day 76: buy 1 units at price 110.930000, total balance 10016.590019
# day 78: buy 1 units at price 109.989998, total balance 9906.600021
# day 79: buy 5 units at price 550.499992, total balance 9356.100029
# day 80, sell 5 units at price 547.000008, investment 393.103765 %, total balance 9903.100037,
# day 81: buy 1 units at price 108.779999, total balance 9794.320038
# day 83, sell 3 units at price 323.759995, investment 194.354033 %, total balance 10118.080032,
# day 84: buy 5 units at price 536.199989, total balance 9581.880043
# day 85, sell 5 units at price 542.150002, investment -1.516801 %, total balance 10124.030045,
# day 86: buy 5 units at price 546.850014, total balance 9577.180031
# day 88, sell 5 units at price 567.050018, investment 421.281508 %, total balance 10144.230049,
# day 94: buy 5 units at price 564.799995, total balance 9579.430054
# day 97, sell 5 units at price 565.050011, investment 0.044266 %, total balance 10144.480064,
# day 99: buy 1 units at price 111.230003, total balance 10033.250061
# day 100: buy 1 units at price 110.660004, total balance 9922.590057
# day 101: buy 5 units at price 529.650002, total balance 9392.940056
# day 102, sell 5 units at price 541.749992, investment 387.053831 %, total balance 9934.690048,
# day 103: buy 5 units at price 535.050011, total balance 9399.640038
# day 104: buy 5 units at price 542.000008, total balance 8857.640030
# day 105, sell 5 units at price 542.249985, investment 390.014429 %, total balance 9399.890015,
# day 106: buy 5 units at price 539.199982, total balance 8860.690033
# day 107: buy 5 units at price 551.800003, total balance 8308.890030
# day 108, sell 5 units at price 554.000015, investment 4.597378 %, total balance 8862.890045,
# day 109: buy 1 units at price 111.110001, total balance 8751.780045
# day 111: buy 1 units at price 110.190002, total balance 8641.590042
# day 112: buy 5 units at price 549.850006, total balance 8091.740036
# day 113: buy 5 units at price 540.149994, total balance 7551.590042
# day 114: buy 5 units at price 539.500008, total balance 7012.090034
# day 116: buy 5 units at price 537.750015, total balance 6474.340019
# day 119: buy 5 units at price 528.750000, total balance 5945.590019
# day 121: buy 5 units at price 524.300003, total balance 5421.290016
# day 122: buy 5 units at price 516.199989, total balance 4905.090027
# day 123: buy 5 units at price 524.650002, total balance 4380.440025
# day 124: buy 5 units at price 520.999985, total balance 3859.440041
# day 125: buy 5 units at price 525.400009, total balance 3334.040031
# day 127: buy 5 units at price 518.600006, total balance 2815.440025
# day 128: buy 5 units at price 520.299988, total balance 2295.140038
# day 129, sell 5 units at price 536.399994, investment 0.252310 %, total balance 2831.540031,
# day 130: buy 5 units at price 533.100014, total balance 2298.440018
# day 132: buy 5 units at price 534.249992, total balance 1764.190025
# day 134, sell 5 units at price 552.900009, investment 2.011070 %, total balance 2317.090034,
# day 135, sell 5 units at price 552.500000, investment 2.466621 %, total balance 2869.590034,
# day 138, sell 5 units at price 556.399994, investment 0.833634 %, total balance 3425.990028,
# day 139, sell 5 units at price 566.749992, investment 410.080091 %, total balance 3992.740021,
# day 140, sell 5 units at price 570.750008, investment 417.968958 %, total balance 4563.490028,
# day 143, sell 5 units at price 580.149994, investment 5.510592 %, total balance 5143.640022,
# day 144, sell 5 units at price 583.650017, investment 8.053323 %, total balance 5727.290039,
# day 145, sell 5 units at price 574.749985, investment 6.533823 %, total balance 6302.040024,
# day 146, sell 5 units at price 578.300018, investment 7.540679 %, total balance 6880.340042,
# day 148: buy 5 units at price 585.449982, total balance 6294.890060
# day 149, sell 5 units at price 585.600014, investment 10.751776 %, total balance 6880.490074,
# day 150, sell 5 units at price 587.750015, investment 12.101852 %, total balance 7468.240089,
# day 151, sell 5 units at price 588.950005, investment 14.093378 %, total balance 8057.190094,
# day 153: buy 1 units at price 115.730003, total balance 7941.460091
# day 154: buy 5 units at price 569.449997, total balance 7372.010094
# day 155, sell 5 units at price 573.250008, investment 9.263320 %, total balance 7945.260101,
# day 157, sell 5 units at price 573.849983, investment 10.143954 %, total balance 8519.110085,
# day 159: buy 5 units at price 573.100014, total balance 7946.010071
# day 160, sell 5 units at price 576.599998, investment 9.744954 %, total balance 8522.610069,
# day 162: buy 1 units at price 114.730003, total balance 8407.880066
# day 164: buy 5 units at price 583.549995, total balance 7824.330070
# day 166: buy 5 units at price 578.800011, total balance 7245.530060
# day 169, sell 5 units at price 575.750008, investment 11.020054 %, total balance 7821.280067,
# day 171: buy 5 units at price 570.499992, total balance 7250.780075
# day 172, sell 5 units at price 571.599998, investment 9.859699 %, total balance 7822.380074,
# day 173: buy 1 units at price 113.709999, total balance 7708.670074
# day 174: buy 5 units at price 572.150002, total balance 7136.520073
# day 175: buy 1 units at price 113.080002, total balance 7023.440071
# day 176: buy 1 units at price 113.519997, total balance 6909.920074
# day 178, sell 5 units at price 569.199982, investment 6.771706 %, total balance 7479.120056,
# day 179, sell 5 units at price 571.500015, investment 6.972396 %, total balance 8050.620071,
# day 180, sell 5 units at price 588.100014, investment 0.452649 %, total balance 8638.720085,
# day 181, sell 5 units at price 593.149986, investment 412.529136 %, total balance 9231.870071,
# day 183: buy 1 units at price 116.720001, total balance 9115.150070
# day 185: buy 5 units at price 575.099983, total balance 8540.050087
# day 186, sell 5 units at price 572.599983, investment 0.553163 %, total balance 9112.650070,
# day 188: buy 5 units at price 567.500000, total balance 8545.150070
# day 189, sell 5 units at price 569.850006, investment -0.567093 %, total balance 9115.000076,
# day 190, sell 5 units at price 575.200005, investment 401.350987 %, total balance 9690.200081,
# day 191: buy 1 units at price 115.269997, total balance 9574.930084
# day 192: buy 1 units at price 114.620003, total balance 9460.310081
# day 194, sell 5 units at price 572.599983, investment -1.876448 %, total balance 10032.910065,
# day 195: buy 1 units at price 111.470001, total balance 9921.440063
# day 196: buy 5 units at price 540.649986, total balance 9380.790077
# day 197: buy 5 units at price 534.749985, total balance 8846.040092
# day 198: buy 5 units at price 531.699982, total balance 8314.340111
# day 199: buy 5 units at price 543.100014, total balance 7771.240097
# day 200: buy 5 units at price 549.150009, total balance 7222.090088
# day 201: buy 5 units at price 540.449982, total balance 6681.640106
# day 202, sell 5 units at price 539.550018, investment -6.781270 %, total balance 7221.190125,
# day 203: buy 1 units at price 106.360001, total balance 7114.830124
# day 204: buy 5 units at price 526.250000, total balance 6588.580124
# day 205: buy 5 units at price 516.450005, total balance 6072.130119
# day 206: buy 5 units at price 524.300003, total balance 5547.830116
# day 207: buy 5 units at price 517.099991, total balance 5030.730125
# day 208: buy 5 units at price 524.249992, total balance 4506.480133
# day 209, sell 5 units at price 533.499985, investment -6.485540 %, total balance 5039.980118,
# day 210: buy 5 units at price 545.099983, total balance 4494.880135
# day 211: buy 1 units at price 108.980003, total balance 4385.900131
# day 213: buy 1 units at price 109.089996, total balance 4276.810135
# day 214, sell 5 units at price 547.999992, investment 381.927708 %, total balance 4824.810127,
# day 215, sell 5 units at price 557.400017, investment -2.577993 %, total balance 5382.210144,
# day 219, sell 5 units at price 547.949982, investment 384.568423 %, total balance 5930.160126,
# day 220, sell 5 units at price 536.650009, investment 372.736104 %, total balance 6466.810135,
# day 221, sell 5 units at price 550.349998, investment 371.513016 %, total balance 7017.160133,
# day 222, sell 5 units at price 549.949989, investment -4.373152 %, total balance 7567.110123,
# day 223, sell 5 units at price 554.150009, investment -2.352421 %, total balance 8121.260132,
# day 225: buy 5 units at price 538.199997, total balance 7583.060135
# day 226: buy 5 units at price 533.250008, total balance 7049.810127
# day 227, sell 5 units at price 546.300011, investment 373.930794 %, total balance 7596.110138,
# day 228: buy 1 units at price 109.720001, total balance 7486.390137
# day 229, sell 5 units at price 554.700012, investment 383.946954 %, total balance 8041.090149,
# day 230, sell 5 units at price 550.299988, investment 393.675412 %, total balance 8591.390137,
# day 231, sell 5 units at price 555.950012, investment 2.829932 %, total balance 9147.340149,
# day 232, sell 5 units at price 561.199989, investment 4.946238 %, total balance 9708.540138,
# day 233: buy 1 units at price 107.230003, total balance 9601.310135
# day 234: buy 1 units at price 105.190002, total balance 9496.120132
# day 235: buy 5 units at price 516.450005, total balance 8979.670128
# day 236: buy 5 units at price 506.800003, total balance 8472.870125
# day 237, sell 5 units at price 501.850014, investment -5.614062 %, total balance 8974.720139,
# day 238: buy 5 units at price 505.099983, total balance 8469.620155
# day 239: buy 5 units at price 505.600014, total balance 7964.020142
# day 240: buy 1 units at price 100.290001, total balance 7863.730141
# day 241: buy 1 units at price 99.010002, total balance 7764.720139
# day 242: buy 5 units at price 492.700005, total balance 7272.020134
# day 243: buy 5 units at price 486.450005, total balance 6785.570129
# day 244: buy 5 units at price 482.249985, total balance 6303.320145
# day 246: buy 5 units at price 460.699997, total balance 5842.620148
# day 247: buy 5 units at price 479.799995, total balance 5362.820152
# day 248: buy 5 units at price 485.200005, total balance 4877.620148
# day 249: buy 5 units at price 484.150009, total balance 4393.470139
# day 251: buy 5 units at price 496.549988, total balance 3896.920151
# day 252: buy 5 units at price 485.550003, total balance 3411.370148
# day 253, sell 5 units at price 503.450012, investment -7.300681 %, total balance 3914.820160,
# day 254: buy 5 units at price 503.800011, total balance 3411.020149
# day 255: buy 5 units at price 502.849998, total balance 2908.170151
# day 257: buy 5 units at price 501.949997, total balance 2406.220154
# day 258: buy 5 units at price 499.550018, total balance 1906.670135
# day 259, sell 5 units at price 504.700012, investment -8.094327 %, total balance 2411.370148,
# day 260, sell 5 units at price 508.400002, investment -5.930240 %, total balance 2919.770149,
# day 262, sell 5 units at price 514.599991, investment 383.828496 %, total balance 3434.370140,
# day 263, sell 5 units at price 522.949982, investment -0.627082 %, total balance 3957.320122,
# day 265, sell 5 units at price 513.400002, investment -0.590571 %, total balance 4470.720123,
# day 267: buy 5 units at price 516.949997, total balance 3953.770126
# day 268, sell 5 units at price 519.399986, investment -0.934583 %, total balance 4473.170113,
# day 269, sell 5 units at price 520.849991, investment 0.725198 %, total balance 4994.020103,
# day 270, sell 5 units at price 522.050018, investment -0.419642 %, total balance 5516.070122,
# day 272: buy 1 units at price 103.879997, total balance 5412.190125
# day 273: buy 5 units at price 521.250000, total balance 4890.940125
# day 274: buy 5 units at price 518.950005, total balance 4371.990120
# day 275: buy 5 units at price 518.699989, total balance 3853.290131
# day 278: buy 5 units at price 504.399986, total balance 3348.890144
# day 279: buy 5 units at price 512.999992, total balance 2835.890152
# day 281: buy 5 units at price 512.099991, total balance 2323.790161
# day 282, sell 5 units at price 527.750015, investment -3.182896 %, total balance 2851.540176,
# day 284, sell 5 units at price 528.450012, investment 384.905484 %, total balance 3379.990189,
# day 286: buy 5 units at price 525.000000, total balance 2854.990189
# day 288, sell 5 units at price 526.450005, investment 382.583209 %, total balance 3381.440193,
# day 289: buy 5 units at price 525.800018, total balance 2855.640175
# day 291: buy 1 units at price 104.430000, total balance 2751.210175
# day 293: buy 5 units at price 520.550003, total balance 2230.660172
# day 294: buy 1 units at price 103.720001, total balance 2126.940170
# day 296, sell 5 units at price 515.050011, investment -4.301372 %, total balance 2641.990181,
# day 298: buy 5 units at price 520.200005, total balance 2121.790176
# day 299: buy 5 units at price 521.949997, total balance 1599.840179
# day 301, sell 5 units at price 532.750015, investment -0.093763 %, total balance 2132.590195,
# day 302, sell 5 units at price 535.950012, investment 388.470658 %, total balance 2668.540207,
# day 303, sell 5 units at price 534.000015, investment 397.994963 %, total balance 3202.540222,
# day 305: buy 5 units at price 514.350014, total balance 2688.190208
# day 306: buy 5 units at price 498.800011, total balance 2189.390198
# day 307: buy 5 units at price 494.650002, total balance 1694.740196
# day 308, sell 5 units at price 499.599991, investment 374.950071 %, total balance 2194.340187,
# day 309: buy 5 units at price 497.900009, total balance 1696.440178
# day 310: buy 5 units at price 503.549995, total balance 1192.890182
# day 312: buy 5 units at price 523.199997, total balance 669.690186
# day 313, sell 5 units at price 525.699997, investment 1.791072 %, total balance 1195.390182,
# day 314: buy 1 units at price 105.349998, total balance 1090.040184
# day 316: buy 5 units at price 526.549988, total balance 563.490196
# day 317, sell 5 units at price 528.250008, investment 4.232440 %, total balance 1091.740204,
# day 319: buy 5 units at price 526.699982, total balance 565.040222
# day 321, sell 5 units at price 556.049995, investment 10.087114 %, total balance 1121.090218,
# day 323, sell 5 units at price 555.499992, investment 9.869458 %, total balance 1676.590210,
# day 324, sell 5 units at price 571.500015, investment 469.847452 %, total balance 2248.090225,
# day 327, sell 5 units at price 568.699989, investment 474.386402 %, total balance 2816.790215,
# day 328: buy 5 units at price 567.750015, total balance 2249.040199
# day 329, sell 5 units at price 568.050003, investment 15.293281 %, total balance 2817.090202,
# day 330, sell 5 units at price 572.350006, investment 17.658547 %, total balance 3389.440208,
# day 331, sell 5 units at price 580.600014, investment 20.393993 %, total balance 3970.040222,
# day 332, sell 5 units at price 580.250015, investment 25.949646 %, total balance 4550.290237,
# day 333, sell 5 units at price 575.800018, investment 20.008342 %, total balance 5126.090256,
# day 335, sell 5 units at price 580.600014, investment 19.661997 %, total balance 5706.690269,
# day 336, sell 5 units at price 575.449982, investment 18.857786 %, total balance 6282.140251,
# day 338: buy 5 units at price 563.050003, total balance 5719.090248
# day 340: buy 5 units at price 562.550011, total balance 5156.540237
# day 343: buy 5 units at price 549.500008, total balance 4607.040230
# day 344: buy 5 units at price 556.549988, total balance 4050.490242
# day 346: buy 5 units at price 556.749992, total balance 3493.740250
# day 347: buy 5 units at price 558.650017, total balance 2935.090233
# day 349: buy 1 units at price 108.639999, total balance 2826.450233
# day 351: buy 5 units at price 542.599983, total balance 2283.850250
# day 352: buy 5 units at price 541.100006, total balance 1742.750244
# day 354: buy 5 units at price 529.799995, total balance 1212.950249
# day 355: buy 5 units at price 532.299995, total balance 680.650253
# day 356, sell 5 units at price 548.699989, investment 10.502468 %, total balance 1229.350243,
# day 357: buy 1 units at price 110.129997, total balance 1119.220245
# day 358: buy 1 units at price 110.370003, total balance 1008.850243
# day 359: buy 1 units at price 109.160004, total balance 899.690239
# day 361, sell 5 units at price 553.400002, investment 13.973844 %, total balance 1453.090240,
# day 362: buy 1 units at price 109.269997, total balance 1343.820244
# day 365, sell 5 units at price 546.100006, investment 8.396188 %, total balance 1889.920250,
# day 366, sell 5 units at price 553.549995, investment 10.082529 %, total balance 2443.470245,
# day 367: buy 5 units at price 549.550018, total balance 1893.920227
# day 370: buy 5 units at price 543.300018, total balance 1350.620209
# day 371: buy 1 units at price 107.760002, total balance 1242.860207
# day 372, sell 5 units at price 542.400017, investment 8.058576 %, total balance 1785.260223,
# day 373: buy 5 units at price 544.199982, total balance 1241.060242
# day 375: buy 1 units at price 113.680000, total balance 1127.380241
# day 377, sell 5 units at price 564.099998, investment 12.921625 %, total balance 1691.480240,
# day 378, sell 5 units at price 567.449989, investment 9.768835 %, total balance 2258.930229,
# day 380, sell 5 units at price 566.749992, investment 445.581447 %, total balance 2825.680222,
# day 383, sell 5 units at price 576.500015, investment 10.599523 %, total balance 3402.180237,
# day 387: buy 1 units at price 114.669998, total balance 3287.510239
# day 388, sell 5 units at price 567.700005, investment 9.393969 %, total balance 3855.210243,
# day 389, sell 5 units at price 571.349983, investment 10.150375 %, total balance 4426.560226,
# day 390, sell 5 units at price 581.800003, investment 15.344968 %, total balance 5008.360229,
# day 391, sell 5 units at price 584.150009, investment 13.869399 %, total balance 5592.510239,
# day 394: buy 5 units at price 579.249992, total balance 5013.260246
# day 395, sell 5 units at price 577.949982, investment 12.858815 %, total balance 5591.210228,
# day 396, sell 5 units at price 580.000000, investment 10.476190 %, total balance 6171.210228,
# day 397: buy 5 units at price 564.700012, total balance 5606.510216
# day 399: buy 5 units at price 547.849998, total balance 5058.660217
# day 400: buy 5 units at price 552.150002, total balance 4506.510216
# day 401: buy 5 units at price 540.149994, total balance 3966.360222
# day 402: buy 5 units at price 549.300003, total balance 3417.060219
# day 404: buy 5 units at price 538.400002, total balance 2878.660217
# day 405: buy 1 units at price 109.339996, total balance 2769.320221
# day 406: buy 5 units at price 524.000015, total balance 2245.320206
# day 407: buy 5 units at price 525.999985, total balance 1719.320221
# day 408, sell 5 units at price 538.600006, investment 2.434383 %, total balance 2257.920227,
# day 409: buy 5 units at price 543.450012, total balance 1714.470215
# day 410: buy 5 units at price 536.549988, total balance 1177.920227
# day 412: buy 5 units at price 543.600006, total balance 634.320221
# day 414: buy 1 units at price 106.870003, total balance 527.450218
# day 416: buy 5 units at price 534.000015, total balance -6.549797
# day 417, sell 5 units at price 546.100006, investment 422.934027 %, total balance 539.550209,
# day 419: buy 5 units at price 542.799988, total balance -3.249779
# day 423, sell 5 units at price 577.000008, investment 10.844300 %, total balance 573.750229,
# day 424, sell 5 units at price 584.350014, investment 463.391831 %, total balance 1158.100243,
# day 426, sell 5 units at price 589.550018, investment 13.331414 %, total balance 1747.650261,
# day 428: buy 5 units at price 595.800018, total balance 1151.850243
# day 430, sell 5 units at price 598.800011, investment 14.723635 %, total balance 1750.650253,
# day 431, sell 5 units at price 596.899986, investment 16.049377 %, total balance 2347.550240,
# day 432, sell 5 units at price 594.500008, investment 19.186045 %, total balance 2942.050247,
# day 433, sell 5 units at price 594.399986, investment 20.165771 %, total balance 3536.450233,
# day 435, sell 5 units at price 590.000000, investment 18.497688 %, total balance 4126.450233,
# day 436: buy 1 units at price 117.029999, total balance 4009.420235
# day 437: buy 5 units at price 588.600006, total balance 3420.820229
# day 438, sell 5 units at price 588.450012, investment 16.860295 %, total balance 4009.270241,
# day 439: buy 5 units at price 577.750015, total balance 3431.520226
# day 440: buy 5 units at price 566.250000, total balance 2865.270226
# day 441: buy 5 units at price 560.950012, total balance 2304.320213
# day 442: buy 5 units at price 573.100014, total balance 1731.220200
# day 443: buy 5 units at price 571.850014, total balance 1159.370186
# day 444: buy 5 units at price 559.099998, total balance 600.270187
# day 446: buy 5 units at price 571.049995, total balance 29.220192
# day 457, sell 5 units at price 630.149994, investment 20.441513 %, total balance 659.370186,
# day 458, sell 5 units at price 632.550011, investment 500.427166 %, total balance 1291.920197,
# day 459, sell 5 units at price 632.150002, investment 20.055079 %, total balance 1924.070198,
# day 461: buy 1 units at price 124.919998, total balance 1799.150200
# day 462, sell 5 units at price 639.000015, investment 21.321442 %, total balance 2438.150215,
# day 463, sell 5 units at price 644.100037, investment 13.447824 %, total balance 3082.250252,
# day 464, sell 5 units at price 645.500031, investment 14.643465 %, total balance 3727.750282,
# day 465, sell 5 units at price 646.500015, investment 14.923118 %, total balance 4374.250298,
# day 468, sell 5 units at price 649.599991, investment 18.216557 %, total balance 5023.850288,
# day 469: buy 5 units at price 645.800018, total balance 4378.050270
# day 472, sell 5 units at price 647.649994, investment 16.368701 %, total balance 5025.700264,
# day 473: buy 5 units at price 653.099976, total balance 4372.600288
# day 474: buy 5 units at price 652.900009, total balance 3719.700279
# day 477, sell 5 units at price 653.949966, investment 17.458460 %, total balance 4373.650246,
# day 478: buy 1 units at price 131.490005, total balance 4242.160240
# day 479, sell 5 units at price 658.349991, investment 17.846589 %, total balance 4900.510231,
# day 484, sell 5 units at price 661.699982, investment 509.075833 %, total balance 5562.210213,
# day 485, sell 5 units at price 665.299988, investment 22.613345 %, total balance 6227.510201,
# day 486, sell 5 units at price 675.199966, investment 24.782842 %, total balance 6902.710167,
# day 488, sell 5 units at price 672.500000, investment 26.934693 %, total balance 7575.210167,
# day 490, sell 5 units at price 690.100021, investment 29.644942 %, total balance 8265.310188,
# day 493, sell 5 units at price 690.899963, investment 527.349478 %, total balance 8956.210152,
# day 494, sell 5 units at price 690.199966, investment 525.351046 %, total balance 9646.410118,
# day 495, sell 5 units at price 686.750031, investment 529.122396 %, total balance 10333.160149,
# day 496, sell 5 units at price 686.200027, investment 527.985768 %, total balance 11019.360176,
# day 498, sell 5 units at price 687.900009, investment 25.175141 %, total balance 11707.260185,
# day 499, sell 5 units at price 695.199966, investment 27.958760 %, total balance 12402.460152,
# day 500, sell 5 units at price 695.699997, investment 545.601321 %, total balance 13098.160149,
# day 501, sell 5 units at price 693.150024, investment 27.370461 %, total balance 13791.310173,
# day 502, sell 5 units at price 696.999969, investment 513.124532 %, total balance 14488.310143,
# day 504: buy 1 units at price 138.339996, total balance 14349.970146
# day 505, sell 5 units at price 691.149979, investment 502.729563 %, total balance 15041.120125,
# day 507, sell 4 units at price 547.760010, investment -5.436337 %, total balance 15588.880135,
#
# total gained 5588.880135, total investment 55.888801 %
